# %% [markdown]
# TP  2 : Introduction à la bibliothèque spaCy et à l'analyse linguistique de texte
# ====

# %% [markdown]
# 1 - Introduction
# ------
#
# L'objectif de ce TP est de se familiariser avec la bilbiothèque spaCy et de comprendre les différentes analyses linguistiques possibles au niveau du mot et notamment le couplage texte - ontologie.
#
# N'hésitez pas à regarder régulièrement la documentation de ces librairies, des exemples d\'utilisation accompagnent généralement l\'explication de chaque fonction.
#
# - spaCy: https://spacy.io/api
# - NLTK: https://www.nltk.org/
# - WordCloud : https://amueller.github.io/word_cloud/
# - Counter : https://docs.python.org/3/library/collections.html
# - Python 3: https://docs.python.org/3/
# - Matplotilb: https://matplotlib.org/contents.html

# %%
# A exécuter si ces librairies ne sont pas sur vos machines
# !pip install --user spacy
# !pip install --user nltk
# !pip install --user wordcloud
# !python3 -m spacy download en_core_web_lg
# !python3 -m spacy download fr_core_news_sm
# !pip install --upgrade --user Pillow
# Out:
# Requirement already satisfied: spacy in /home/22012235/.local/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from spacy) (3.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from spacy) (21.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy) (59.6.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: numpy>=1.19.0 in /usr/lib/python3/dist-packages (from spacy) (1.21.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (2.5.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (4.66.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/22012235/.local/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/22012235/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /home/22012235/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/22012235/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/22012235/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/22012235/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.3)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/22012235/.local/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: nltk in /home/22012235/.local/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: tqdm in /home/22012235/.local/lib/python3.10/site-packages (from nltk) (4.66.1)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.0.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/lib/python3/dist-packages (from nltk) (2021.11.10)
# Requirement already satisfied: joblib in /home/22012235/.local/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: wordcloud in /home/22012235/.local/lib/python3.10/site-packages (1.9.2)
# Requirement already satisfied: pillow in /home/22012235/.local/lib/python3.10/site-packages (from wordcloud) (10.1.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/lib/python3/dist-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (from wordcloud) (3.5.1)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/22012235/.local/lib/python3.10/site-packages (from en-core-web-lg==3.7.1) (3.7.2)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (59.6.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (21.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (6.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.5.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.1)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.25.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: pydantic-core==2.14.5 in /home/22012235/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/22012235/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.8.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/22012235/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.6.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/22012235/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/22012235/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.0.3)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/22012235/.local/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 35.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /home/22012235/.local/lib/python3.10/site-packages (from fr-core-news-sm==3.7.0) (3.7.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.5.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.25.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.66.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (59.6.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/22012235/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: numpy>=1.19.0 in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.21.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/22012235/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /home/22012235/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/22012235/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.8.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/22012235/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/22012235/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.0.3)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/22012235/.local/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.16.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# Requirement already satisfied: Pillow in /home/22012235/.local/lib/python3.10/site-packages (10.1.0)

# %%
import spacy
import matplotlib.pyplot as plt
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

from wordcloud import WordCloud
from collections import Counter

# %% [markdown]
# 2 - Génération de nuages de mots avec une motivation linguistique
# -----

# %% [markdown]
# Importer le modèle de langue français.

# %%
# Pour impoter le moduèle : !python -m spacy download fr_core_news_sm
nlp = spacy.load("fr_core_news_sm")
# si vous voulez utiliser un autre modèle voici quelques liens intéressants
# Tous les modèles : https://spacy.io/models
# Anglais : https://spacy.io/models/en
# Italien : https://spacy.io/models/it

# %% [markdown]
# Lire l'un des deux textes proposés dans ce TP: sport.text ou sante.text.

# %%
text_path1 = "sport.txt"
text_path2 = "sante.txt"

text1 = ""
with open(text_path1, encoding='utf-8') as f:
    text1 = f.read()
    
text2 = ""
with open(text_path2, encoding='utf-8') as f:
    text2 = f.read()

# %% [markdown]
# Transformer le texte en un objet "nlp" de la bibliothèque spaCy qui vous permet d'accéder facilement aux objets textuels.

# %%
doc = nlp(text1)
doc2 = nlp(text2)

# %% [markdown]
# Fonction qui retourne la fréquence des 50 mots les plus fréquents dans un document.

# %%
freq_list = Counter(token.text for token in doc if "\n" not in token.text)
freq_list.most_common(50)
# Out:
# [(',', 51),
#  ('.', 40),
#  ('de', 35),
#  ('les', 19),
#  ('le', 19),
#  ('en', 14),
#  ('a', 13),
#  ('du', 12),
#  ('la', 12),
#  ('"', 12),
#  ('des', 11),
#  ('Bleus', 9),
#  ('dans', 9),
#  ("l'", 9),
#  ('se', 9),
#  ('et', 9),
#  ('pour', 8),
#  ('sur', 8),
#  ("d'", 7),
#  (':', 6),
#  ('une', 6),
#  ('monde', 6),
#  ('Lucas', 6),
#  ('France', 5),
#  ("L'", 5),
#  ('Hernandez', 5),
#  ('équipe', 5),
#  ('est', 5),
#  ('que', 5),
#  ('par', 5),
#  ('plus', 5),
#  ('un', 5),
#  ('qui', 5),
#  ('-', 4),
#  ('Australie', 4),
#  ('cette', 4),
#  ('Coupe', 4),
#  ('mois', 4),
#  ('La', 4),
#  ('après', 4),
#  ('but', 4),
#  ('blessure', 4),
#  ('Didier', 4),
#  ('Deschamps', 4),
#  ('pas', 4),
#  ('match', 3),
#  ('contre', 3),
#  ('victoire', 3),
#  ('(', 3),
#  (')', 3)]

# %% [markdown]
# [Q1] Programmer la suite d'instructions pour calculer les 40 mots les plus fréquents du fichier sante.txt.

# %%
# Insérer votre code ici
freq = Counter(token.text for token in doc2 if "\n" not in token.text)
freq.most_common(40)
# Out:
# [('de', 52),
#  (',', 50),
#  ('les', 39),
#  ('la', 35),
#  ('.', 35),
#  ('"', 22),
#  ('et', 21),
#  ('en', 20),
#  ('le', 20),
#  ('à', 19),
#  ('grippe', 17),
#  ('vaccination', 16),
#  ("l'", 16),
#  ('est', 16),
#  ('personnes', 12),
#  ('contre', 10),
#  ('une', 10),
#  ('a', 10),
#  ('des', 9),
#  ('?', 8),
#  ('(', 8),
#  (')', 8),
#  ("d'", 7),
#  ('faire', 7),
#  ('moins', 7),
#  ('Covid-19', 7),
#  ('sur', 6),
#  ('campagne', 6),
#  ('que', 6),
#  ('vacciner', 6),
#  ('octobre', 6),
#  ('par', 6),
#  ('du', 6),
#  ('vous', 6),
#  ('-', 6),
#  ('un', 6),
#  ('pas', 6),
#  ('plus', 5),
#  ('fragiles', 5),
#  ('deux', 5)]

# %% [markdown]
# Fonction qui génère un nuage de mots à partir d'une liste de mots ordonnés par leur fréquence.

# %%
def generate_wordcloud(freq_list):
    wordcloud = WordCloud(max_font_size=40).generate_from_frequencies(freq_list)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")

# %% [markdown]
# Génerer le nuage de mots

# %%
generate_wordcloud(freq_list)

# %% [markdown]
# [Q2] Générer le nuage de mots du fichier sante.txt.

# %%
# Insérer votre code ici
generate_wordcloud(freq)

# %% [markdown]
# Fonction qui ne compte que les fréquences des mots qui ne sont pas de mots vides. Rappel, un mot vide est un mot qui n'a pas de sens dénotatif particulier. Ce sont les déterminants, les prépositions etc.

# %%
freq_list = Counter(token.text for token in doc if not token.is_stop)

# %%
generate_wordcloud(freq_list)

# %% [markdown]
# [Q3] Générer le nuage de mots pour tous les mots sauf ceux qui sont un mot vide ou une ponctuation.

# %%
# insérer votre code ici

# %% [markdown]
# Fonction qui génère un nuage de lemmes, i.e. du radical d'un mot.

# %%
freq_list = Counter(token.lemma_ for token in doc if not token.is_stop and not token.is_punct)
generate_wordcloud(freq_list)

# %% [markdown]
# Fonction qui génère un nuage de lemmes nominaux, i.e. seulement les noms.

# %%
freq_list = Counter(token.lemma_ for token in doc if not token.is_stop and not token.is_punct and token.pos_ == "NOUN")
generate_wordcloud(freq_list)

# %% [markdown]
# [Q4] Générer le nuage de lemmes adjectivaux pour le texte sante.txt.

# %%
# Insérer votre code ici

# %% [markdown]
# Fonction qui génère un nuage d'entités nommées de type personne.

# %%
freq_list = Counter(token.text for token in doc if not token.is_stop and not token.is_punct and token.ent_type_ == "PER")
generate_wordcloud(freq_list)

# %% [markdown]
# [Q5] Générer le nuage d'entités nommées de type Localisation pour le texte sante.txt.

# %%
# insérer votre code ici

# %% [markdown]
# Fonction qui génère un nuage de mots qui sont compléments d'objet.

# %%
freq_list = Counter(token.lemma_ for token in doc if not token.is_stop and not token.is_punct and token.dep_ == "obj")
generate_wordcloud(freq_list)

# %% [markdown]
# [Q6] Générer le nuage des noms qui sont un sujet pour le texte sport.txt.

# %%
# insérer votre code ici

# %% [markdown]
# 3 - Liste des informations linguistiques et leur visualisation
# -----

# %% [markdown]
# Fonction qui montre toutes les informations linguistiques disponibles pour chacune des phrases d'un texte.

# %%
print('\n'.join(['\t'.join([str(token.i), token.text, token.lemma_, token.pos_, str(token.morph), str(token.head.i), token.dep_, token.ent_type_, token.ent_iob_]) for sent in doc.sents
                 for token in sent]))
# Out:
# 0	France	France	PROPN	Gender=Fem|Number=Sing	0	ROOT	LOC	B
# 1	-	-	PROPN		1	ROOT		O
# 2	Australie	Australie	PROPN		2	ROOT	LOC	B
# 3	:	:	PUNCT		2	punct		O
# 4	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	6	det		O
# 5	première	premier	ADJ	Gender=Fem|NumType=Ord|Number=Sing	6	amod		O
# 6	demi-heure	demi-heure	NOUN	Gender=Fem|Number=Sing	2	nmod		O
# 7	fondatrice	fondateur	ADJ	Number=Sing	6	amod		O
# 8	pour	pour	ADP		10	case		O
# 9	les	le	DET	Definite=Def|Number=Plur|PronType=Art	10	det		O
# 10	Bleus	bleu	NOUN	Gender=Masc|Number=Plur	6	nmod	ORG	B
# 11	dans	dans	ADP		13	case		O
# 12	cette	ce	DET	Gender=Fem|Number=Sing|PronType=Dem	13	det		O
# 13	Coupe	coupe	NOUN	Gender=Fem|Number=Sing	13	ROOT	MISC	B
# 14	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	15	case	MISC	I
# 15	monde	monde	NOUN	Gender=Masc|Number=Sing	13	nmod	MISC	I
# 16	2022	2022	NUM	NumType=Card	13	nummod	MISC	I
# 17	?	?	PUNCT		20	punct		O
# 18
#
#
#
# 	SPACE		20	dep		O
# 19	L'	le	DET	Definite=Def|Number=Sing|PronType=Art	20	det		O
# 20	entame	entame	NOUN	Gender=Fem|Number=Sing	20	ROOT		O
# 21	de	de	ADP		22	case		O
# 22	match	match	NOUN	Gender=Masc|Number=Sing	20	nmod		O
# 23	des	de	ADP	Definite=Def|Number=Plur|PronType=Art	24	case		O
# 24	Bleus	Bleus	PROPN		22	nmod	ORG	B
# 25	,	,	PUNCT		20	punct		O
# 26	ratée	rater	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	20	acl		O
# 27	mardi	mardi	NOUN	Gender=Masc|Number=Sing	26	obl:mod		O
# 28	contre	contre	ADP		30	case		O
# 29	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	30	det		O
# 30	Australie	australie	NOUN	Gender=Fem|Number=Sing	26	obl:arg	LOC	B
# 31	malgré	malgré	ADP		33	case		O
# 32	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	33	det		O
# 33	victoire	victoire	NOUN	Gender=Fem|Number=Sing	30	nmod		O
# 34	finale	final	ADJ	Gender=Fem|Number=Sing	33	amod		O
# 35	(	(	PUNCT		33	punct		O
# 36	4	4	NUM	NumType=Card	33	appos		O
# 37	-	-	NOUN	NumType=Card	33	nmod		O
# 38	1	1	NOUN	NumType=Card	33	nmod		O
# 39	)	)	PUNCT		26	punct		O
# 40	,	,	PUNCT		20	punct		O
# 41	pourrait	pouvoir	VERB	Mood=Cnd|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	20	acl		O
# 42	servir	servir	ADJ	Number=Sing	41	xcomp		O
# 43	de	de	ADP		44	case		O
# 44	déclic	déclic	NOUN	Gender=Masc|Number=Sing	42	obl:arg		O
# 45	pour	pour	ADP		47	case		O
# 46	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	47	det		O
# 47	reste	reste	NOUN	Gender=Masc|Number=Sing	42	obl:mod		O
# 48	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	49	case		O
# 49	Mondial	Mondial	PROPN		47	nmod	MISC	B
# 50	.	.	PUNCT		20	punct		O
# 51
#
#
#
# 	SPACE		53	dep		O
# 52	L'	le	DET	Definite=Def|Number=Sing|PronType=Art	53	det		O
# 53	incompréhension	incompréhension	NOUN	Gender=Fem|Number=Sing	53	ROOT		O
# 54	d'	de	ADP		55	case		O
# 55	Hugo	Hugo	PROPN	Gender=Fem|Number=Sing	53	nmod	PER	B
# 56	Lloris	Lloris	PROPN	Gender=Masc|Number=Sing	55	flat:name	PER	I
# 57	.	.	PUNCT		53	punct		O
# 58	Le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	59	det		O
# 59	regard	regard	NOUN	Gender=Masc|Number=Sing	59	ROOT		O
# 60	noir	noir	ADJ	Gender=Masc|Number=Sing	59	amod		O
# 61	de	de	ADP		62	case		O
# 62	Benjamin	Benjamin	PROPN	Gender=Masc|Number=Sing	59	nmod	PER	B
# 63	Pavard	Pavard	PROPN	Gender=Masc|Number=Sing	62	nmod	PER	I
# 64	.	.	PUNCT		59	punct		O
# 65	L'	le	DET	Definite=Def|Number=Sing|PronType=Art	66	det		O
# 66	inquiétude	inquiétude	NOUN	Gender=Fem|Number=Sing	66	ROOT		O
# 67	autour	autour	ADV		66	dep		O
# 68	de	de	ADP		69	case		O
# 69	Lucas	luca	NOUN	Gender=Masc|Number=Plur	67	dep	PER	B
# 70	Hernandez	Hernandez	PROPN		69	nmod	PER	I
# 71	.	.	PUNCT		66	punct		O
# 72	L'	le	DET	Definite=Def|Number=Sing|PronType=Art	73	det		O
# 73	équipe	équipe	NOUN	Gender=Fem|Number=Sing	78	nsubj		O
# 74	de	de	ADP		75	case	LOC	B
# 75	France	France	PROPN	Gender=Fem|Number=Sing	73	nmod	LOC	I
# 76	n'	n'	ADV	Polarity=Neg	78	advmod		O
# 77	est	être	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	78	aux:pass		O
# 78	entrée	entrer	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass	78	ROOT		O
# 79	que	que	SCONJ		82	advmod		O
# 80	depuis	depuis	ADP		82	case		O
# 81	neuf	neuf	NUM	Gender=Masc|NumType=Card	82	amod		O
# 82	minutes	minute	NOUN	Gender=Fem|Number=Plur	78	ccomp		O
# 83	dans	dans	ADP		85	case		O
# 84	sa	son	DET	Gender=Fem|Number=Sing|Poss=Yes	85	det		O
# 85	Coupe	coupe	NOUN	Gender=Fem|Number=Sing	78	obl:mod	MISC	B
# 86	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	87	case	MISC	I
# 87	monde	monde	NOUN	Gender=Masc|Number=Sing	85	nmod	MISC	I
# 88	2022	2022	NUM	NumType=Card	87	nummod	MISC	I
# 89	,	,	PUNCT		78	punct		O
# 90	mardi	mardi	NOUN	Gender=Masc|Number=Sing	78	obl:mod		O
# 91	22	22	NUM	NumType=Card	90	nmod		O
# 92	novembre	novembre	NOUN	Gender=Masc|Number=Sing	91	flat:name		O
# 93	,	,	PUNCT		78	punct		O
# 94	qu'	qu'	PRON	PronType=Rel	97	iobj		O
# 95	elle	lui	PRON	Gender=Fem|Number=Sing|Person=3	97	nsubj		O
# 96	se	se	PRON	Person=3|Reflex=Yes	97	expl:comp		O
# 97	trouve	trouve	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	78	ccomp		O
# 98	déjà	déjà	ADV		97	advmod		O
# 99	en	en	ADP		100	case		O
# 100	pleine	pleine	NOUN	Gender=Fem|Number=Sing	97	obl:mod		O
# 101	tourmente	tourment	ADJ	Gender=Fem|Number=Sing	100	amod		O
# 102	.	.	PUNCT		78	punct		O
# 103	Menés	mener	VERB	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	110	advcl	LOC	B
# 104	par	par	ADP		106	case		O
# 105	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	106	det		O
# 106	Australie	Australie	PROPN	Number=Sing	103	obl:agent	LOC	B
# 107	,	,	PUNCT		110	punct		O
# 108	les	le	DET	Definite=Def|Number=Plur|PronType=Art	109	det		O
# 109	Bleus	bleu	NOUN	Gender=Fem|Number=Plur	110	nsubj	ORG	B
# 110	voient	voir	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	110	ROOT		O
# 111	les	le	DET	Definite=Def|Number=Plur|PronType=Art	112	det		O
# 112	spectres	spectre	NOUN	Gender=Masc|Number=Plur	110	obj		O
# 113	des	de	ADP	Definite=Def|Number=Plur|PronType=Art	115	case		O
# 114	derniers	dernier	ADJ	Gender=Masc|NumType=Ord|Number=Plur	115	amod		O
# 115	mois	mois	NOUN	Gender=Masc|Number=Plur	112	nmod		O
# 116	resurgir	resurgir	VERB	VerbForm=Inf	115	amod		O
# 117	soudainement	soudainement	ADV		116	advmod		O
# 118	:	:	PUNCT		120	punct		O
# 119	les	le	DET	Definite=Def|Number=Plur|PronType=Art	120	det		O
# 120	blessures	blessure	NOUN	Gender=Fem|Number=Plur	115	conj		O
# 121	,	,	PUNCT		124	punct		O
# 122	les	le	DET	Definite=Def|Number=Plur|PronType=Art	124	det		O
# 123	mauvais	mauvais	ADJ	Gender=Masc|Number=Plur	124	amod		O
# 124	résultats	résultat	NOUN	Gender=Masc|Number=Plur	115	conj		O
# 125	,	,	PUNCT		127	punct		O
# 126	les	le	DET	Definite=Def|Number=Plur|PronType=Art	127	det		O
# 127	doutes	doute	NOUN	Gender=Masc|Number=Plur	115	conj		O
# 128	.	.	PUNCT		110	punct		O
# 129	La	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	130	det	LOC	B
# 130	France	France	PROPN	Gender=Fem|Number=Sing	132	nsubj	LOC	I
# 131	se	se	PRON	Person=3|Reflex=Yes	132	expl:comp		O
# 132	prend	prendre	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	132	ROOT		O
# 133	de	de	ADP		135	case		O
# 134	plein	plein	ADJ	Gender=Masc|Number=Sing	135	amod		O
# 135	fouet	fouet	NOUN	Gender=Masc|Number=Sing	132	obl:arg		O
# 136	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	137	det		O
# 137	mur	mur	NOUN	Gender=Masc|Number=Sing	132	obj		O
# 138	sur	sur	ADP		139	case		O
# 139	lequel	lequel	PRON	Gender=Masc|Number=Sing|PronType=Rel	132	obl:arg		O
# 140	se	se	PRON	Person=3|Reflex=Yes	139	advmod		O
# 141	brisent	briser	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	140	fixed		O
# 142	les	le	DET	Definite=Def|Number=Plur|PronType=Art	143	det		O
# 143	ambitions	ambition	NOUN	Gender=Fem|Number=Plur	140	nsubj		O
# 144	des	de	ADP	Definite=Def|Number=Plur|PronType=Art	145	case		O
# 145	champions	champion	NOUN	Gender=Masc|Number=Plur	143	nmod		O
# 146	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	147	case		O
# 147	monde	monde	NOUN	Gender=Masc|Number=Sing	145	nmod		O
# 148	en	en	ADP		149	case		O
# 149	titre	titre	NOUN	Gender=Masc|Number=Sing	147	nmod		O
# 150	lors	lors	ADV		140	fixed		O
# 151	des	un	DET	Definite=Ind|Number=Plur|PronType=Art	153	case		O
# 152	dernières	dernier	ADJ	Gender=Masc|Number=Plur	153	amod		O
# 153	éditions	édition	NOUN	Gender=Fem|Number=Plur	150	obl:arg		O
# 154	.	.	PUNCT		132	punct		O
# 155
#
#
#
# 	SPACE		170	dep		O
# 156	Devancés	Devancés	PROPN	Gender=Masc|Number=Sing	155	flat:name	LOC	B
# 157	au	au	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	158	case		O
# 158	tableau	tableau	NOUN	Gender=Masc|Number=Sing	170	obl:mod		O
# 159	d'	de	ADP		160	case		O
# 160	affichage	affichage	NOUN	Gender=Masc|Number=Sing	158	nmod		O
# 161	après	après	ADP		163	case		O
# 162	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	163	det		O
# 163	but	but	NOUN	Gender=Masc|Number=Sing	158	nmod		O
# 164	de	de	ADP		165	case		O
# 165	Craig	craig	VERB	Tense=Pres|VerbForm=Part	163	nmod	PER	B
# 166	Goodwin	Goodwin	PROPN		165	flat:name		O
# 167	,	,	PUNCT		170	punct		O
# 168	les	le	DET	Definite=Def|Number=Plur|PronType=Art	169	det		O
# 169	Bleus	bleu	NOUN	Gender=Masc|Number=Plur	170	nsubj	ORG	B
# 170	doivent	devoir	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	170	ROOT		O
# 171	en	en	ADP		170	advmod		O
# 172	plus	plus	ADV		171	fixed		O
# 173	digérer	digérer	VERB	VerbForm=Inf	170	xcomp		O
# 174	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	175	det		O
# 175	blessure	blessure	NOUN	Gender=Fem|Number=Sing	173	obj		O
# 176	de	de	ADP		177	case		O
# 177	Lucas	luca	NOUN	Gender=Masc|Number=Plur	175	nmod	PER	B
# 178	Hernandez	Hernandez	PROPN		175	nmod	PER	I
# 179	.	.	PUNCT		170	punct		O
# 180	"	"	PUNCT		182	punct		O
# 181	Je	je	PRON	Number=Sing|Person=1	182	nsubj		O
# 182	pense	pense	VERB	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	182	ROOT		O
# 183	que	que	SCONJ		185	mark		O
# 184	ça	cela	PRON	Gender=Masc|Number=Sing|Person=3	185	nsubj		O
# 185	va	aller	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	182	ccomp		O
# 186	être	être	AUX	VerbForm=Inf	189	cop		O
# 187	malheureusement	malheureusement	ADV		188	advmod		O
# 188	assez	assez	ADV		189	advmod		O
# 189	grave	grave	ADJ	Number=Sing	185	xcomp		O
# 190	"	"	PUNCT		185	punct		O
# 191	,	,	PUNCT		193	punct		O
# 192	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	193	aux:tense		O
# 193	confirmé	confirmer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	182	parataxis		O
# 194	Didier	Didier	PROPN	Gender=Masc|Number=Sing	193	nsubj	PER	B
# 195	Deschamps	Deschamps	X		194	flat:name	PER	I
# 196	en	en	ADP		197	case		O
# 197	conférence	conférence	NOUN	Gender=Fem|Number=Sing	193	obl:mod		O
# 198	de	de	ADP		199	case		O
# 199	presse	presse	NOUN	Gender=Fem|Number=Sing	197	nmod		O
# 200	après	après	ADP		202	case		O
# 201	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	202	det		O
# 202	match	match	NOUN	Gender=Masc|Number=Sing	193	obl:mod		O
# 203	.	.	PUNCT		182	punct		O
# 204	Le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	205	det		O
# 205	choix	choix	NOUN	Gender=Masc|Number=Sing	246	nsubj		O
# 206	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	207	case		O
# 207	sélectionneur	sélectionneur	NOUN	Gender=Masc|Number=Sing	205	nmod		O
# 208	de	de	ADP		211	mark		O
# 209	ne	ne	ADV	Polarity=Neg	211	advmod		O
# 210	pas	pas	ADV	Polarity=Neg	211	advmod		O
# 211	retenir	retenir	VERB	VerbForm=Inf	207	acl		O
# 212	un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	213	det		O
# 213	latéral	latéral	NOUN	Gender=Masc|Number=Sing	211	obj		O
# 214	de	de	ADP		215	case		O
# 215	plus	plus	ADV		213	nmod		O
# 216	et	et	CCONJ		219	cc		O
# 217	d'	de	ADP		219	mark		O
# 218	avoir	avoir	AUX	VerbForm=Inf	219	aux:tense		O
# 219	convoqué	convoquer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	211	conj		O
# 220	trois	trois	NUM	NumType=Card	221	nummod		O
# 221	défenseurs	défenseur	NOUN	Gender=Masc|Number=Plur	219	obj		O
# 222	centraux	central	ADJ	Gender=Masc|Number=Plur	221	amod		O
# 223	(	(	PUNCT		221	punct		O
# 224	Pavard	pavard	NOUN	Gender=Masc|Number=Sing	221	appos		O
# 225	,	,	PUNCT		221	punct		O
# 226	Lucas	luca	NOUN	Gender=Masc	221	appos	PER	B
# 227	Hernandez	Hernandez	PROPN		226	nmod	PER	I
# 228	et	et	CCONJ		229	cc		O
# 229	Jules	Jules	PROPN	Gender=Fem|Number=Sing	226	conj	PER	B
# 230	Koundé	Koundé	PROPN		229	flat:name	PER	I
# 231	)	)	PUNCT		221	punct		O
# 232	pour	pour	ADP		233	mark		O
# 233	jouer	jouer	VERB	VerbForm=Inf	211	advcl		O
# 234	sur	sur	ADP		236	case		O
# 235	les	le	DET	Definite=Def|Number=Plur|PronType=Art	236	det		O
# 236	côtés	côté	NOUN	Gender=Fem|Number=Plur	233	obl:mod		O
# 237	exacerbe	exacerbe	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	236	amod		O
# 238	les	le	DET	Definite=Def|Number=Plur|PronType=Art	239	det		O
# 239	interrogations	interrogation	NOUN	Gender=Fem|Number=Plur	237	obj		O
# 240	dans	dans	ADP		242	case		O
# 241	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	242	det		O
# 242	stade	stade	NOUN	Gender=Masc|Number=Sing	233	obl:mod	LOC	B
# 243	Al	al	NOUN	Gender=Masc|Number=Sing	242	nmod	LOC	I
# 244	-	-	NOUN	NumType=Card	242	nmod	LOC	I
# 245	Janoub	Janoub	PROPN		242	nmod	LOC	I
# 246	.	.	PUNCT		246	ROOT		O
# 247	Tout	tout	ADJ	Gender=Masc|Number=Sing	249	nsubj		O
# 248	se	se	PRON	Person=3|Reflex=Yes	249	expl:comp		O
# 249	bouscule	bouscule	VERB	VerbForm=Inf	249	ROOT		O
# 250	.	.	PUNCT		249	punct		O
# 251
#
# 	SPACE		250	dep		O
# 252	"	"	PUNCT		258	punct		O
# 253	La	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	254	det		O
# 254	blessure	blessure	NOUN	Gender=Fem|Number=Sing	258	nsubj		O
# 255	de	de	ADP		256	case		O
# 256	Lucas	luca	NOUN		254	nmod	MISC	B
# 257	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	258	aux:tense		O
# 258	forcément	forcémer	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin	259	dep		O
# 259	pesé	peser	ADJ	Gender=Masc|Number=Sing	249	xcomp		O
# 260	"	"	PUNCT		259	punct		O
# 261
#
#
#
# 	SPACE		249	dep		O
# 262	"	"	PUNCT		249	punct		O
# 263	La	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	264	det		O
# 264	blessure	blessure	NOUN	Gender=Fem|Number=Sing	268	nsubj		O
# 265	de	de	ADP		266	case		O
# 266	Lucas	luca	NOUN		264	nmod	MISC	B
# 267	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	268	aux:tense		O
# 268	forcément	forcémer	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin	269	advmod		O
# 269	pesé	peser	ADJ	Number=Plur	249	conj		O
# 270	psychologiquement	psychologiquement	ADV		269	advmod		O
# 271	.	.	PUNCT		249	punct		O
# 272	Et	et	CCONJ		275	cc		O
# 273	d'	de	ADP		275	mark		O
# 274	être	être	AUX	VerbForm=Inf	275	aux:pass		O
# 275	menés	mener	VERB	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part|Voice=Pass	275	ROOT		O
# 276	,	,	PUNCT		282	punct		O
# 277	ce	ce	PRON	Number=Sing|Person=3	282	nsubj		O
# 278	n'	n'	ADV	Polarity=Neg	282	advmod		O
# 279	est	être	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	282	cop		O
# 280	jamais	jamais	ADV	Polarity=Neg	282	advmod		O
# 281	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	282	det		O
# 282	idéal	idéal	PRON	Gender=Masc|Number=Sing	275	conj		O
# 283	,	,	PUNCT		275	punct		O
# 284	mais	mais	CCONJ		287	cc		O
# 285	il	il	PRON	Number=Sing|Person=3	287	expl:subj		O
# 286	y	y	PRON	Person=3	287	expl:comp		O
# 287	a	avoir	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	275	conj		O
# 288	de	de	ADP		290	case		O
# 289	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	290	det		O
# 290	force	force	NOUN	Gender=Fem|Number=Sing	287	obj		O
# 291	et	et	CCONJ		293	cc		O
# 292	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	293	case		O
# 293	caractère	caractère	NOUN	Gender=Masc|Number=Sing	290	conj		O
# 294	dans	dans	ADP		296	case		O
# 295	ce	ce	DET	Gender=Masc|Number=Sing|PronType=Dem	296	det		O
# 296	groupe	groupe	NOUN	Gender=Masc|Number=Sing	290	nmod		O
# 297	,	,	PUNCT		290	punct		O
# 298	avec	avec	ADP		300	case		O
# 299	des	un	DET	Definite=Ind|Number=Plur|PronType=Art	300	det		O
# 300	joueurs	joueur	NOUN	Gender=Masc|Number=Plur	287	dep		O
# 301	expérimentés	expérimenté	NOUN	Gender=Masc|Number=Plur	300	amod		O
# 302	"	"	PUNCT		300	punct		O
# 303	,	,	PUNCT		305	punct		O
# 304	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	305	aux:tense		O
# 305	expliqué	expliquer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	275	conj		O
# 306	Didier	Didier	PROPN	Gender=Masc|Number=Sing	305	nsubj	PER	B
# 307	Deschamps	Deschamps	PROPN		306	flat:name	PER	I
# 308	.	.	PUNCT		275	punct		O
# 309	Les	le	DET	Definite=Def|Number=Plur|PronType=Art	310	det		O
# 310	minutes	minute	NOUN	Gender=Fem|Number=Plur	310	ROOT		O
# 311	qui	qui	PRON	PronType=Rel	312	nsubj		O
# 312	suivent	suivre	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	310	acl:relcl		O
# 313	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	314	det		O
# 314	but	but	NOUN	Gender=Masc|Number=Sing	317	nsubj		O
# 315	australien	australien	ADJ	Gender=Masc|Number=Sing	314	amod		O
# 316	sont	être	AUX	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	317	cop		O
# 317	difficiles	difficile	ADJ	Number=Plur	312	obj		O
# 318	:	:	PUNCT		317	punct		O
# 319	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	321	det		O
# 320	mauvaise	mauvais	ADJ	Gender=Fem|Number=Sing	321	amod		O
# 321	passe	passe	NOUN	Gender=Fem|Number=Sing	312	obj		O
# 322	de	de	ADP		323	case		O
# 323	Rabiot	Rabiot	PROPN		321	nmod	PER	B
# 324	,	,	PUNCT		321	punct		O
# 325	puis	puis	CCONJ		327	cc		O
# 326	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	327	det		O
# 327	autre	autre	ADJ	Number=Sing	321	conj		O
# 328	de	de	ADP		329	case		O
# 329	Theo	Theo	PROPN	Gender=Masc|Number=Sing	327	nmod	PER	B
# 330	Hernandez	Hernandez	PROPN		329	flat:name	PER	I
# 331	qui	qui	PRON	PronType=Rel	332	nsubj		O
# 332	amène	amener	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	327	acl:relcl		O
# 333	un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	334	det		O
# 334	missile	missile	NOUN	Gender=Masc|Number=Sing	332	obj		O
# 335	de	de	ADP		336	case		O
# 336	Mitchell	mitchell	NOUN	Gender=Masc|Number=Plur	334	nmod	MISC	B
# 337	Duke	Duke	PROPN	Gender=Masc|Number=Sing	327	flat:name	MISC	I
# 338	pour	pour	ADP		339	mark		O
# 339	faire	faire	VERB	VerbForm=Inf	342	aux:tense		O
# 340	nouvelle	nouveau	ADJ	Gender=Fem|Number=Sing	341	amod		O
# 341	fois	fois	NOUN	Gender=Fem|Number=Sing	342	obl:mod		O
# 342	trembler	trembler	VERB	VerbForm=Inf	312	xcomp		O
# 343	Lloris	Lloris	PROPN	Gender=Masc|Number=Sing	342	obj		O
# 344	.	.	PUNCT		310	punct		O
# 345	L'	le	DET	Definite=Def|Number=Sing|PronType=Art	346	det		O
# 346	édifice	édifice	NOUN	Gender=Fem|Number=Sing	346	ROOT		O
# 347	tremble	trembl	ADJ	Number=Sing	346	amod		O
# 348	.	.	PUNCT		346	punct		O
# 349	Malade	malade	NOUN	Gender=Fem|Number=Sing	365	advcl		O
# 350	depuis	depuis	ADP		352	case		O
# 351	plusieurs	plusieurs	DET	Number=Plur	352	det		O
# 352	mois	mois	NOUN	Gender=Masc|Number=Plur	349	nmod		O
# 353	et	et	CCONJ		355	cc		O
# 354	en	en	ADP		355	case		O
# 355	partie	partie	NOUN	Gender=Fem|Number=Sing	352	conj		O
# 356	composée	composer	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	352	acl		O
# 357	de	de	ADP		358	case		O
# 358	joueurs	joueur	NOUN	Gender=Masc|Number=Plur	356	obl:mod		O
# 359	inexpérimentés	inexpérimenté	ADJ	Gender=Fem|Number=Plur	358	amod		O
# 360	,	,	PUNCT		365	punct		O
# 361	cette	ce	DET	Gender=Fem|Number=Sing|PronType=Dem	362	det		O
# 362	équipe	équipe	NOUN	Gender=Fem|Number=Sing	365	nsubj		O
# 363	de	de	ADP		364	case	LOC	B
# 364	France	France	PROPN	Gender=Fem|Number=Sing	362	nmod	LOC	I
# 365	semble	semble	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	365	ROOT		O
# 366	engagée	engager	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass	365	obj		O
# 367	sur	sur	ADP		370	case		O
# 368	de	de	DET	Definite=Ind|Number=Plur|PronType=Art	370	det		O
# 369	mauvais	mauvais	ADJ	Number=Plur	368	fixed		O
# 370	rails	rail	NOUN	Gender=Masc|Number=Plur	366	obl:arg		O
# 371	.	.	PUNCT		365	punct		O
# 372
#
#
#
# 	SPACE		383	dep		O
# 373	Mais	mais	CCONJ		383	cc		O
# 374	,	,	PUNCT		383	punct		O
# 375	dans	dans	ADP		377	case		O
# 376	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	377	det		O
# 377	dur	dur	NOUN	Gender=Masc|Number=Sing	383	obl:mod		O
# 378	,	,	PUNCT		383	punct		O
# 379	Didier	Didier	PROPN	Gender=Masc|Number=Sing	383	nsubj	PER	B
# 380	Deschamps	Deschamps	PROPN		379	flat:name	PER	I
# 381	s'	se	PRON	Person=3|Reflex=Yes	383	expl:comp		O
# 382	est	être	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	383	aux:tense		O
# 383	trouvé	trouver	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	383	ROOT		O
# 384	des	un	DET	Definite=Ind|Number=Plur|PronType=Art	385	det		O
# 385	leaders	leader	NOUN	Gender=Masc|Number=Plur	383	obj		O
# 386	capables	capable	ADJ	Number=Plur	385	amod		O
# 387	de	de	ADP		388	mark		O
# 388	répondre	répondre	VERB	VerbForm=Inf	385	acl		O
# 389	sur	sur	ADP		391	case		O
# 390	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	391	det		O
# 391	terrain	terrain	NOUN	Gender=Masc|Number=Sing	388	obl:arg		O
# 392	.	.	PUNCT		383	punct		O
# 393	Dayot	Dayot	PROPN	Gender=Fem|Number=Sing	393	ROOT		O
# 394	Upamecano	Upamecano	PROPN		394	ROOT		O
# 395	d'	de	ADP		394	advmod		O
# 396	abord	abord	ADV		395	fixed		O
# 397	,	,	PUNCT		394	punct		O
# 398	lui	lui	PRON	Gender=Masc|Number=Sing|Person=3|PronType=Prs	394	dep		O
# 399	qui	qui	PRON	PronType=Rel	401	nsubj		O
# 400	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	401	aux:tense		O
# 401	livré	livrer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	398	acl:relcl		O
# 402	sa	son	DET	Gender=Fem|Number=Sing|Poss=Yes	404	det		O
# 403	meilleure	meilleur	ADJ	Gender=Fem|Number=Sing	404	amod		O
# 404	prestation	prestation	NOUN	Gender=Fem|Number=Sing	401	obj		O
# 405	en	en	ADP		406	case		O
# 406	bleu	bleu	NOUN	Gender=Fem|Number=Sing	401	obl:mod		O
# 407	:	:	PUNCT		394	punct		O
# 408	"	"	PUNCT		394	punct		O
# 409	Il	il	PRON	Gender=Masc|Number=Sing|Person=3	411	expl:subj		O
# 410	nous	nous	PRON	Number=Plur|Person=1	411	iobj		O
# 411	fallait	falloir	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	411	ROOT		O
# 412	un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	418	advmod		O
# 413	peu	peu	ADV		412	fixed		O
# 414	de	de	ADP		415	case		O
# 415	temps	temps	NOUN	Gender=Masc|Number=Plur	413	nmod		O
# 416	pour	pour	ADP		418	mark		O
# 417	se	se	PRON	Person=3|Reflex=Yes	418	expl:comp		O
# 418	mettre	mettre	VERB	VerbForm=Inf	411	xcomp		O
# 419	dedans	dedans	PRON		418	xcomp		O
# 420	,	,	PUNCT		422	punct		O
# 421	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	422	aux:tense		O
# 422	consenti	consentir	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	418	conj		O
# 423	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	424	det		O
# 424	défenseur	défenseur	NOUN	Gender=Masc|Number=Sing	422	obj		O
# 425	.	.	PUNCT		411	punct		O
# 426	Mais	mais	CCONJ		431	cc		O
# 427	après	après	ADP		431	mark		O
# 428	on	on	PRON	Number=Sing|Person=3	431	nsubj		O
# 429	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	431	aux:tense		O
# 430	bien	bien	ADV		431	advmod		O
# 431	réagi	réagi	ADJ	Number=Plur	431	ROOT		O
# 432	"	"	PUNCT		431	punct		O
# 433	.	.	PUNCT		431	punct		O
# 434	Adrien	Adrien	PROPN	Gender=Masc|Number=Sing	434	ROOT	PER	B
# 435	Rabiot	Rabiot	PROPN		434	flat:name	PER	I
# 436	,	,	PUNCT		434	punct		O
# 437	surtout	surtout	ADV		434	advmod		O
# 438	,	,	PUNCT		439	punct		O
# 439	buteur	buteur	NOUN	Gender=Masc|Number=Sing	434	conj		O
# 440	puis	puis	CCONJ		441	cc		O
# 441	passeur	passeur	ADJ	Gender=Masc|Number=Sing	434	conj		O
# 442	décisif	décisif	ADJ	Gender=Masc|Number=Sing	434	amod		O
# 443	.	.	PUNCT		434	punct		O
# 444	Un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	446	det		O
# 445	nouveau	nouveau	ADJ	Gender=Masc|Number=Sing	446	amod		O
# 446	phare	phare	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	446	ROOT		O
# 447	capable	capable	ADJ	Number=Sing	446	xcomp		O
# 448	de	de	ADP		449	mark		O
# 449	guider	guider	VERB	VerbForm=Inf	447	xcomp		O
# 450	les	le	DET	Definite=Def|Number=Plur|PronType=Art	451	det		O
# 451	Bleus	bleu	NOUN	Gender=Masc|Number=Plur	449	obj	ORG	B
# 452	quand	quand	SCONJ		455	mark		O
# 453	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	454	det		O
# 454	tempête	tempête	NOUN	Gender=Fem|Number=Sing	455	nsubj		O
# 455	emportait	emporter	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	446	advcl		O
# 456	tout	tout	ADV		459	advmod		O
# 457	sur	sur	ADP		459	case		O
# 458	son	son	DET	Number=Sing|Poss=Yes	459	det		O
# 459	passage	passage	NOUN	Gender=Masc|Number=Sing	455	obj		O
# 460	.	.	PUNCT		446	punct		O
# 461
#
#
#
# 	SPACE		471	dep		O
# 462	Vendredi	vendredi	NOUN	Gender=Masc|Number=Sing	471	obl:mod	LOC	B
# 463	dernier	dernier	ADJ	Gender=Masc|NumType=Ord|Number=Sing	462	amod		O
# 464	,	,	PUNCT		471	punct		O
# 465	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	466	det		O
# 466	milieu	milieu	NOUN	Gender=Masc|Number=Sing	471	nsubj		O
# 467	de	de	ADP		469	case		O
# 468	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	469	det		O
# 469	Juventus	Juventus	PROPN	Gender=Fem|Number=Sing	466	nmod	MISC	B
# 470	se	se	PRON	Person=3|Reflex=Yes	471	expl:comp		O
# 471	décrivait	décrire	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	471	ROOT		O
# 472	ainsi	ainsi	ADV		471	advmod		O
# 473	:	:	PUNCT		471	punct		O
# 474	"	"	PUNCT		471	punct		O
# 475	Quand	quand	SCONJ		477	mark		O
# 476	je	je	PRON	Number=Sing|Person=1	477	nsubj		O
# 477	suis	être	AUX	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	483	advcl		O
# 478	sur	sur	ADP		480	case		O
# 479	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	480	det		O
# 480	terrain	terrain	NOUN	Gender=Masc|Number=Sing	477	obl:mod		O
# 481	,	,	PUNCT		483	punct		O
# 482	j'	je	PRON	Number=Sing|Person=1	483	nsubj		O
# 483	ai	avoir	VERB	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	471	advcl		O
# 484	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	485	det		O
# 485	personnalité	personnalité	NOUN	Gender=Fem|Number=Sing	483	obj		O
# 486	assez	assez	ADV		487	advmod		O
# 487	différente	différente	NOUN	Gender=Masc|Number=Sing	485	nmod		O
# 488	de	de	ADP		489	case		O
# 489	celle	celui	PRON	Gender=Fem|Number=Sing|PronType=Dem	487	nmod		O
# 490	à	à	ADP		492	case		O
# 491	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	492	det		O
# 492	extérieur	extérieur	NOUN	Gender=Masc|Number=Sing	489	nmod		O
# 493	.	.	PUNCT		471	punct		O
# 494	Je	je	PRON	Number=Sing|Person=1	497	nsubj		O
# 495	suis	être	AUX	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	497	cop		O
# 496	vraiment	vraiment	ADV		497	advmod		O
# 497	là	là	ADV		497	ROOT		O
# 498	pour	pour	ADP		499	mark		O
# 499	aider	aider	VERB	VerbForm=Inf	497	advcl		O
# 500	mes	mon	DET	Number=Plur|Poss=Yes	501	det		O
# 501	coéquipiers	coéquipier	NOUN	Gender=Masc|Number=Plur	499	obj		O
# 502	et	et	CCONJ		504	cc		O
# 503	les	le	PRON	Number=Plur|Person=3	504	obj		O
# 504	tirer	tirer	VERB	VerbForm=Inf	499	conj		O
# 505	au	au	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	506	case		O
# 506	maximum	maximum	NOUN	Gender=Masc|Number=Sing	504	obl:arg		O
# 507	,	,	PUNCT		499	punct		O
# 508	sans	sans	ADP		510	mark		O
# 509	même	même	ADV		510	advmod		O
# 510	regarder	regarder	VERB	VerbForm=Inf	499	advcl		O
# 511	qui	qui	PRON	PronType=Rel	510	obj		O
# 512	est	être	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	511	dep		O
# 513	sur	sur	ADP		515	case		O
# 514	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	515	det		O
# 515	terrain	terrain	NOUN	Gender=Masc|Number=Sing	511	nmod		O
# 516	ou	ou	CCONJ		517	cc		O
# 517	pas	pas	ADV	Polarity=Neg	515	conj		O
# 518	,	,	PUNCT		510	punct		O
# 519	qui	qui	PRON	PronType=Rel	520	nsubj		O
# 520	a	avoir	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	510	acl:relcl		O
# 521	plus	plus	ADV		520	advmod		O
# 522	de	de	ADP		523	det		O
# 523	sélections	sélection	NOUN	Gender=Fem|Number=Plur	520	obj		O
# 524	.	.	PUNCT		497	punct		O
# 525	C'	ce	PRON	Number=Sing|Person=3	527	expl:subj		O
# 526	est	être	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	527	aux:pass		O
# 527	naturel	naturel	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass	527	ROOT		O
# 528	chez	chez	ADP		529	case		O
# 529	moi	moi	PRON	Number=Sing|Person=1|PronType=Prs	527	obl:mod		O
# 530	,	,	PUNCT		527	punct		O
# 531	parce	parce	SCONJ		534	mark		O
# 532	que	que	SCONJ		531	fixed		O
# 533	j'	je	PRON	Number=Sing|Person=1	534	nsubj		O
# 534	ai	avoir	VERB	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	527	advcl		O
# 535	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	536	det		O
# 536	envie	envie	NOUN	Gender=Fem|Number=Sing	534	obj		O
# 537	de	de	ADP		538	case		O
# 538	gagner	gagner	VERB	VerbForm=Inf	536	nmod		O
# 539	.	.	PUNCT		527	punct		O
# 540	"	"	PUNCT		527	punct		O
# 541	Promu	Promu	PROPN		542	amod	LOC	B
# 542	titulaire	titulaire	NOUN	Number=Sing	542	ROOT		O
# 543	indiscutable	indiscutable	ADJ	Number=Sing	542	amod		O
# 544	en	en	ADP		546	case		O
# 545	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	546	det		O
# 546	absence	absence	NOUN	Gender=Fem|Number=Sing	557	obl:mod		O
# 547	de	de	ADP		548	case		O
# 548	N'	n'	NOUN	Gender=Masc|Number=Sing	546	nmod	MISC	B
# 549	Golo	Golo	X		550	advmod	MISC	I
# 550	Kanté	Kanté	PROPN		546	nmod	MISC	I
# 551	et	et	CCONJ		552	cc		O
# 552	Paul	Paul	PROPN	Gender=Masc|Number=Sing	557	nsubj	PER	B
# 553	Pogba	Pogba	PROPN		552	flat:name	PER	I
# 554	,	,	PUNCT		552	punct		O
# 555	Rabiot	Rabiot	PROPN		552	flat:name	PER	B
# 556	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	557	aux:tense		O
# 557	assumé	assumer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	542	parataxis		O
# 558	son	son	DET	Number=Sing|Poss=Yes	559	det		O
# 559	rôle	rôle	NOUN	Gender=Masc|Number=Sing	557	obj		O
# 560	de	de	ADP		561	case		O
# 561	patron	patron	NOUN	Gender=Masc|Number=Sing	559	nmod		O
# 562	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	563	case		O
# 563	milieu	milieu	NOUN	Gender=Masc|Number=Sing	561	nmod		O
# 564	.	.	PUNCT		557	punct		O
# 565
#
# 	SPACE		564	dep		O
# 566	Quelques	quelque	DET	Definite=Ind|Number=Plur|PronType=Art	567	det		O
# 567	instants	instant	NOUN	Gender=Masc|Number=Plur	557	obl:mod		O
# 568	pour	pour	ADP		570	mark		O
# 569	s'	se	PRON	Person=3|Reflex=Yes	570	expl:comp		O
# 570	encourager	encourager	VERB	VerbForm=Inf	557	advcl		O
# 571
#
#
#
# 	SPACE		570	dep		O
# 572	Sur	sur	ADP		574	case		O
# 573	son	son	DET	Number=Sing|Poss=Yes	574	det		O
# 574	but	but	NOUN	Gender=Masc|Number=Sing	570	obl:arg		O
# 575	égalisateur	égalisateur	ADJ	Gender=Fem|Number=Sing	574	amod		O
# 576	,	,	PUNCT		579	punct		O
# 577	tous	tout	ADJ	Gender=Masc|Number=Plur	579	amod		O
# 578	les	le	DET	Definite=Def|Number=Plur|PronType=Art	579	det		O
# 579	joueurs	joueur	NOUN	Gender=Masc|Number=Plur	574	conj		O
# 580	de	de	ADP		582	case		O
# 581	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	582	det		O
# 582	équipe	équipe	NOUN	Gender=Fem|Number=Sing	579	nmod		O
# 583	de	de	ADP		584	case	LOC	B
# 584	France	France	PROPN	Gender=Fem|Number=Sing	582	nmod	LOC	I
# 585	se	se	PRON	Person=3|Reflex=Yes	587	expl:comp		O
# 586	sont	être	AUX	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	587	aux:tense		O
# 587	retrouvés	retrouver	VERB	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	557	conj		O
# 588	dans	dans	ADP		590	case		O
# 589	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	590	det		O
# 590	camp	camp	NOUN	Gender=Masc|Number=Sing	587	obl:mod		O
# 591	australien	australien	ADJ	Gender=Masc|Number=Sing	590	amod		O
# 592	pour	pour	ADP		593	mark		O
# 593	prendre	prendre	VERB	VerbForm=Inf	587	xcomp		O
# 594	quelques	quelque	DET	Definite=Ind|Number=Plur|PronType=Art	595	det		O
# 595	secondes	seconde	NOUN	Gender=Fem|Number=Plur	593	obj		O
# 596	dans	dans	ADP		598	case		O
# 597	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	598	det		O
# 598	nuit	nuit	NOUN	Gender=Fem|Number=Sing	595	nmod		O
# 599	de	de	ADP		600	case		O
# 600	Doha	Doha	PROPN	Gender=Masc|Number=Sing	598	nmod	LOC	B
# 601	.	.	PUNCT		557	punct		O
# 602	S'	se	PRON	Person=3|Reflex=Yes	603	obj		O
# 603	encourager	encourager	VERB	VerbForm=Inf	606	advcl		O
# 604	,	,	PUNCT		606	punct		O
# 605	se	se	PRON	Person=3|Reflex=Yes	606	obj		O
# 606	rassurer	rassurer	VERB	VerbForm=Inf	609	advcl		O
# 607	,	,	PUNCT		609	punct		O
# 608	se	se	PRON	Person=3|Reflex=Yes	609	expl:comp		O
# 609	motiver	motiver	VERB	VerbForm=Inf	609	ROOT		O
# 610	.	.	PUNCT		609	punct		O
# 611	Mettre	mettre	VERB	VerbForm=Inf	611	ROOT		O
# 612	davantage	davantage	ADV		611	fixed		O
# 613	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	614	det		O
# 614	pied	pied	NOUN	Gender=Masc|Number=Sing	611	obj		O
# 615	.	.	PUNCT		611	punct		O
# 616	Mettre	mettre	VERB	VerbForm=Inf	616	ROOT		O
# 617	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	618	det		O
# 618	intensité	intensité	NOUN	Gender=Fem|Number=Sing	616	obj		O
# 619	digne	digne	ADJ	Number=Sing	618	amod		O
# 620	d'	de	ADP		622	case		O
# 621	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	622	det		O
# 622	Coupe	coupe	NOUN	Gender=Fem|Number=Sing	619	obl:arg	MISC	B
# 623	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	624	case	MISC	I
# 624	monde	monde	NOUN	Gender=Masc|Number=Sing	622	nmod	MISC	I
# 625	,	,	PUNCT		616	punct		O
# 626	finalement	finalement	ADV		616	advmod		O
# 627	.	.	PUNCT		616	punct		O
# 628	Ce	ce	PRON	Number=Sing|Person=3	631	nsubj		O
# 629	fut	être	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	631	cop		O
# 630	beaucoup	beaucoup	ADV		631	advmod		O
# 631	mieux	mieux	ADV		640	advmod		O
# 632	par	par	ADP		634	case		O
# 633	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	634	det		O
# 634	suite	suite	NOUN	Gender=Fem|Number=Sing	631	dep		O
# 635	,	,	PUNCT		631	punct		O
# 636	et	et	CCONJ		639	cc		O
# 637	on	on	PRON	Number=Sing|Person=3	639	nsubj		O
# 638	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	639	aux:tense		O
# 639	vu	voir	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	640	case		O
# 640	Olivier	olivier	NOUN	Gender=Masc|Number=Sing	640	ROOT	PER	B
# 641	Giroud	Giroud	PROPN		640	flat:name	PER	I
# 642	,	,	PUNCT		640	punct		O
# 643	autre	autre	ADJ	Number=Sing	644	amod		O
# 644	leader	leader	VERB	VerbForm=Inf	640	appos		O
# 645	,	,	PUNCT		644	punct		O
# 646	apaiser	apaiser	VERB	VerbForm=Inf	644	xcomp		O
# 647	certains	certain	DET	Gender=Masc|Number=Plur	648	det		O
# 648	coéquipiers	coéquipier	ADJ	Gender=Masc|Number=Plur	646	obj		O
# 649	et	et	CCONJ		650	cc		O
# 650	donner	donner	VERB	VerbForm=Inf	646	conj		O
# 651	des	un	DET	Definite=Ind|Number=Plur|PronType=Art	652	det		O
# 652	consignes	consigne	NOUN	Gender=Fem|Number=Plur	650	obj		O
# 653	à	à	ADP		654	case		O
# 654	Benjamin	benjamin	NOUN	Gender=Masc|Number=Sing	650	obl:arg	PER	B
# 655	Pavard	Pavard	PROPN	Gender=Masc|Number=Sing	654	nmod	PER	I
# 656	,	,	PUNCT		644	punct		O
# 657	en	en	ADP		658	mark		O
# 658	difficulté	difficulter	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	644	advmod		O
# 659	ce	ce	DET	Gender=Masc|Number=Sing|PronType=Dem	660	det		O
# 660	soir	soir	NOUN	Gender=Masc|Number=Sing	658	obj		O
# 661	.	.	PUNCT		640	punct		O
# 662
#
#
#
# 	SPACE		662	dep		O
# 663	Les	le	DET	Definite=Def|Number=Plur|PronType=Art	664	det		O
# 664	nuages	nuage	NOUN	Gender=Masc|Number=Plur	670	nsubj		O
# 665	passés	passer	VERB	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	664	acl		O
# 666	,	,	PUNCT		670	punct		O
# 667	les	le	DET	Definite=Def|Number=Plur|PronType=Art	668	det		O
# 668	Bleus	Bleus	PROPN	Gender=Masc|Number=Plur	670	nsubj	ORG	B
# 669	ont	avoir	AUX	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	670	aux:tense		O
# 670	déroulé	dérouler	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	670	ROOT		O
# 671	comme	comme	ADP		672	case		O
# 672	rarement	rarement	ADV		670	xcomp		O
# 673	ces	ce	DET	Number=Plur|PronType=Dem	675	det		O
# 674	derniers	dernier	ADJ	Gender=Masc|NumType=Ord|Number=Plur	675	amod		O
# 675	mois	mois	NOUN	Gender=Masc|Number=Plur	670	obj		O
# 676	.	.	PUNCT		670	punct		O
# 677	Au	au	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	678	case		O
# 678	point	point	NOUN	Gender=Masc|Number=Sing	682	obl:mod		O
# 679	que	que	SCONJ		682	mark		O
# 680	les	le	DET	Definite=Def|Number=Plur|PronType=Art	681	det		O
# 681	échecs	échec	NOUN	Gender=Masc|Number=Plur	682	nsubj		O
# 682	semblent	sembler	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	682	ROOT		O
# 683	nourrir	nourrir	VERB	VerbForm=Inf	682	xcomp		O
# 684	cette	ce	DET	Gender=Fem|Number=Sing|PronType=Dem	685	det		O
# 685	équipe	équipe	NOUN	Gender=Fem|Number=Sing	683	obj		O
# 686	.	.	PUNCT		682	punct		O
# 687	Une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	688	det		O
# 688	thèse	thèse	NOUN	Gender=Fem|Number=Sing	688	ROOT		O
# 689	développée	développer	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	688	amod		O
# 690	,	,	PUNCT		688	punct		O
# 691	déjà	déjà	ADV		693	advmod		O
# 692	en	en	ADP		693	case		O
# 693	septembre	septembre	NOUN	Gender=Masc|Number=Sing	688	nmod		O
# 694	,	,	PUNCT		688	punct		O
# 695	par	par	ADP		696	case		O
# 696	Antoine	Antoine	PROPN		688	nmod	PER	B
# 697	Griezmann	Griezmann	PROPN		696	flat:name	PER	I
# 698	.	.	PUNCT		688	punct		O
# 699	Interrogé	interroger	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	722	advcl		O
# 700	sur	sur	ADP		703	case		O
# 701	les	le	DET	Definite=Def|Number=Plur|PronType=Art	703	det		O
# 702	mauvais	mauvais	ADJ	Number=Plur	703	amod		O
# 703	résultats	résultat	NOUN	Gender=Masc|Number=Plur	699	obl:arg		O
# 704	des	de	ADP	Definite=Def|Number=Plur|PronType=Art	705	case		O
# 705	Bleus	bleu	NOUN	Gender=Masc|Number=Plur	703	nmod	ORG	B
# 706	ces	ce	DET	Number=Plur|PronType=Dem	708	det		O
# 707	derniers	dernier	ADJ	Gender=Masc|NumType=Ord|Number=Plur	708	amod		O
# 708	mois	mois	NOUN	Gender=Masc|Number=Plur	699	obj		O
# 709	,	,	PUNCT		699	punct		O
# 710	avec	avec	ADP		713	case		O
# 711	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	713	det		O
# 712	seule	seul	ADJ	Gender=Fem|Number=Sing	713	amod		O
# 713	victoire	victoire	NOUN	Gender=Fem|Number=Sing	699	obl:mod		O
# 714	en	en	ADP		715	case		O
# 715	six	six	NUM	NumType=Card	713	nmod		O
# 716	matchs	match	PROPN	Gender=Masc|Number=Sing	715	flat:name		O
# 717	,	,	PUNCT		722	punct		O
# 718	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	719	det		O
# 719	numéro	numéro	NOUN	Gender=Masc|Number=Sing	722	nsubj		O
# 720	7	7	NUM	NumType=Card	719	nmod		O
# 721	y	y	PRON	Person=3	722	iobj		O
# 722	voyait	voir	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	722	ROOT		O
# 723	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	724	case		O
# 724	bon	bon	ADJ	Gender=Masc|Number=Sing	722	nmod		O
# 725	:	:	PUNCT		722	punct		O
# 726	"	"	PUNCT		729	punct		O
# 727	Ça	Ça	PROPN		729	nsubj	MISC	B
# 728	nous	nous	PRON	Number=Plur|Person=1	729	iobj		O
# 729	fait	faire	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	722	advcl		O
# 730	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	734	det		O
# 731	bien	bien	ADV		730	fixed		O
# 732	avant	avant	ADP		734	case		O
# 733	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	734	det		O
# 734	Coupe	coupe	NOUN	Gender=Fem|Number=Sing	729	obj	MISC	B
# 735	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	736	case	MISC	I
# 736	monde	monde	NOUN	Gender=Masc|Number=Sing	734	nmod	MISC	I
# 737	"	"	PUNCT		729	punct		O
# 738	.	.	PUNCT		722	punct		O
# 739	Cette	ce	DET	Gender=Fem|Number=Sing|PronType=Dem	741	det		O
# 740	première	premier	ADJ	Gender=Fem|NumType=Ord|Number=Sing	741	amod		O
# 741	demi-heure	demi-heure	NOUN	Gender=Fem|Number=Sing	741	ROOT		O
# 742	cauchemardesque	cauchemardesque	ADJ	Number=Sing	741	amod		O
# 743	,	,	PUNCT		741	punct		O
# 744	sanctionnée	sanctionner	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	741	acl		O
# 745	par	par	ADP		747	case		O
# 746	un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	747	det		O
# 747	but	but	NOUN	Gender=Masc|Number=Sing	744	obl:agent		O
# 748	et	et	CCONJ		750	cc		O
# 749	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	750	det		O
# 750	blessure	blessure	NOUN	Gender=Fem|Number=Sing	747	conj		O
# 751	de	de	ADP		752	case		O
# 752	Lucas	luca	NOUN	Gender=Masc|Number=Plur	750	nmod	PER	B
# 753	Hernandez	Hernandez	PROPN		747	nmod	PER	I
# 754	,	,	PUNCT		747	punct		O
# 755	montre	montr	ADJ	Number=Sing	747	appos		O
# 756	que	que	SCONJ		763	mark		O
# 757	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	758	det		O
# 758	Mâconnais	Mâconnais	PROPN	Gender=Masc|Number=Sing	763	nsubj	LOC	B
# 759	n'	n'	ADV	Polarity=Neg	763	advmod		O
# 760	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	763	aux:tense		O
# 761	pas	pas	ADV	Polarity=Neg	763	advmod		O
# 762	juste	juste	ADV		763	advmod		O
# 763	appliqué	appliquer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	744	ccomp		O
# 764	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	765	det		O
# 765	méthode	méthode	NOUN	Gender=Fem|Number=Sing	763	obj		O
# 766	Coué	Coué	PROPN	Gender=Masc|Number=Sing	765	acl	ORG	B
# 767	.	.	PUNCT		741	punct		O
# 768	La	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	769	det		O
# 769	difficulté	difficulté	NOUN	Gender=Fem|Number=Sing	771	nsubj		O
# 770	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	771	aux:tense		O
# 771	paradoxalement	paradoxalement	ADV		771	ROOT		O
# 772	semblé	semblé	ADV		771	advmod		O
# 773	débloquer	débloquer	VERB	VerbForm=Inf	771	xcomp		O
# 774	des	un	DET	Definite=Ind|Number=Plur|PronType=Art	775	det		O
# 775	Bleus	bleu	NOUN	Gender=Masc|Number=Plur	773	obl:arg	ORG	B
# 776	submergés	submerger	VERB	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	775	acl		O
# 777	par	par	ADP		779	case		O
# 778	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	779	det		O
# 779	pression	pression	NOUN	Gender=Fem|Number=Sing	776	obl:agent		O
# 780	en	en	ADP		781	case		O
# 781	début	début	NOUN	Gender=Masc|Number=Sing	779	nmod		O
# 782	de	de	ADP		783	case		O
# 783	rencontre	rencontre	NOUN	Number=Sing	781	nmod		O
# 784	.	.	PUNCT		771	punct		O
# 785
#
#
#
# 	SPACE		795	dep		O
# 786	Impossible	Impossible	PROPN		785	nmod		O
# 787	,	,	PUNCT		785	punct		O
# 788	dès	dès	ADP		795	advmod		O
# 789	lors	lors	ADV		788	fixed		O
# 790	,	,	PUNCT		795	punct		O
# 791	de	de	ADP		795	mark		O
# 792	ne	ne	ADV	Polarity=Neg	795	advmod		O
# 793	pas	pas	ADV	Polarity=Neg	795	advmod		O
# 794	y	y	PRON	Person=3	795	iobj		O
# 795	voir	voir	VERB	VerbForm=Inf	795	ROOT		O
# 796	un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	797	det		O
# 797	lien	lien	NOUN	Gender=Masc|Number=Sing	795	obj		O
# 798	avec	avec	ADP		800	case		O
# 799	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	800	det		O
# 800	victoire	victoire	NOUN	Gender=Fem|Number=Sing	797	nmod		O
# 801	étriquée	étriquer	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	800	acl		O
# 802	acquise	acquérir	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	797	acl		O
# 803	dans	dans	ADP		807	case		O
# 804	les	le	DET	Definite=Def|Number=Plur|PronType=Art	807	det		O
# 805	plus	plus	ADV		806	advmod		O
# 806	grandes	grand	ADJ	Gender=Fem|Number=Plur	807	amod		O
# 807	difficultés	difficulté	NOUN	Gender=Fem|Number=Plur	797	nmod		O
# 808	contre	contre	ADP		810	case		O
# 809	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	810	det		O
# 810	Australie	Australie	PROPN	Number=Sing	807	nmod	LOC	B
# 811	,	,	PUNCT		795	punct		O
# 812	déjà	déjà	ADV		795	advmod		O
# 813	,	,	PUNCT		795	punct		O
# 814	en	en	ADP		815	case		O
# 815	2018	2018	NUM	NumType=Card	795	obl:mod		O
# 816	(	(	PUNCT		815	punct		O
# 817	2	2	NUM	NumType=Card	815	nmod		O
# 818	-	-	NUM	NumType=Card	817	nmod		O
# 819	1	1	NOUN	NumType=Card	817	nmod		O
# 820	)	)	PUNCT		815	punct		O
# 821	.	.	PUNCT		795	punct		O
# 822	Une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	823	det		O
# 823	prestation	prestation	NOUN	Gender=Fem|Number=Sing	823	ROOT		O
# 824	fondatrice	fondateur	ADJ	Number=Sing	823	amod		O
# 825	dans	dans	ADP		827	case		O
# 826	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	827	det		O
# 827	parcours	parcours	NOUN	Gender=Masc|Number=Sing	823	nmod		O
# 828	des	de	ADP	Definite=Def|Number=Plur|PronType=Art	829	case		O
# 829	Bleus	Bleus	PROPN		827	nmod	ORG	B
# 830	,	,	PUNCT		823	punct		O
# 831	futurs	futur	NOUN	Gender=Masc|Number=Plur	823	appos		O
# 832	champions	champion	NOUN	Gender=Masc|Number=Plur	831	amod		O
# 833	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	834	case		O
# 834	monde	monde	NOUN	Gender=Masc|Number=Sing	831	nmod		O
# 835	.	.	PUNCT		823	punct		O
# 836	Didier	Didier	PROPN	Gender=Masc|Number=Sing	840	nsubj	PER	B
# 837	Deschamps	Deschamps	PROPN	Gender=Masc|Number=Sing	836	flat:name	PER	I
# 838	en	en	PRON	Person=3	840	iobj		O
# 839	avait	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	840	aux:tense		O
# 840	tiré	tirer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	840	ROOT		O
# 841	des	un	DET	Definite=Ind|Number=Plur|PronType=Art	842	det		O
# 842	leçons	leçon	NOUN	Gender=Fem|Number=Plur	840	obj		O
# 843	,	,	PUNCT		840	punct		O
# 844	en	en	ADP		845	mark		O
# 845	bouleversant	bouleverser	VERB	Tense=Pres|VerbForm=Part	840	advcl		O
# 846	sa	son	DET	Gender=Fem|Number=Sing|Poss=Yes	847	det		O
# 847	composition	composition	NOUN	Gender=Fem|Number=Sing	845	obj		O
# 848	d'	de	ADP		849	case		O
# 849	équipe	équipe	NOUN	Gender=Fem|Number=Sing	847	nmod		O
# 850	dès	dès	ADP		853	case		O
# 851	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	853	det		O
# 852	second	second	ADJ	Gender=Masc|NumType=Ord|Number=Sing	853	amod		O
# 853	match	match	NOUN	Gender=Masc|Number=Sing	847	nmod		O
# 854	.	.	PUNCT		840	punct		O
# 855	Ce	ce	DET	Gender=Masc|Number=Sing|PronType=Dem	857	det		O
# 856	nouveau	nouveau	ADJ	Gender=Masc|Number=Sing	857	amod		O
# 857	succès	succès	NOUN	Gender=Masc|Number=Sing	874	nsubj		O
# 858	contre	contre	ADP		860	case		O
# 859	les	le	DET	Definite=Def|Number=Plur|PronType=Art	860	det		O
# 860	Socceroos	socceroo	NOUN	Gender=Fem|Number=Plur	857	nmod	PER	B
# 861	,	,	PUNCT		857	punct		O
# 862	beaucoup	beaucoup	ADV		864	advmod		O
# 863	plus	plus	ADV		864	advmod		O
# 864	large	large	ADJ	Number=Sing	857	amod		O
# 865	cette	ce	DET	Gender=Fem|Number=Sing|PronType=Dem	866	det		O
# 866	fois	fois	NOUN	Gender=Fem|Number=Sing	864	obl:mod		O
# 867	mais	mais	CCONJ		870	cc		O
# 868	après	après	ADP		870	mark		O
# 869	avoir	avoir	AUX	VerbForm=Inf	870	aux:tense		O
# 870	renversé	renverser	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	864	conj		O
# 871	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	872	det		O
# 872	score	score	NOUN	Gender=Masc|Number=Sing	870	obj		O
# 873	,	,	PUNCT		874	punct		O
# 874	aura	avoir	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	874	ROOT		O
# 875	peut-être	peut-être	ADV		874	advmod		O
# 876	les	le	DET	Definite=Def|Number=Plur|PronType=Art	878	det		O
# 877	mêmes	même	ADJ	Number=Plur	878	amod		O
# 878	vertus	vertu	NOUN	Gender=Fem|Number=Plur	874	obj		O
# 879	.	.	PUNCT		874	punct		O

# %% [markdown]
# Visualisation des entités nommées dans un texte.

# %%
from spacy import displacy
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# -
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  : une première demi-heure fondatrice pour les
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bleus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  dans cette
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coupe du monde 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  ?</br></br>L'entame de match des
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bleus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , ratée mardi contre l'
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  malgré la victoire finale (4-1), pourrait servir de déclic pour le reste du
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mondial
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .</br></br>L'incompréhension d'
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hugo Lloris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Le regard noir de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Benjamin Pavard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . L'inquiétude autour de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lucas Hernandez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . L'équipe
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     de France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  n'est entrée que depuis neuf minutes dans sa
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coupe du monde 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , mardi 22 novembre, qu'elle se trouve déjà en pleine tourmente.
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Menés
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  par l'
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , les
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bleus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  voient les spectres des derniers mois resurgir soudainement : les blessures, les mauvais résultats, les doutes.
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  se prend de plein fouet le mur sur lequel se brisent les ambitions des champions du monde en titre lors des dernières éditions.</br></br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Devancés
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  au tableau d'affichage après le but de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Craig
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  Goodwin, les
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bleus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  doivent en plus digérer la blessure de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lucas Hernandez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . &quot;Je pense que ça va être malheureusement assez grave&quot;, a confirmé
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Didier Deschamps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  en conférence de presse après le match. Le choix du sélectionneur de ne pas retenir un latéral de plus et d'avoir convoqué trois défenseurs centraux (Pavard,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lucas Hernandez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  et
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jules Koundé
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align:

# %% [markdown]
# Visualisation de l'abre de dépendance d'une phrase donnée.

# %%
displacy.render(list(doc.sents)[4], style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="941fb85cbf454ca691ec8e3ce06873d6-0" class="displacy" width="4950" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">L'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">entame</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">match</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">des</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Bleus,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">ratée</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">mardi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">contre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">l'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Australie</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">malgré</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">victoire</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">finale (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">4-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">1),</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">pourrait</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">servir</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">déclic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">pour</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">reste</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">du</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Mondial.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-941fb85cbf454ca691ec8e3ce06873d6-0-0" stroke-width="2px" d="M70,352.0 C70,89.5 570.0,89.5 570.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-941fb85cbf454ca691ec8e3ce06873d6-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-941fb85cbf454ca691ec8e3ce06873d6-0-1" stroke-width="2px" d="M245,352.0 C245,177.0 56

# %% [markdown]
# [Q7] Visualiser l'abre de dépendance de la dixième phrase dans un format compact.

# %%
# insérer votre code ici
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="3d2dc0add14944918b9c983e21032029-0" class="displacy" width="3800" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">France</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">se</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">prend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">plein</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">fouet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">mur</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">sur</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">lequel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">se</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">brisent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">les</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">ambitions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">des</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">champions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">du</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">monde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">titre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">lors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">des</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">dernières</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">éditions.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3d2dc0add14944918b9c983e21032029-0-0" stroke-width="2px" d="M62,377.0 62,352.0 188.0,352.0 188.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3d2dc0add14944918b9c983e21032029-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,379.0 L58,371.0 66,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3d2dc0add14944918b9c983e21032029-0-1" stroke-width="2px" d="M212,377.0 212,327.0 491.0,327.0 491.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3d2dc0add14944918b9c983e21032029-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,379.0 L208,371.0 216,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3d2dc0add14944918b9c983e21032029-0-2" stroke-width="2px" d="M362,377.0 362,352.0 488.0,352.0 488.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3d2dc0a

# %% [markdown]
# 4 - Utilisation d'une image pour la réalisation d'un nuage de mots
# -----

# %%
from PIL import Image
import numpy as np

# %% [markdown]
# Convertir l'image en une matrice de valeurs 0 ou 255, i.e. un masque.

# %%
#mask = (np.array(Image.open("heart.png").convert('L')) > 0) * 255
mask = (np.array(Image.open("football.png").convert('L')) > 0) * 255
plt.imshow(mask)

# %% [markdown]
# Génerer le nuage de mots avec des masques.

# %%
wc = WordCloud(background_color="white", max_words=100, mask=mask, contour_width=1, contour_color='steelblue')
wc.generate_from_frequencies(freq_list)
plt.imshow(wc, interpolation='bilinear')

# %% [markdown]
# 5 - Extraire des unités polylexicales
# -----

# %%
import nltk
from nltk.collocations import *

# %% [markdown]
# Trouver les bigrams avec l'information mutuelle la plus forte.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words([token.text for token in doc])
finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('22', 'novembre'),
#  ('Antoine', 'Griezmann'),
#  ('Au', 'point'),
#  ('Craig', 'Goodwin'),
#  ('Dayot', 'Upamecano'),
#  ('Golo', 'Kanté'),
#  ('Jules', 'Koundé'),
#  ('Mitchell', 'Duke'),
#  ("N'", 'Golo'),
#  ('Olivier', 'Giroud')]

# %% [markdown]
# [Q8] Trouver les 10 bigrams avec le coefficient de DICE le plus élevé.

# %%
# insérer votre code ici
# Out:
# [('22', 'novembre'),
#  ('Antoine', 'Griezmann'),
#  ('Au', 'point'),
#  ('Craig', 'Goodwin'),
#  ('Dayot', 'Upamecano'),
#  ('Didier', 'Deschamps'),
#  ('Golo', 'Kanté'),
#  ('Jules', 'Koundé'),
#  ('Mitchell', 'Duke'),
#  ("N'", 'Golo')]

# %% [markdown]
# Trouver les 10 trigrams avec l'information mutuelle la plus élevée.

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = TrigramCollocationFinder.from_words([token.text for token in doc])
finder.nbest(trigram_measures.pmi, 10)
# Out:
# [("N'", 'Golo', 'Kanté'),
#  ('Promu', 'titulaire', 'indiscutable'),
#  ('convoqué', 'trois', 'défenseurs'),
#  ('déroulé', 'comme', 'rarement'),
#  ('naturel', 'chez', 'moi'),
#  ('ont', 'déroulé', 'comme'),
#  ('paradoxalement', 'semblé', 'débloquer'),
#  ('prendre', 'quelques', 'secondes'),
#  ('sans', 'même', 'regarder'),
#  ('tempête', 'emportait', 'tout')]

# %% [markdown]
# [Q9] Trouver les 10 trigrams avec le coefficient de DICE le plus élevé. Que se passe-t-il? Quelles sont les alternatives?

# %%
# insérer votre code ici
# Out:
# [('Coupe', 'du', 'monde'),
#  ('blessure', 'de', 'Lucas'),
#  (',', 'les', 'Bleus'),
#  ('de', 'Lucas', 'Hernandez'),
#  ('sur', 'le', 'terrain'),
#  ('équipe', 'de', 'France'),
#  ('"', ',', 'a'),
#  ('"', 'La', 'blessure'),
#  ('-', '1', ')'),
#  ('Didier', 'Deschamps', 'en')]

# %% [markdown]
# Intégrer les 30 meilleurs bigrams suivant le coefficient de DICE dans un texte en les connectant par un underscore. Et générer le nuage de mot correspondant.

# %%
from nltk.tokenize import MWETokenizer

# %%
finder = BigramCollocationFinder.from_words([token.text for token in doc])
tokenizer = MWETokenizer(finder.nbest(bigram_measures.dice, 30))
new_doc = nlp(' '.join(tokenizer.tokenize([token.text for token in doc])))
generate_wordcloud(Counter([token.text for token in new_doc if not token.is_stop]))

# %% [markdown]
# [Q10] Intégrer les 30 meilleurs trigrams suivant l'information mutuelle dans un texte en les connectant par un underscore. Et générer un nuage de mot qui ne contient que des trigrams.

# %%
# insérer votre code ici

# %% [markdown]
# 6 - Enrichissement des textes par liaison ontologique
# -----

# %%
from nltk.corpus import wordnet as wn
#import nltk
#nltk.download('omw-1.4')

# %% [markdown]
# L'algorithme de Lesk (https://en.wikipedia.org/wiki/Lesk_algorithm) permet de désambiguiser le sens d'un mot dans un contexte défini. Par exemple, dans la phrase, "le chanteur danse la java avec des choristes", l'algorithme de Lesk permet de désambiguiser le sens de java, i.e. java dans les sens de danse et non java dans le sens de café ou de langage de programmation. L'algorithme de Lesk retourne le sens correspondant à un mot dans un contexte donné.

# %%
def lesk(context_sentence, ambiguous_word, pos=None, synsets=None):
    
    """Return a synset for an ambiguous word in a context.
    :param iter context_sentence: The context sentence where the ambiguous word
         occurs, passed as an iterable of words.
    :param str ambiguous_word: The ambiguous word that requires WSD.
    :param str pos: A specified Part-of-Speech (POS).
    :param iter synsets: Possible synsets of the ambiguous word.
    :return: ``lesk_sense`` The Synset() object with the highest signature overlaps.
    This function is an implementation of the original Lesk algorithm (1986) [1].
    Usage example::
        >>> lesk(['I', 'went', 'to', 'the', 'bank', 'to', 'deposit', 'money', '.'], 'bank', 'n')
        Synset('savings_bank.n.02')
    [1] Lesk, Michael. "Automatic sense disambiguation using machine
    readable dictionaries: how to tell a pine cone from an ice cream
    cone." Proceedings of the 5th Annual International Conference on
    Systems Documentation. ACM, 1986.
    https://dl.acm.org/citation.cfm?id=318728
    """

    context = set(context_sentence)
    
    if synsets is None:
        # synsets = wn.synsets(ambiguous_word, lang='fra')
        synsets = wn.synsets(ambiguous_word)
    
    if pos:
        synsets = [ss for ss in synsets if str(ss.pos()) == pos]

    if not synsets:
        return None
    
    _, sense = max(
        (len(context.intersection(ss.definition().split())), ss) for ss in synsets
    )

    return sense

# %% [markdown]
# Nous travaillerons avec un texte en anglais pour avoir toutes les fonctions nécessaires d'accès à wordnet. Si vous voulez tester d'autres langues, l'italien et l'espagnol fonctionnent.

# %%
nlp = spacy.load("en_core_web_lg")

text_path3 = "sport-en.txt"

text3 = ""
with open(text_path3, encoding='utf-8') as f:
    text3 = f.read()
    
doc = nlp(text3)

# %% [markdown]
# Pour tous les mots d'un texte, trouver le sens de chacun d'eux dans wordnet. Attention, seuls les noms, les verbes, les adjectifs et les adverbes se trouvent dans wordnet. Dans cet exemple, le contexte donné est celui de la phrase dans lequel se trouve le mot.

# %%
pos_to_wn = {'NOUN': wn.NOUN, 'VERB': wn.VERB, 'ADJ': wn.ADJ, 'ADV': wn.ADV, 'PROPN': wn.NOUN}

sent_level = []

for sent in doc.sents:
    context = [token.text for token in sent]
    for token in sent:
        if token.pos_ in pos_to_wn:
            # print((token.text, lesk(context, token.lemma_, pos=pos_to_wn[token.pos_])))
            sent_level.append((token.text, lesk(context, token.lemma_, pos=pos_to_wn[token.pos_])))
        else:
            sent_level.append((token.text, None))

sent_level
# Out:
# [('The', None),
#  ('US', Synset('uranium.n.01')),
#  ('Men', Synset('serviceman.n.01')),
#  ('’s', None),
#  ('National', Synset('national.n.01')),
#  ('Team', Synset('team.n.02')),
#  ('(', None),
#  ('USMNT', None),
#  (')', None),
#  ('was', None),
#  ('made', Synset('make.v.42')),
#  ('to', None),
#  ('work', Synset('work.v.01')),
#  ('hard', Synset('hard.r.10')),
#  ('for', None),
#  ('its', None),
#  ('place', Synset('seat.n.01')),
#  ('in', None),
#  ('the', None),
#  ('World', Synset('world.n.06')),
#  ('Cup', Synset('cup.n.08')),
#  ('knockout', Synset('knockout.n.02')),
#  ('stage', Synset('stage.n.08')),
#  (',', None),
#  ('earning', Synset('gain.v.08')),
#  ('a', None),
#  ('tough', Synset('tough.a.07')),
#  ('1', None),
#  ('-', None),
#  ('0', None),
#  ('win', Synset('win.n.01')),
#  ('over', None),
#  ('Iran', Synset('iran.n.01')),
#  ('in', None),
#  ('a', None),
#  ('nerve', Synset('nerve.n.01')),
#  ('-', None),
#  ('racking', Synset('rack.v.10')),
#  ('Group', Synset('group.n.03')),
#  ('B', Synset('boron.n.01')),
#  ('decider', None),
#  ('at', None),
#  ('Qatar', Synset('qatar.n.02')),
#  ('2022', None),
#  ('.', None),
#  ('\n\n', None),
#  ('Christian', Synset('christian.n.01')),
#  ('Pulisic', None),
#  ('’s', None),
#  ('first', Synset('first.a.01')),
#  ('-', None),
#  ('half', Synset('half.n.02')),
#  ('goal', Synset('goal.n.01')),
#  ('was', None),
#  ('all', None),
#  ('that', None),
#  ('separated', Synset('discriminate.v.02')),
#  ('the', None),
#  ('two', None),
#  ('sides', Synset('side.n.09')),
#  ('as', None),
#  ('the', None),
#  ('USMNT', None),
#  ('reached', Synset('pass.v.05')),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  ('for', None),
#  ('the', None),
#  ('first', Synset('first.a.01')),
#  ('time', Synset('time.n.02')),
#  ('since', None),
#  ('2014', None),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('pressure', Synset('pressure.n.01')),
#  ('was', None),
#  ('certainly', Synset('surely.r.01')),
#  ('on', Synset('on.r.03')),
#  ('for', None),
#  ('Gregg', None),
#  ('Berhalter', None),
#  ('’s', None),
#  ('side', Synset('english.n.04')),
#  ('in', None),
#  ('Qatar', Synset('qatar.n.01')),
#  ('after', None),
#  ('the', None),
#  ('national', Synset('national.a.02')),
#  ('team', Synset('team.n.02')),
#  ('’s', None),
#  ('failure', Synset('failure.n.07')),
#  ('to', None),
#  ('qualify', Synset('stipulate.v.01')),
#  ('for', None),
#  ('the', None),
#  ('2018', None),
#  ('World', Synset('world.n.02')),
#  ('Cup', Synset('cup.n.08')),
#  (',', None),
#  ('but', None),
#  ('the', None),
#  ('US', Synset('uranium.n.01')),
#  ('got', Synset('scram.v.01')),
#  ('the', None),
#  ('job', Synset('occupation.n.01')),
#  ('done', Synset('suffice.v.01')),
#  ('with', None),
#  ('three', None),
#  ('gritty', None),
#  ('group', Synset('group.n.03')),
#  ('performances', Synset('performance.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('It', None),
#  ('certainly', Synset('surely.r.01')),
#  ('was', None),
#  ('n’t', None),
#  ('pretty', None),
#  ('at', None),
#  ('times', Synset('time.n.05')),
#  (',', None),
#  ('in', None),
#  ('particular', None),
#  ('in', None),
#  ('the', None),
#  ('closing', Synset('shutting.n.01')),
#  ('stages', Synset('stage.n.08')),
#  ('against', None),
#  ('Iran', Synset('iran.n.01')),
#  (',', None),
#  ('but', None),
#  ('progressing', Synset('advance.v.01')),
#  ('through', None),
#  ('the', None),
#  ('group', Synset('group.n.03')),
#  ('stage', Synset('stage.n.08')),
#  ('was', None),
#  ('the', None),
#  ('minimum', Synset('minimal.a.01')),
#  ('expectation', Synset('expectation.n.03')),
#  ('for', None),
#  ('this', None),
#  ('exciting', Synset('exciting.a.01')),
#  ('young', Synset('young.a.01')),
#  ('team', Synset('team.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('will', None),
#  ('be', None),
#  ('some', None),
#  ('concerns', Synset('concern.n.02')),
#  ('going', Synset('fit.v.02')),
#  ('into', None),
#  ('the', None),
#  ('knockout', Synset('knockout.n.02')),
#  ('stages', Synset('stage.n.03')),
#  (',', None),
#  ('though', Synset('though.r.01')),
#  (',', None),
#  ('after', None),
#  ('Pulisic', None),
#  ('suffered', Synset('suffer.v.11')),
#  ('an', None),
#  ('abdominal', Synset('abdominal.a.01')),
#  ('injury', Synset('injury.n.04')),
#  ('while', None),
#  ('scoring', Synset('score.v.02')),
#  ('the', None),
#  ('winner', Synset('winner.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('will', None),
#  ('be', None),
#  ('hoping', Synset('hope.v.03')),
#  ('its', None),
#  ('star', Synset('star_topology.n.01')),
#  ('man', Synset('serviceman.n.01')),
#  (',', None),
#  ('dubbed', Synset('dub.v.02')),
#  ('‘', None),
#  ('Captain', Synset('captain.n.07')),
#  ('America', Synset('united_states.n.01')),
#  ('’', None),
#  ('by', None),
#  ('some', None),
#  (',', None),
#  ('is', None),
#  ('fit', Synset('fit.a.01')),
#  ('for', None),
#  ('the', None),
#  ('round', Synset('turn.n.09')),
#  ('of', None),
#  ('16', None),
#  ('tie', Synset('tie.n.07')),
#  ('against', None),
#  ('the', None),
#  ('Netherlands', Synset('netherlands.n.01')),
#  ('on', None),
#  ('Saturday', Synset('saturday.n.01')),
#  ('following', Synset('come.v.05')),
#  ('the', None),
#  ('news', Synset('newsworthiness.n.01')),
#  ('that', None),
#  ('Pulisic', None),
#  ('had', None),
#  ('been', None),
#  ('sent', Synset('commit.v.03')),
#  ('to', None),
#  ('hospital', Synset('hospital.n.02')),
#  ('for', None),
#  ('a', None),
#  ('scan', Synset('scan.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Weston', Synset('weston.n.01')),
#  ('McKennie', None),
#  ('and', None),
#  ('Tyler', Synset('tyler.n.01')),
#  ('Adams', Synset('adams.n.02')),
#  ('celebrate', Synset('observe.v.06')),
#  ('the', None),
#  ('opening', Synset('opening.n.05')),
#  ('goal', Synset('goal.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Winner', Synset('winner.n.02')),
#  ('takes', Synset('take.v.39')),
#  ('all', None),
#  ('\n\n', None),
#  ('This', None),
#  ('was', None),
#  ('the', None),
#  ('only', Synset('only.r.07')),
#  ('the', None),
#  ('third', None),
#  ('meeting', Synset('merging.n.01')),
#  ('ever', Synset('always.r.01')),
#  ('between', None),
#  ('the', None),
#  ('two', None),
#  ('nations', Synset('state.n.04')),
#  ('and', None),
#  ('their', None),
#  ('first', Synset('first.a.01')),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  ('encounter', Synset('encounter.n.03')),
#  ('since', None),
#  ('France', Synset('france.n.01')),
#  ('1998', None),
#  ('–', None),
#  ('a', None),
#  ('politically', Synset('politically.r.02')),
#  ('charged', Synset('charge.v.24')),
#  ('match', Synset('match.n.05')),
#  ('that', None),
#  ('saw', Synset('visit.v.01')),
#  ('Iran', Synset('iran.n.01')),
#  ('emerge', Synset('come_forth.v.02')),
#  ('as', None),
#  ('a', None),
#  ('shock', Synset('daze.n.01')),
#  ('2', None),
#  ('-', None),
#  ('1', None),
#  ('winner', Synset('winner.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('That', None),
#  ('was', None),
#  ('the', None),
#  ('first', Synset('first.a.06')),
#  ('time', Synset('time.n.02')),
#  ('that', None),
#  ('Iran', Synset('iran.n.01')),
#  ('and', None),
#  ('the', None),
#  ('US', Synset('uracil.n.01')),
#  (',', None),
#  ('sometimes', Synset('sometimes.r.01')),
#  ('described', Synset('identify.v.05')),
#  ('officially', Synset('officially.r.01')),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('as', None),
#  ('the', None),
#  ('‘', None),
#  ('Great', Synset('great.n.01')),
#  ('Satan', Synset('satan.n.01')),
#  (',', None),
#  ('’', None),
#  ('had', None),
#  ('met', Synset('touch.v.05')),
#  ('on', None),
#  ('the', None),
#  ('football', Synset('football.n.02')),
#  ('pitch', Synset('pitch.n.08')),
#  ('and', None),
#  ('the', None),
#  ('biggest', Synset('large.a.01')),
#  ('sporting', None),
#  ('occasion', Synset('occasion.n.04')),
#  ('between', None),
#  ('the', None),
#  ('countries', Synset('nation.n.02')),
#  ('since', None),
#  ('the', None),
#  ('1979', None),
#  ('revolution', Synset('revolution.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('build', Synset('human_body.n.01')),
#  ('-', None),
#  ('up', None),
#  ('to', None),
#  ('this', None),
#  ('game', Synset('game.n.09')),
#  ('in', None),
#  ('Qatar', Synset('qatar.n.01')),
#  ('has', None),
#  ('been', None),
#  ('similarly', Synset('similarly.r.01')),
#  ('tense', Synset('tense.a.02')),
#  (',', None),
#  ('with', None),
#  ('Iran', Synset('iran.n.01')),
#  ('even', Synset('even.r.04')),
#  ('calling', Synset('call.v.20')),
#  ('for', None),
#  ('the', None),
#  ('USMNT', None),
#  ('to', None),
#  ('be', None),
#  ('expelled', Synset('rout.v.01')),
#  ('from', None),
#  ('the', None),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  ('after', None),
#  ('the', None),
#  ('US', Synset('uracil.n.01')),
#  ('Soccer', Synset('soccer.n.01')),
#  ('Federation', Synset('federation.n.03')),
#  ('posted', Synset('post.v.08')),
#  ('an', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('flag', Synset('pin.n.08')),
#  ('without', None),
#  ('the', None),
#  ('emblem', Synset('emblem.n.02')),
#  ('of', None),
#  ('the', None),
#  ('Islamic', None),
#  ('Republic', Synset('democracy.n.02')),
#  ('on', None),
#  ('its', None),
#  ('social', Synset('social.a.03')),
#  ('media', Synset('metier.n.02')),
#  ('platforms', Synset('platform.n.03')),
#  ('to', None),
#  ('show', Synset('show.v.01')),
#  ('support', Synset('support.n.04')),
#  ('for', None),
#  ('protesters', Synset('demonstrator.n.03')),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('USMNT', None),
#  ('manager', Synset('coach.n.01')),
#  ('Berhalter', None),
#  ('and', None),
#  ('captain', Synset('captain.n.07')),
#  ('Tyler', Synset('tyler.n.02')),
#  ('Adams', Synset('adam.n.01')),
#  ('also', Synset('besides.r.02')),
#  ('faced', Synset('front.v.01')),
#  ('some', None),
#  ('tough', Synset('tough.a.07')),
#  ('questions', Synset('question.n.03')),
#  ('from', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('journalists', Synset('journalist.n.01')),
#  ('in', None),
#  ('a', None),
#  ('fiery', None),
#  ('press', Synset('wardrobe.n.01')),
#  ('conference', Synset('conference.n.01')),
#  (',', None),
#  ('fending', Synset('resist.v.04')),
#  ('off', None),
#  ('accusations', Synset('accusation.n.02')),
#  ('of', None),
#  ('hypocrisy', Synset('hypocrisy.n.02')),
#  ('and', None),
#  ('disrespect', Synset('contempt.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('furore', Synset('furor.n.02')),
#  ('surrounding', Synset('wall.v.01')),
#  ('this', None),
#  ('game', Synset('game.n.09')),
#  ('only', Synset('only.r.04')),
#  ('added', Synset('add.v.01')),
#  ('to', None),
#  ('the', None),
#  ('drama', Synset('drama.n.04')),
#  ('of', None),
#  ('a', None),
#  ('matchup', Synset('match-up.n.01')),
#  ('that', None),
#  ('–', None),
#  ('even', Synset('even.r.03')),
#  ('in', None),
#  ('a', None),
#  ('vacuum', Synset('vacuum.n.03')),
#  ('away', Synset('aside.r.02')),
#  ('from', None),
#  ('off', None),
#  ('-', None),
#  ('field', Synset('field.n.12')),
#  ('issues', Synset('return.n.06')),
#  ('–', None),
#  ('was', None),
#  ('guaranteed', Synset('guarantee.v.04')),
#  ('to', None),
#  ('be', None),
#  ('fraught', None),
#  ('with', None),
#  ('tension', Synset('tension.n.04')),
#  ('.', None),
#  ('\n\n', None),
#  ('Both', None),
#  ('teams', Synset('team.n.01')),
#  ('knew', Synset('know.v.03')),
#  ('a', None),
#  ('win', Synset('win.n.01')),
#  ('would', None),
#  ('secure', Synset('fasten.v.01')),
#  ('a', None),
#  ('place', Synset('topographic_point.n.01')),
#  ('in', None),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  (',', None),
#  ('but', None),
#  ('for', None),
#  ('the', None),
#  ('USMNT', None),
#  ('even', Synset('even.r.04')),
#  ('a', None),
#  ('draw', Synset('hook.n.06')),
#  ('would', None),
#  ('not', None),
#  ('be', None),
#  ('enough', None),
#  ('to', None),
#  ('see', Synset('visit.v.01')),
#  ('it', None),
#  ('progress', Synset('progress.v.01')),
#  ('from', None),
#  ('the', None),
#  ('group', Synset('group.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('had', Synset('induce.v.02')),
#  ('to', None),
#  ('battled', Synset('battle.v.01')),
#  ('hard', Synset('hard.r.10')),
#  ('for', None),
#  ('its', None),
#  ('place', Synset('topographic_point.n.01')),
#  ('in', None),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('were', Synset('embody.v.02')),
#  ('n’t', None),
#  ('too', Synset('besides.r.02')),
#  ('many', Synset('many.a.01')),
#  ('signs', Synset('sign_of_the_zodiac.n.01')),
#  ('of', None),
#  ('early', Synset('early.a.05')),
#  ('nerves', Synset('nerve.n.01')),
#  ('from', None),
#  ('the', None),
#  ('USMNT', None),
#  ('as', None),
#  ('Berhalter', None),
#  ('’s', None),
#  ('side', Synset('english.n.04')),
#  ('dictated', Synset('dictate.v.02')),
#  ('the', None),
#  ('play', Synset('gambling.n.01')),
#  ('in', None),
#  ('the', None),
#  ('opening', Synset('opening.n.05')),
#  ('stages', Synset('stage.n.08')),
#  ('–', None),
#  ('enjoying', Synset('love.v.02')),
#  ('65', None),
#  ('%', None),
#  ('of', None),
#  ('the', None),
#  ('possession', Synset('self-control.n.02')),
#  ('–', None),
#  ('though', None),
#  ('it', None),
#  ('took', Synset('take.v.20')),
#  ('until', None),
#  ('the', None),
#  ('28th', None),
#  ('minute', Synset('hour.n.04')),
#  ('for', None),
#  ('it', None),
#  ('conjure', Synset('raise.v.07')),
#  ('the', None),
#  ('first', Synset('first.a.06')),
#  ('chance', Synset('probability.n.01')),
#  ('of', None),
#  ('note', Synset('note.n.04')),
#  ('.', None),
#  ('\n\n', None),
#  ('Josh', None),
#  ('Sargeant', None),
#  ('’s', None),
#  ('long', Synset('long.a.05')),
#  ('-', None),
#  ('range', Synset('image.n.07')),
#  ('effort', Synset('campaign.n.02')),
#  ('took', Synset('take.v.34')),
#  ('a', None),
#  ('deflection', Synset('deflection.n.03')),
#  ('off', None),
#  ('an', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('defender', Synset('defender.n.02')),
#  ('and', None),
#  ('fell', Synset('fall.v.03')),
#  ('perfectly', Synset('perfectly.r.02')),
#  ('into', None),
#  ('the', None),
#  ('path', Synset('way.n.05')),
#  ('of', None),
#  ('Timothy', Synset('timothy.n.02')),
#  ('Weah', None),
#  (',', None),
#  ('who', None),
#  ('perhaps', Synset('possibly.r.01')),
#  ('did', None),
#  ('n’t', None),
#  ('realize', Synset('realize.v.06')),
#  ('he', None),
#  ('was', None),
#  ('all', Synset('wholly.r.01')),
#  ('alone', None),
#  ('in', None),
#  ('front', Synset('movement.n.04')),
#  ('of', None),
#  ('goal', Synset('goal.n.01')),
#  ('and', None),
#  ('rushed', Synset('rush.v.05')),
#  ('a', None),
#  ('headed', Synset('headed.a.03')),
#  ('effort', Synset('campaign.n.02')),
#  ('that', None),
#  ('Alireza', None),
#  ('Beiranvand', None),
#  ('in', None),
#  ('the', None),
#  ('Iran', Synset('iran.n.01')),
#  ('goal', Synset('goal.n.01')),
#  ('caught', Synset('catch.v.18')),
#  ('with', None),
#  ('ease', Synset('relief.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('On', None),
#  ('the', None),
#  ('half', Synset('half.a.03')),
#  ('hour', Synset('hour.n.04')),
#  ('mark', Synset('mark.n.05')),
#  (',', None),
#  ('Weah', None),
#  ('once', Synset('once.r.03')),
#  ('again', Synset('again.r.01')),
#  ('took', Synset('take.v.34')),
#  ('up', None),
#  ('a', None),
#  ('brilliant', None),
#  ('position', Synset('status.n.01')),
#  ('inside', None),
#  ('the', None),
#  ('box', Synset('box.n.03')),
#  ('but', None),
#  ('skied', Synset('ski.v.01')),
#  ('his', None),
#  ('effort', Synset('feat.n.01')),
#  ('well', Synset('well.r.02')),
#  ('over', None),
#  ('the', None),
#  ('crossbar', Synset('crossbar.n.02')),
#  ('after', None),
#  ('being', None),
#  ('set', Synset('set.v.08')),
#  ('up', None),
#  ('by', None),
#  ('Sargeant', None),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('’s', None),
#  ('pressure', Synset('pressure.n.05')),
#  ('eventually', Synset('finally.r.01')),
#  ('told', Synset('tell.v.07')),
#  ('seven', None),
#  ('minutes', Synset('moment.n.02')),
#  ('before', None),
#  ('half', Synset('half.a.03')),
#  ('time', Synset('prison_term.n.01')),
#  (',', None),
#  ('taking', Synset('remove.v.01')),
#  ('the', None),
#  ('lead', Synset('spark_advance.n.01')),
#  ('following', Synset('watch.v.02')),
#  ('an', None),
#  ('incisive', None),
#  ('team', Synset('team.n.02')),
#  ('move', Synset('move.n.05')),
#  ('.', None),
#  ('\n\n', None),
#  ('Weston', Synset('weston.n.01')),
#  ('McKennie', None),
#  ('’s', None),
#  ('pinpoint', Synset('pinpoint.n.03')),
#  ('cross', Synset('cross.n.03')),
#  ('field', Synset('field.n.10')),
#  ('ball', Synset('ball.n.07')),
#  ('was', None),
#  ('headed', Synset('head.v.04')),
#  ('back', Synset('back.r.02')),
#  ('across', None),
#  ('goal', Synset('goal.n.03')),
#  ('by', None),
#  ('the', None),
#  ('marauding', Synset('maraud.v.01')),
#  ('Sergiño', None),
#  ('Dest', None),
#  ('and', None),
#  ('bundled', Synset('bundle.v.04')),
#  ('home', Synset('home_plate.n.01')),
#  ('bravely', Synset('bravely.r.01')),
#  ('by', None),
#  ('Pulisic', None),
#  (',', None),
#  ('who', None),
#  ('suffered', Synset('suffer.v.11')),
#  ('a', None),
#  ('hefty', None),
#  ('collision', Synset('collision.n.03')),
#  ('with', None),
#  ('Beiranvand', None),
#  ('as', None),
#  ('he', None),
#  ('turned', Synset('plow.v.01')),
#  ('the', None),
#  ('ball', Synset('ball.n.07')),
#  ('over', None),
#  ('the', None),
#  ('line', Synset('wrinkle.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('’s', None),
#  ('delight', Synset('joy.n.02')),
#  ('swiftly', Synset('swiftly.r.01')),
#  ('turned', Synset('twist.v.10')),
#  ('to', None),
#  ('worry', Synset('worry.v.05')),
#  ('as', None),
#  ('it', None),
#  ('was', None),
#  ('evident', None),
#  ('that', None),
#  ('Pulisic', None),
#  ('was', None),
#  ('in', None),
#  ('significant', Synset('significant.a.03')),
#  ('pain', Synset('pain.n.02')),
#  ('following', Synset('take_after.v.02')),
#  ('the', None),
#  ('clash', Synset('clash.n.03')),
#  (',', None),
#  ('limping', Synset('limp.v.01')),
#  ('heavily', Synset('heavy.r.01')),
#  ('as', None),
#  ('he', None),
#  ('was', None),
#  ('helped', Synset('help.v.06')),
#  ('off', None),
#  ('the', None),
#  ('pitch', Synset('pitch.n.02')),
#  ('by', None),
#  ('two', None),
#  ('medics', Synset('medical_officer.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Pulisic', None),
#  ('soon', Synset('soon.r.01')),
#  ('re', None),
#  ('-', None),
#  ('entered', Synset('record.v.01')),
#  ('the', None),
#  ('pitch', Synset('pitch.n.01')),
#  (',', None),
#  ('but', None),
#  ('the', None),
#  ('Chelsea', None),
#  ('man', Synset('world.n.08')),
#  ('was', None),
#  ('clearly', Synset('distinctly.r.01')),
#  ('still', Synset('still.r.01')),
#  ('struggling', Synset('struggle.v.02')),
#  ('with', None),
#  ('the', None),
#  ('knock', Synset('knock.n.05')),
#  ('.', None),
#  ('\n\n', None),
#  ('Christian', Synset('christian.n.01')),
#  ('Pulisic', None),
#  ('is', None),
#  ('surrounded', Synset('wall.v.01')),
#  ('by', None),
#  ('teammates', Synset('teammate.n.01')),
#  ('after', None),
#  ('going', Synset('move.v.13')),
#  ('down', None),
#  ('injured', Synset('injure.v.01')),
#  ('following', Synset('follow.v.06')),
#  ('his', None),
#  ('goal', Synset('goal.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('As', None),
#  ('the', None),
#  ('USMNT', None),
#  ('grew', Synset('grow.v.10')),
#  ('in', None),
#  ('confidence', Synset('confidence.n.03')),
#  (',', None),
#  ('spaces', Synset('space.n.08')),
#  ('began', Synset('begin.v.08')),
#  ('to', None),
#  ('open', Synset('open.v.11')),
#  ('up', None),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('’s', None),
#  ('defense', Synset('department_of_defense.n.01')),
#  ('and', None),
#  ('Weah', None),
#  ('thought', Synset('think.v.03')),
#  ('he', None),
#  ('’d', None),
#  ('doubled', Synset('double_over.v.01')),
#  ('his', None),
#  ('team', Synset('team.n.02')),
#  ('’s', None),
#  ('lead', Synset('spark_advance.n.01')),
#  ('just', Synset('merely.r.01')),
#  ('before', None),
#  ('the', None),
#  ('interval', Synset('time_interval.n.01')),
#  (',', None),
#  ('finishing', Synset('finish.v.06')),
#  ('wonderfully', Synset('wonderfully.r.01')),
#  ('with', None),
#  ('the', None),
#  ('outside', Synset('outside.n.01')),
#  ('of', None),
#  ('his', None),
#  ('boot', Synset('boot.n.06')),
#  ('only', Synset('only.r.04')),
#  ('to', None),
#  ('be', None),
#  ('met', Synset('meet.v.09')),
#  ('by', None),
#  ('the', None),
#  ('linesman', Synset('linesman.n.01')),
#  ('’s', None),
#  ('flag', Synset('masthead.n.01')),
#  ('for', None),
#  ('the', None),
#  ('narrowest', Synset('narrow.a.04')),
#  ('of', None),
#  ('offside', Synset('offside.a.01')),
#  ('decisions', Synset('decisiveness.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Though', None),
#  ('Iran', Synset('iran.n.01')),
#  ('would', None),
#  ('have', None),
#  ('been', None),
#  ('happy', Synset('happy.a.01')),
#  ('to', None),
#  ('weather', Synset('weather.v.04')),
#  ('that', None),
#  ('first', Synset('first.a.06')),
#  ('-', None),
#  ('half', Synset('one-half.n.01')),
#  ('storm', Synset('storm.n.01')),
#  (',', None),
#  ('it', None),
#  ('was', None),
#  ('a', None),
#  ('surprisingly', Synset('surprisingly.r.01')),
#  ('subdued', None),
#  ('performance', Synset('performance.n.03')),
#  ('–', None),
#  ('in', None),
#  ('particular', None),
#  ('following', Synset('take_after.v.02')),
#  ('Pulisic', None),
#  ('’s', None),
#  ('goal', Synset('goal.n.01')),
#  ('–', None),
#  ('from', None),
#  ('a', None),
#  ('team', Synset('team.n.02')),
#  ('that', None),
#  ('had', None),
#  ('caused', Synset('induce.v.02')),
#  ('both', None),
#  ('England', Synset('england.n.01')),
#  ('and', None),
#  ('Wales', Synset('wales.n.01')),
#  ('defensive', Synset('defensive.a.01')),
#  ('problems', Synset('problem.n.01')),
#  ('in', None),
#  ('its', None),
#  ('opening', Synset('unfold.v.04')),
#  ('two', None),
#  ('matches', Synset('match.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('Iran', Synset('iran.n.01')),
#  ('did', None),
#  ('begin', Synset('begin.v.10')),
#  ('the', None),
#  ('second', Synset('second.a.02')),
#  ('half', Synset('half.n.02')),
#  ('with', None),
#  ('more', Synset('more.a.02')),
#  ('authority', Synset('authority.n.01')),
#  (',', None),
#  ('creating', Synset('make.v.03')),
#  ('two', None),
#  ('brilliant', None),
#  ('chances', Synset('probability.n.01')),
#  ('for', None),
#  ('Saman', Synset('rain_tree.n.01')),
#  ('Ghoddos', None),
#  ('but', None),
#  ('the', None),
#  ('Brentford', None),
#  ('forward', Synset('forward.r.01')),
#  ('was', None),
#  ('unable', Synset('unable.a.01')),
#  ('to', None),
#  ('trouble', Synset('trouble_oneself.v.01')),
#  ('USMNT', None),
#  ('goalkeeper', Synset('goalkeeper.n.02')),
#  ('Matt', Synset('flatness.n.04')),
#  ('Turner', Synset('turner.n.07')),
#  ('.', None),
#  ('\n\n', None),
#  ('With', None),
#  ('the', None),
#  ('clock', Synset('clock.n.01')),
#  ('ticking', Synset('tick.v.02')),
#  ('down', None),
#  (',', None),
#  ('Iran', Synset('iran.n.01')),
#  ('had', Synset('induce.v.02')),
#  ('a', None),
#  ('glorious', Synset('glorious.a.01')),
#  ('chance', Synset('probability.n.01')),
#  ('to', None),
#  ('level', Synset('level.v.02')),
#  ('the', None),
#  ('score', Synset('score.n.10')),
#  ('but', None),
#  ('Morteza', None),
#  ('Pouraliganji', None),
#  ('’s', None),
#  ('stooping', Synset('crouch.v.01')),
#  ('header', Synset('header.n.04')),
#  ('flashed', Synset('flash.v.08')),
#  ('narrowly', Synset('narrowly.r.01')),
#  ('wide', Synset('wide.r.04')),
#  ('of', None),
#  ('the', None),
#  ('far', Synset('far.r.02')),
#  ('post', Synset('post.n.09')),
#  ('much', Synset('much.a.01')),
#  ('to', None),
#  ('the', None),
#  ('relief', Synset('relief.n.10')),
#  ('of', None),
#  ('the', None),
#  ('American', Synset('american.a.02')),
#  ('fans', Synset('fan.n.01')),
#  ('in', None),
#  ('the', None),
#  ('stands', Synset('stand.n.10')),
#  (',', None),
#  ('many', Synset('many.a.01')),
#  ('who', None),
#  ('had', Synset('induce.v.02')),
#  ('their', None),
#  ('heads', Synset('head.n.25')),
#  ('in', None),
#  ('their', None),
#  ('hands', Synset('hand.n.09')),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('were', Synset('embody.v.02')),
#  ('loud', Synset('forte.a.01')),
#  ('calls', Synset('margin_call.n.01')),
#  ('for', None),
#  ('a', None),
#  ('penalty', Synset('penalty.n.04')),
#  ('from', None),
#  ('the', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('players', Synset('player.n.01')),
#  ('late', Synset('recently.r.01')),
#  ('on', Synset('on.r.03')),
#  ('in', None),
#  ('the', None),
#  ('nine', None),
#  ('minutes', Synset('minute.n.01')),
#  ('of', None),
#  ('added', Synset('add.v.01')),
#  ('time', Synset('time.n.05')),
#  (',', None),
#  ('with', None),
#  ('Mehdi', None),
#  ('Taremi', None),
#  ('insisting', Synset('insist.v.03')),
#  ('that', None),
#  ('Cameron', None),
#  ('Carter', Synset('carter.n.01')),
#  ('-', None),
#  ('Vickers', None),
#  ('had', None),
#  ('pulled', Synset('pull.v.11')),
#  ('down', None),
#  ('the', None),
#  ('Porto', Synset('porto.n.01')),
#  ('forward', Synset('ahead.r.02')),
#  ('down', Synset('down.r.03')),
#  ('as', None),
#  ('he', None),
#  ('attempted', Synset('undertake.v.01')),
#  ('to', None),
#  ('get', Synset('induce.v.02')),
#  ('on', None),
#  ('the', None),
#  ('end', Synset('goal.n.01')),
#  ('of', None),
#  ('a', None),
#  ('cross', Synset('cross.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('USA', Synset('united_states_army.n.01')),
#  ('players', Synset('player.n.01')),
#  ('celebrate', Synset('observe.v.06')),
#  ('at', None),
#  ('the', None),
#  ...]

# %% [markdown]
# [Q11] Pour tous les mots d'un texte, trouver le sens de chacun d'eux dans wordnet en utilisant l'ensemble du document pour désambiguiser le sens? Quels sont vos commentaires par rapport à une désambiguisation basée sur la phrase uniquement.

# %%
# insérer votre code ici
# Out:
# [('The', None),
#  ('US', Synset('uracil.n.01')),
#  ('Men', Synset('man.n.08')),
#  ('’s', None),
#  ('National', Synset('national.n.01')),
#  ('Team', Synset('team.n.02')),
#  ('(', None),
#  ('USMNT', None),
#  (')', None),
#  ('was', None),
#  ('made', Synset('make.v.42')),
#  ('to', None),
#  ('work', Synset('work.v.09')),
#  ('hard', Synset('hard.r.10')),
#  ('for', None),
#  ('its', None),
#  ('place', Synset('topographic_point.n.01')),
#  ('in', None),
#  ('the', None),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  ('knockout', Synset('smasher.n.02')),
#  ('stage', Synset('stage.n.03')),
#  (',', None),
#  ('earning', Synset('gain.v.08')),
#  ('a', None),
#  ('tough', Synset('tough.a.01')),
#  ('1', None),
#  ('-', None),
#  ('0', None),
#  ('win', Synset('win.n.01')),
#  ('over', None),
#  ('Iran', Synset('iran.n.01')),
#  ('in', None),
#  ('a', None),
#  ('nerve', Synset('nerve.n.01')),
#  ('-', None),
#  ('racking', Synset('rack.v.10')),
#  ('Group', Synset('group.n.03')),
#  ('B', Synset('barn.n.02')),
#  ('decider', None),
#  ('at', None),
#  ('Qatar', Synset('qatar.n.01')),
#  ('2022', None),
#  ('.', None),
#  ('\n\n', None),
#  ('Christian', Synset('christian.n.01')),
#  ('Pulisic', None),
#  ('’s', None),
#  ('first', Synset('first.a.01')),
#  ('-', None),
#  ('half', Synset('half.n.02')),
#  ('goal', Synset('goal.n.03')),
#  ('was', None),
#  ('all', None),
#  ('that', None),
#  ('separated', Synset('branch.v.02')),
#  ('the', None),
#  ('two', None),
#  ('sides', Synset('english.n.04')),
#  ('as', None),
#  ('the', None),
#  ('USMNT', None),
#  ('reached', Synset('reach.v.03')),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  ('for', None),
#  ('the', None),
#  ('first', Synset('first.a.01')),
#  ('time', Synset('time.n.05')),
#  ('since', None),
#  ('2014', None),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('pressure', Synset('pressure.n.05')),
#  ('was', None),
#  ('certainly', Synset('surely.r.01')),
#  ('on', Synset('on.r.03')),
#  ('for', None),
#  ('Gregg', None),
#  ('Berhalter', None),
#  ('’s', None),
#  ('side', Synset('english.n.04')),
#  ('in', None),
#  ('Qatar', Synset('qatar.n.01')),
#  ('after', None),
#  ('the', None),
#  ('national', Synset('national.a.02')),
#  ('team', Synset('team.n.02')),
#  ('’s', None),
#  ('failure', Synset('failure.n.04')),
#  ('to', None),
#  ('qualify', Synset('stipulate.v.01')),
#  ('for', None),
#  ('the', None),
#  ('2018', None),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  (',', None),
#  ('but', None),
#  ('the', None),
#  ('US', Synset('uracil.n.01')),
#  ('got', Synset('get.v.14')),
#  ('the', None),
#  ('job', Synset('job.n.02')),
#  ('done', Synset('serve.v.09')),
#  ('with', None),
#  ('three', None),
#  ('gritty', None),
#  ('group', Synset('group.n.03')),
#  ('performances', Synset('performance.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('It', None),
#  ('certainly', Synset('surely.r.01')),
#  ('was', None),
#  ('n’t', None),
#  ('pretty', None),
#  ('at', None),
#  ('times', Synset('time.n.05')),
#  (',', None),
#  ('in', None),
#  ('particular', None),
#  ('in', None),
#  ('the', None),
#  ('closing', Synset('shutting.n.01')),
#  ('stages', Synset('stage.n.03')),
#  ('against', None),
#  ('Iran', Synset('iran.n.01')),
#  (',', None),
#  ('but', None),
#  ('progressing', Synset('advance.v.01')),
#  ('through', None),
#  ('the', None),
#  ('group', Synset('group.n.03')),
#  ('stage', Synset('stage.n.03')),
#  ('was', None),
#  ('the', None),
#  ('minimum', Synset('minimal.a.01')),
#  ('expectation', Synset('expectation.n.03')),
#  ('for', None),
#  ('this', None),
#  ('exciting', Synset('exciting.a.01')),
#  ('young', Synset('young.a.01')),
#  ('team', Synset('team.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('will', None),
#  ('be', None),
#  ('some', None),
#  ('concerns', Synset('business.n.01')),
#  ('going', Synset('go.v.03')),
#  ('into', None),
#  ('the', None),
#  ('knockout', Synset('smasher.n.02')),
#  ('stages', Synset('stage.n.03')),
#  (',', None),
#  ('though', Synset('though.r.01')),
#  (',', None),
#  ('after', None),
#  ('Pulisic', None),
#  ('suffered', Synset('suffer.v.11')),
#  ('an', None),
#  ('abdominal', Synset('abdominal.a.01')),
#  ('injury', Synset('injury.n.01')),
#  ('while', None),
#  ('scoring', Synset('score.v.06')),
#  ('the', None),
#  ('winner', Synset('achiever.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('will', None),
#  ('be', None),
#  ('hoping', Synset('hope.v.03')),
#  ('its', None),
#  ('star', Synset('star.n.05')),
#  ('man', Synset('man.n.08')),
#  (',', None),
#  ('dubbed', Synset('dub.v.02')),
#  ('‘', None),
#  ('Captain', Synset('captain.n.07')),
#  ('America', Synset('united_states.n.01')),
#  ('’', None),
#  ('by', None),
#  ('some', None),
#  (',', None),
#  ('is', None),
#  ('fit', Synset('fit.a.01')),
#  ('for', None),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  ('tie', Synset('tie.n.07')),
#  ('against', None),
#  ('the', None),
#  ('Netherlands', Synset('netherlands.n.01')),
#  ('on', None),
#  ('Saturday', Synset('saturday.n.01')),
#  ('following', Synset('follow.v.10')),
#  ('the', None),
#  ('news', Synset('newsworthiness.n.01')),
#  ('that', None),
#  ('Pulisic', None),
#  ('had', None),
#  ('been', None),
#  ('sent', Synset('commit.v.03')),
#  ('to', None),
#  ('hospital', Synset('hospital.n.02')),
#  ('for', None),
#  ('a', None),
#  ('scan', Synset('scan.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Weston', Synset('weston.n.01')),
#  ('McKennie', None),
#  ('and', None),
#  ('Tyler', Synset('tyler.n.01')),
#  ('Adams', Synset('adam.n.01')),
#  ('celebrate', Synset('observe.v.06')),
#  ('the', None),
#  ('opening', Synset('opening.n.12')),
#  ('goal', Synset('goal.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('Winner', Synset('achiever.n.01')),
#  ('takes', Synset('take.v.34')),
#  ('all', None),
#  ('\n\n', None),
#  ('This', None),
#  ('was', None),
#  ('the', None),
#  ('only', Synset('only.r.04')),
#  ('the', None),
#  ('third', None),
#  ('meeting', Synset('meeting.n.04')),
#  ('ever', Synset('always.r.01')),
#  ('between', None),
#  ('the', None),
#  ('two', None),
#  ('nations', Synset('nation.n.03')),
#  ('and', None),
#  ('their', None),
#  ('first', Synset('first.a.01')),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  ('encounter', Synset('encounter.n.03')),
#  ('since', None),
#  ('France', Synset('france.n.01')),
#  ('1998', None),
#  ('–', None),
#  ('a', None),
#  ('politically', Synset('politically.r.01')),
#  ('charged', Synset('charge.v.24')),
#  ('match', Synset('peer.n.01')),
#  ('that', None),
#  ('saw', Synset('visit.v.01')),
#  ('Iran', Synset('iran.n.01')),
#  ('emerge', Synset('emerge.v.04')),
#  ('as', None),
#  ('a', None),
#  ('shock', Synset('shock.n.07')),
#  ('2', None),
#  ('-', None),
#  ('1', None),
#  ('winner', Synset('achiever.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('That', None),
#  ('was', None),
#  ('the', None),
#  ('first', Synset('first.a.01')),
#  ('time', Synset('time.n.05')),
#  ('that', None),
#  ('Iran', Synset('iran.n.01')),
#  ('and', None),
#  ('the', None),
#  ('US', Synset('uracil.n.01')),
#  (',', None),
#  ('sometimes', Synset('sometimes.r.01')),
#  ('described', Synset('report.v.01')),
#  ('officially', Synset('officially.r.01')),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('as', None),
#  ('the', None),
#  ('‘', None),
#  ('Great', Synset('great.n.01')),
#  ('Satan', Synset('satan.n.01')),
#  (',', None),
#  ('’', None),
#  ('had', None),
#  ('met', Synset('meet.v.09')),
#  ('on', None),
#  ('the', None),
#  ('football', Synset('football.n.01')),
#  ('pitch', Synset('pitch.n.08')),
#  ('and', None),
#  ('the', None),
#  ('biggest', Synset('large.a.01')),
#  ('sporting', None),
#  ('occasion', Synset('occasion.n.04')),
#  ('between', None),
#  ('the', None),
#  ('countries', Synset('area.n.01')),
#  ('since', None),
#  ('the', None),
#  ('1979', None),
#  ('revolution', Synset('revolution.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('build', Synset('human_body.n.01')),
#  ('-', None),
#  ('up', None),
#  ('to', None),
#  ('this', None),
#  ('game', Synset('game.n.09')),
#  ('in', None),
#  ('Qatar', Synset('qatar.n.01')),
#  ('has', None),
#  ('been', None),
#  ('similarly', Synset('similarly.r.01')),
#  ('tense', Synset('tense.a.02')),
#  (',', None),
#  ('with', None),
#  ('Iran', Synset('iran.n.01')),
#  ('even', Synset('even.r.03')),
#  ('calling', Synset('call.v.20')),
#  ('for', None),
#  ('the', None),
#  ('USMNT', None),
#  ('to', None),
#  ('be', None),
#  ('expelled', Synset('oust.v.01')),
#  ('from', None),
#  ('the', None),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  ('after', None),
#  ('the', None),
#  ('US', Synset('uracil.n.01')),
#  ('Soccer', Synset('soccer.n.01')),
#  ('Federation', Synset('federation.n.03')),
#  ('posted', Synset('post.v.08')),
#  ('an', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('flag', Synset('masthead.n.01')),
#  ('without', None),
#  ('the', None),
#  ('emblem', Synset('emblem.n.02')),
#  ('of', None),
#  ('the', None),
#  ('Islamic', None),
#  ('Republic', Synset('democracy.n.02')),
#  ('on', None),
#  ('its', None),
#  ('social', Synset('social.a.01')),
#  ('media', Synset('medium.n.09')),
#  ('platforms', Synset('platform.n.03')),
#  ('to', None),
#  ('show', Synset('prove.v.02')),
#  ('support', Synset('support.n.04')),
#  ('for', None),
#  ('protesters', Synset('demonstrator.n.03')),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('USMNT', None),
#  ('manager', Synset('coach.n.01')),
#  ('Berhalter', None),
#  ('and', None),
#  ('captain', Synset('captain.n.07')),
#  ('Tyler', Synset('tyler.n.01')),
#  ('Adams', Synset('adam.n.01')),
#  ('also', Synset('besides.r.02')),
#  ('faced', Synset('front.v.01')),
#  ('some', None),
#  ('tough', Synset('tough.a.01')),
#  ('questions', Synset('motion.n.05')),
#  ('from', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('journalists', Synset('journalist.n.01')),
#  ('in', None),
#  ('a', None),
#  ('fiery', None),
#  ('press', Synset('press.n.02')),
#  ('conference', Synset('league.n.01')),
#  (',', None),
#  ('fending', Synset('resist.v.04')),
#  ('off', None),
#  ('accusations', Synset('accusation.n.02')),
#  ('of', None),
#  ('hypocrisy', Synset('hypocrisy.n.02')),
#  ('and', None),
#  ('disrespect', Synset('contempt.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('furore', Synset('furor.n.02')),
#  ('surrounding', Synset('wall.v.01')),
#  ('this', None),
#  ('game', Synset('game.n.09')),
#  ('only', Synset('only.r.04')),
#  ('added', Synset('add.v.01')),
#  ('to', None),
#  ('the', None),
#  ('drama', Synset('play.n.01')),
#  ('of', None),
#  ('a', None),
#  ('matchup', Synset('match-up.n.01')),
#  ('that', None),
#  ('–', None),
#  ('even', Synset('even.r.03')),
#  ('in', None),
#  ('a', None),
#  ('vacuum', Synset('vacuum.n.04')),
#  ('away', Synset('away.r.01')),
#  ('from', None),
#  ('off', None),
#  ('-', None),
#  ('field', Synset('field.n.10')),
#  ('issues', Synset('consequence.n.01')),
#  ('–', None),
#  ('was', None),
#  ('guaranteed', Synset('guarantee.v.04')),
#  ('to', None),
#  ('be', None),
#  ('fraught', None),
#  ('with', None),
#  ('tension', Synset('tension.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('Both', None),
#  ('teams', Synset('team.n.02')),
#  ('knew', Synset('know.v.03')),
#  ('a', None),
#  ('win', Synset('win.n.01')),
#  ('would', None),
#  ('secure', Synset('plug.v.01')),
#  ('a', None),
#  ('place', Synset('topographic_point.n.01')),
#  ('in', None),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  (',', None),
#  ('but', None),
#  ('for', None),
#  ('the', None),
#  ('USMNT', None),
#  ('even', Synset('even.r.03')),
#  ('a', None),
#  ('draw', Synset('draw.n.07')),
#  ('would', None),
#  ('not', None),
#  ('be', None),
#  ('enough', None),
#  ('to', None),
#  ('see', Synset('visit.v.01')),
#  ('it', None),
#  ('progress', Synset('advance.v.01')),
#  ('from', None),
#  ('the', None),
#  ('group', Synset('group.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('had', Synset('get.v.03')),
#  ('to', None),
#  ('battled', Synset('battle.v.01')),
#  ('hard', Synset('hard.r.10')),
#  ('for', None),
#  ('its', None),
#  ('place', Synset('topographic_point.n.01')),
#  ('in', None),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('were', Synset('be.v.01')),
#  ('n’t', None),
#  ('too', Synset('excessively.r.01')),
#  ('many', Synset('many.a.01')),
#  ('signs', Synset('signboard.n.01')),
#  ('of', None),
#  ('early', Synset('early.a.05')),
#  ('nerves', Synset('nerve.n.01')),
#  ('from', None),
#  ('the', None),
#  ('USMNT', None),
#  ('as', None),
#  ('Berhalter', None),
#  ('’s', None),
#  ('side', Synset('english.n.04')),
#  ('dictated', Synset('dictate.v.02')),
#  ('the', None),
#  ('play', Synset('gambling.n.01')),
#  ('in', None),
#  ('the', None),
#  ('opening', Synset('opening.n.12')),
#  ('stages', Synset('stage.n.03')),
#  ('–', None),
#  ('enjoying', Synset('love.v.02')),
#  ('65', None),
#  ('%', None),
#  ('of', None),
#  ('the', None),
#  ('possession', Synset('possession.n.05')),
#  ('–', None),
#  ('though', None),
#  ('it', None),
#  ('took', Synset('take.v.34')),
#  ('until', None),
#  ('the', None),
#  ('28th', None),
#  ('minute', Synset('minute.n.01')),
#  ('for', None),
#  ('it', None),
#  ('conjure', Synset('raise.v.07')),
#  ('the', None),
#  ('first', Synset('first.a.01')),
#  ('chance', Synset('probability.n.01')),
#  ('of', None),
#  ('note', Synset('note.n.09')),
#  ('.', None),
#  ('\n\n', None),
#  ('Josh', None),
#  ('Sargeant', None),
#  ('’s', None),
#  ('long', Synset('long.a.01')),
#  ('-', None),
#  ('range', Synset('image.n.07')),
#  ('effort', Synset('campaign.n.02')),
#  ('took', Synset('take.v.34')),
#  ('a', None),
#  ('deflection', Synset('deflection.n.03')),
#  ('off', None),
#  ('an', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('defender', Synset('defender.n.02')),
#  ('and', None),
#  ('fell', Synset('descend.v.01')),
#  ('perfectly', Synset('absolutely.r.01')),
#  ('into', None),
#  ('the', None),
#  ('path', Synset('path.n.03')),
#  ('of', None),
#  ('Timothy', Synset('timothy.n.02')),
#  ('Weah', None),
#  (',', None),
#  ('who', None),
#  ('perhaps', Synset('possibly.r.01')),
#  ('did', None),
#  ('n’t', None),
#  ('realize', Synset('realize.v.06')),
#  ('he', None),
#  ('was', None),
#  ('all', Synset('wholly.r.01')),
#  ('alone', None),
#  ('in', None),
#  ('front', Synset('movement.n.04')),
#  ('of', None),
#  ('goal', Synset('goal.n.03')),
#  ('and', None),
#  ('rushed', Synset('rush.v.05')),
#  ('a', None),
#  ('headed', Synset('headed.a.03')),
#  ('effort', Synset('campaign.n.02')),
#  ('that', None),
#  ('Alireza', None),
#  ('Beiranvand', None),
#  ('in', None),
#  ('the', None),
#  ('Iran', Synset('iran.n.01')),
#  ('goal', Synset('goal.n.03')),
#  ('caught', Synset('get.v.19')),
#  ('with', None),
#  ('ease', Synset('relief.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('On', None),
#  ('the', None),
#  ('half', Synset('half.a.03')),
#  ('hour', Synset('hour.n.04')),
#  ('mark', Synset('mark.n.08')),
#  (',', None),
#  ('Weah', None),
#  ('once', Synset('once.r.03')),
#  ('again', Synset('again.r.01')),
#  ('took', Synset('take.v.34')),
#  ('up', None),
#  ('a', None),
#  ('brilliant', None),
#  ('position', Synset('position.n.07')),
#  ('inside', None),
#  ('the', None),
#  ('box', Synset('box.n.07')),
#  ('but', None),
#  ('skied', Synset('ski.v.01')),
#  ('his', None),
#  ('effort', Synset('campaign.n.02')),
#  ('well', Synset('well.r.01')),
#  ('over', None),
#  ('the', None),
#  ('crossbar', Synset('crossbar.n.02')),
#  ('after', None),
#  ('being', None),
#  ('set', Synset('set.v.16')),
#  ('up', None),
#  ('by', None),
#  ('Sargeant', None),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('’s', None),
#  ('pressure', Synset('pressure.n.05')),
#  ('eventually', Synset('finally.r.01')),
#  ('told', Synset('order.v.01')),
#  ('seven', None),
#  ('minutes', Synset('minute.n.01')),
#  ('before', None),
#  ('half', Synset('half.a.03')),
#  ('time', Synset('time.n.05')),
#  (',', None),
#  ('taking', Synset('take.v.34')),
#  ('the', None),
#  ('lead', Synset('lead.n.05')),
#  ('following', Synset('follow.v.10')),
#  ('an', None),
#  ('incisive', None),
#  ('team', Synset('team.n.02')),
#  ('move', Synset('move.n.05')),
#  ('.', None),
#  ('\n\n', None),
#  ('Weston', Synset('weston.n.01')),
#  ('McKennie', None),
#  ('’s', None),
#  ('pinpoint', Synset('pinpoint.n.03')),
#  ('cross', Synset('cross.n.03')),
#  ('field', Synset('field.n.10')),
#  ('ball', Synset('ball.n.12')),
#  ('was', None),
#  ('headed', Synset('head.v.07')),
#  ('back', Synset('back.r.04')),
#  ('across', None),
#  ('goal', Synset('goal.n.03')),
#  ('by', None),
#  ('the', None),
#  ('marauding', Synset('maraud.v.01')),
#  ('Sergiño', None),
#  ('Dest', None),
#  ('and', None),
#  ('bundled', Synset('bundle.v.04')),
#  ('home', Synset('home_plate.n.01')),
#  ('bravely', Synset('bravely.r.01')),
#  ('by', None),
#  ('Pulisic', None),
#  (',', None),
#  ('who', None),
#  ('suffered', Synset('suffer.v.11')),
#  ('a', None),
#  ('hefty', None),
#  ('collision', Synset('collision.n.01')),
#  ('with', None),
#  ('Beiranvand', None),
#  ('as', None),
#  ('he', None),
#  ('turned', Synset('turn.v.10')),
#  ('the', None),
#  ('ball', Synset('ball.n.12')),
#  ('over', None),
#  ('the', None),
#  ('line', Synset('production_line.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('’s', None),
#  ('delight', Synset('joy.n.02')),
#  ('swiftly', Synset('swiftly.r.01')),
#  ('turned', Synset('turn.v.10')),
#  ('to', None),
#  ('worry', Synset('concern.v.02')),
#  ('as', None),
#  ('it', None),
#  ('was', None),
#  ('evident', None),
#  ('that', None),
#  ('Pulisic', None),
#  ('was', None),
#  ('in', None),
#  ('significant', Synset('significant.a.03')),
#  ('pain', Synset('pain.n.02')),
#  ('following', Synset('follow.v.10')),
#  ('the', None),
#  ('clash', Synset('clash.n.03')),
#  (',', None),
#  ('limping', Synset('limp.v.01')),
#  ('heavily', Synset('heavy.r.01')),
#  ('as', None),
#  ('he', None),
#  ('was', None),
#  ('helped', Synset('serve.v.05')),
#  ('off', None),
#  ('the', None),
#  ('pitch', Synset('pitch.n.08')),
#  ('by', None),
#  ('two', None),
#  ('medics', Synset('medic.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Pulisic', None),
#  ('soon', Synset('soon.r.01')),
#  ('re', None),
#  ('-', None),
#  ('entered', Synset('figure.v.02')),
#  ('the', None),
#  ('pitch', Synset('pitch.n.08')),
#  (',', None),
#  ('but', None),
#  ('the', None),
#  ('Chelsea', None),
#  ('man', Synset('man.n.08')),
#  ('was', None),
#  ('clearly', Synset('distinctly.r.01')),
#  ('still', Synset('however.r.01')),
#  ('struggling', Synset('contend.v.06')),
#  ('with', None),
#  ('the', None),
#  ('knock', Synset('knock.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Christian', Synset('christian.n.01')),
#  ('Pulisic', None),
#  ('is', None),
#  ('surrounded', Synset('wall.v.01')),
#  ('by', None),
#  ('teammates', Synset('teammate.n.01')),
#  ('after', None),
#  ('going', Synset('go.v.03')),
#  ('down', None),
#  ('injured', Synset('hurt.v.05')),
#  ('following', Synset('follow.v.10')),
#  ('his', None),
#  ('goal', Synset('goal.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('As', None),
#  ('the', None),
#  ('USMNT', None),
#  ('grew', Synset('grow.v.10')),
#  ('in', None),
#  ('confidence', Synset('confidence.n.03')),
#  (',', None),
#  ('spaces', Synset('quad.n.03')),
#  ('began', Synset('begin.v.08')),
#  ('to', None),
#  ('open', Synset('open.v.11')),
#  ('up', None),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('’s', None),
#  ('defense', Synset('defense.n.03')),
#  ('and', None),
#  ('Weah', None),
#  ('thought', Synset('think.v.03')),
#  ('he', None),
#  ('’d', None),
#  ('doubled', Synset('double_over.v.01')),
#  ('his', None),
#  ('team', Synset('team.n.02')),
#  ('’s', None),
#  ('lead', Synset('lead.n.05')),
#  ('just', Synset('barely.r.01')),
#  ('before', None),
#  ('the', None),
#  ('interval', Synset('time_interval.n.01')),
#  (',', None),
#  ('finishing', Synset('end.v.01')),
#  ('wonderfully', Synset('wonderfully.r.01')),
#  ('with', None),
#  ('the', None),
#  ('outside', Synset('outside.n.01')),
#  ('of', None),
#  ('his', None),
#  ('boot', Synset('boot.n.05')),
#  ('only', Synset('only.r.04')),
#  ('to', None),
#  ('be', None),
#  ('met', Synset('meet.v.09')),
#  ('by', None),
#  ('the', None),
#  ('linesman', Synset('linesman.n.01')),
#  ('’s', None),
#  ('flag', Synset('masthead.n.01')),
#  ('for', None),
#  ('the', None),
#  ('narrowest', Synset('narrow.a.04')),
#  ('of', None),
#  ('offside', Synset('offside.a.01')),
#  ('decisions', Synset('decisiveness.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Though', None),
#  ('Iran', Synset('iran.n.01')),
#  ('would', None),
#  ('have', None),
#  ('been', None),
#  ('happy', Synset('happy.a.01')),
#  ('to', None),
#  ('weather', Synset('weather.v.04')),
#  ('that', None),
#  ('first', Synset('first.a.01')),
#  ('-', None),
#  ('half', Synset('half.n.02')),
#  ('storm', Synset('storm.n.01')),
#  (',', None),
#  ('it', None),
#  ('was', None),
#  ('a', None),
#  ('surprisingly', Synset('amazingly.r.01')),
#  ('subdued', None),
#  ('performance', Synset('performance.n.03')),
#  ('–', None),
#  ('in', None),
#  ('particular', None),
#  ('following', Synset('follow.v.10')),
#  ('Pulisic', None),
#  ('’s', None),
#  ('goal', Synset('goal.n.03')),
#  ('–', None),
#  ('from', None),
#  ('a', None),
#  ('team', Synset('team.n.02')),
#  ('that', None),
#  ('had', None),
#  ('caused', Synset('induce.v.02')),
#  ('both', None),
#  ('England', Synset('england.n.01')),
#  ('and', None),
#  ('Wales', Synset('wales.n.01')),
#  ('defensive', Synset('defensive.a.01')),
#  ('problems', Synset('problem.n.01')),
#  ('in', None),
#  ('its', None),
#  ('opening', Synset('open.v.11')),
#  ('two', None),
#  ('matches', Synset('peer.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Iran', Synset('iran.n.01')),
#  ('did', None),
#  ('begin', Synset('begin.v.08')),
#  ('the', None),
#  ('second', Synset('second.a.02')),
#  ('half', Synset('half.n.02')),
#  ('with', None),
#  ('more', Synset('more.a.01')),
#  ('authority', Synset('authority.n.01')),
#  (',', None),
#  ('creating', Synset('create.v.03')),
#  ('two', None),
#  ('brilliant', None),
#  ('chances', Synset('probability.n.01')),
#  ('for', None),
#  ('Saman', Synset('rain_tree.n.01')),
#  ('Ghoddos', None),
#  ('but', None),
#  ('the', None),
#  ('Brentford', None),
#  ('forward', Synset('forward.r.01')),
#  ('was', None),
#  ('unable', Synset('unable.a.01')),
#  ('to', None),
#  ('trouble', Synset('trouble_oneself.v.01')),
#  ('USMNT', None),
#  ('goalkeeper', Synset('goalkeeper.n.02')),
#  ('Matt', Synset('flatness.n.04')),
#  ('Turner', Synset('turner.n.07')),
#  ('.', None),
#  ('\n\n', None),
#  ('With', None),
#  ('the', None),
#  ('clock', Synset('clock.n.01')),
#  ('ticking', Synset('check.v.06')),
#  ('down', None),
#  (',', None),
#  ('Iran', Synset('iran.n.01')),
#  ('had', Synset('get.v.03')),
#  ('a', None),
#  ('glorious', Synset('glorious.a.01')),
#  ('chance', Synset('probability.n.01')),
#  ('to', None),
#  ('level', Synset('level.v.02')),
#  ('the', None),
#  ('score', Synset('score.n.03')),
#  ('but', None),
#  ('Morteza', None),
#  ('Pouraliganji', None),
#  ('’s', None),
#  ('stooping', Synset('crouch.v.01')),
#  ('header', Synset('heading.n.01')),
#  ('flashed', Synset('flash.v.07')),
#  ('narrowly', Synset('narrowly.r.01')),
#  ('wide', Synset('wide.r.04')),
#  ('of', None),
#  ('the', None),
#  ('far', Synset('far.r.02')),
#  ('post', Synset('post.n.09')),
#  ('much', Synset('much.a.01')),
#  ('to', None),
#  ('the', None),
#  ('relief', Synset('relief.n.10')),
#  ('of', None),
#  ('the', None),
#  ('American', Synset('american.a.01')),
#  ('fans', Synset('fan.n.01')),
#  ('in', None),
#  ('the', None),
#  ('stands', Synset('stand.n.10')),
#  (',', None),
#  ('many', Synset('many.a.01')),
#  ('who', None),
#  ('had', Synset('get.v.03')),
#  ('their', None),
#  ('heads', Synset('heading.n.01')),
#  ('in', None),
#  ('their', None),
#  ('hands', Synset('hand.n.05')),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('were', Synset('be.v.01')),
#  ('loud', Synset('forte.a.01')),
#  ('calls', Synset('margin_call.n.01')),
#  ('for', None),
#  ('a', None),
#  ('penalty', Synset('penalty.n.04')),
#  ('from', None),
#  ('the', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('players', Synset('player.n.01')),
#  ('late', Synset('late.r.03')),
#  ('on', Synset('on.r.03')),
#  ('in', None),
#  ('the', None),
#  ('nine', None),
#  ('minutes', Synset('minute.n.01')),
#  ('of', None),
#  ('added', Synset('add.v.01')),
#  ('time', Synset('time.n.05')),
#  (',', None),
#  ('with', None),
#  ('Mehdi', None),
#  ('Taremi', None),
#  ('insisting', Synset('insist.v.01')),
#  ('that', None),
#  ('Cameron', None),
#  ('Carter', Synset('carter.n.01')),
#  ('-', None),
#  ('Vickers', None),
#  ('had', None),
#  ('pulled', Synset('pull.v.09')),
#  ('down', None),
#  ('the', None),
#  ('Porto', Synset('porto.n.01')),
#  ('forward', Synset('forward.r.01')),
#  ('down', Synset('down.r.02')),
#  ('as', None),
#  ('he', None),
#  ('attempted', Synset('try.v.01')),
#  ('to', None),
#  ('get', Synset('get.v.14')),
#  ('on', None),
#  ('the', None),
#  ('end', Synset('end.n.13')),
#  ('of', None),
#  ('a', None),
#  ('cross', Synset('cross.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('USA', Synset('united_states.n.01')),
#  ('players', Synset('player.n.01')),
#  ('celebrate', Synset('observe.v.06')),
#  ('at', None),
#  ('the', None),
#  ...]

# %% [markdown]
# 7 - PROJET : Réécrire un texte avec des informations retirées de wordnet
# -----

# %% [markdown]
# [PROJET Q1] Réécrire un texte en interchangeant un mot par son antonyme. Par exemple, "petit" devient "grand" et "laideur" devient "beauté". Vous pourrez utiliser la fonction highligth_word() pour mettre en avant les mots qui ont été changés.

# %%
def highlight_word(word):
    return "\x1b[43m" + word + "\x1b[m"

# %%
# insérez votre code ici
# Out:
# The
# US
# woman Men
# ’s
# National
# Team
# (
# USMNT
# )
# was
# made
# to
# work
# hard
# for
# its
# place
# in
# the
# World
# Cup
# knockout
# stage
# ,
# earning
# a
# tender tough
# 1
# -
# 0
# win
# over
# Iran
# in
# a
# nerve
# -
# racking
# Group
# B
# decider
# at
# Qatar
# 2022
# .
#
#
#
# Christian
# Pulisic
# ’s
# last first
# -
# half
# goal
# was
# all
# that
# separated
# the
# two
# sides
# as
# the
# USMNT
# reached
# the
# round
# of
# 16
# for
# the
# last first
# time
# since
# 2014
# .
#
#
#
# The
# pressure
# was
# certainly
# on
# for
# Gregg
# Berhalter
# ’s
# side
# in
# Qatar
# after
# the
# international national
# team
# ’s
# failure
# to
# qualify
# for
# the
# 2018
# World
# Cup
# ,
# but
# the
# US
# got
# the
# job
# done
# with
# three
# gritty
# group
# performances
# .
#
#
#
# It
# certainly
# was
# n’t
# pretty
# at
# times
# ,
# in
# particular
# in
# the
# closing
# stages
# against
# Iran
# ,
# but
# withdraw progressing
# through
# the
# group
# stage
# was
# the
# maximal minimum
# expectation
# for
# this
# unexciting exciting
# old young
# team
# .
#
#
#
# There
# will
# be
# some
# concerns
# come going
# into
# the
# knockout
# stages
# ,
# though
# ,
# after
# Pulisic
# suffered
# an
# abdominal
# injury
# while
# scoring
# the
# failure winner
# .
#
#
#
# The
# USMNT
# will
# be
# hoping
# its
# star
# woman man
# ,
# dubbed
# ‘
# Captain
# America
# ’
# by
# some
# ,
# is
# unfit fit
# for
# the
# round
# of
# 16
# tie
# against
# the
# Netherlands
# on
# Saturday
# following
# the
# news
# that
# Pulisic
# had
# been
# sent
# to
# hospital
# for
# a
# scan
# .
#
#
#
# Weston
# McKennie
# and
# Tyler
# Adams
# celebrate
# the
# opening
# goal
# .
#
#
#
# failure Winner
# takes
# all
#
#
#
# This
# was
# the
# only
# the
# third
# meeting
# ever
# between
# the
# two
# nations
# and
# their
# last first
# World
# Cup
# encounter
# since
# France
# 1998
# –
# a
# politically
# charged
# match
# that
# saw
# Iran
# emerge
# as
# a
# shock
# 2
# -
# 1
# failure winner
# .
#
#
#
# That
# was
# the
# last first
# time
# that
# Iran
# and
# the
# US
# ,
# sometimes
# described
# unofficially officially
# in
# Iran
# as
# the
# ‘
# Great
# Satan
# ,
# ’
# had
# met
# on
# the
# football
# pitch
# and
# the
# small biggest
# sporting
# occasion
# between
# the
# countries
# since
# the
# 1979
# revolution
# .
#
#
#
# The
# build
# -
# up
# to
# this
# game
# in
# Qatar
# has
# been
# similarly
# lax tense
# ,
# with
# Iran
# even
# calling
# for
# the
# USMNT
# to
# be
# expelled
# from
# the
# World
# Cup
# after
# the
# US
# Soccer
# Federation
# posted
# an
# Iranian
# flag
# without
# the
# emblem
# of
# the
# Islamic
# Republic
# on
# its
# social
# media
# platforms
# to
# disprove show
# support
# for
# protesters
# in
# Iran
# .
#
#
#
# USMNT
# manager
# Berhalter
# and
# captain
# Tyler
# Adams
# also
# back faced
# some
# tender tough
# questions
# from
# Iranian
# journalists
# in
# a
# fiery
# press
# conference
# ,
# fending
# off
# accusations
# of
# hypocrisy
# and
# disrespect
# .
#
#
#
# The
# furore
# surrounding
# this
# game
# only
# take_away added
# to
# the
# drama
# of
# a
# matchup
# that
# –
# even
# in
# a
# vacuum
# away
# from
# off
# -
# field
# issues
# –
# was
# guaranteed
# to
# be
# fraught
# with
# tension
# .
#
#
#
# Both
# teams
# knew
# a
# win
# would
# secure
# a
# place
# in
# the
# round
# of
# 16
# ,
# but
# for
# the
# USMNT
# even
# a
# draw
# would
# not
# be
# enough
# to
# see
# it
# withdraw progress
# from
# the
# group
# .
#
#
#
# The
# USMNT
# had
# to
# battled
# hard
# for
# its
# place
# in
# the
# round
# of
# 16
# .
#
#
#
# There
# were
# n’t
# too
# few many
# signs
# of
# middle early
# nerves
# from
# the
# USMNT
# as
# Berhalter
# ’s
# side
# dictated
# the
# play
# in
# the
# opening
# stages
# –
# enjoying
# 65
# %
# of
# the
# possession
# –
# though
# it
# took
# until
# the
# 28th
# minute
# for
# it
# conjure
# the
# last first
# chance
# of
# note
# .
#
#
#
# Josh
# Sargeant
# ’s
# short long
# -
# range
# effort
# took
# a
# deflection
# off
# an
# Iranian
# defender
# and
# ascend fell
# perfectly
# into
# the
# path
# of
# Timothy
# Weah
# ,
# who
# perhaps
# did
# n’t
# realize
# he
# was
# partially all
# alone
# in
# front
# of
# goal
# and
# rushed
# a
# headless headed
# effort
# that
# Alireza
# Beiranvand
# in
# the
# Iran
# goal
# caught
# with
# ease
# .
#
#
#
# On
# the
# whole half
# hour
# mark
# ,
# Weah
# once
# again
# took
# up
# a
# brilliant
# position
# inside
# the
# box
# but
# skied
# his
# effort
# ill well
# over
# the
# crossbar
# after
# being
# set
# up
# by
# Sargeant
# .
#
#
#
# The
# USMNT
# ’s
# pressure
# eventually
# told
# seven
# minutes
# before
# whole half
# time
# ,
# taking
# the
# lead
# following
# an
# incisive
# team
# move
# .
#
#
#
# Weston
# McKennie
# ’s
# pinpoint
# cross
# field
# ball
# was
# headed
# ahead back
# across
# goal
# by
# the
# marauding
# Sergiño
# Dest
# and
# bundled
# home
# bravely
# by
# Pulisic
# ,
# who
# suffered
# a
# hefty
# collision
# with
# Beiranvand
# as
# he
# turned
# the
# ball
# over
# the
# line
# .
#
#
#
# The
# USMNT
# ’s
# delight
# swiftly
# turned
# to
# worry
# as
# it
# was
# evident
# that
# Pulisic
# was
# in
# nonsignificant significant
# pleasure pain
# following
# the
# clash
# ,
# limping
# heavily
# as
# he
# was
# helped
# off
# the
# pitch
# by
# two
# medics
# .
#
#
#
# Pulisic
# soon
# re
# -
# entered
# the
# pitch
# ,
# but
# the
# Chelsea
# woman man
# was
# clearly
# still
# struggling
# with
# the
# knock
# .
#
#
#
# Christian
# Pulisic
# is
# surrounded
# by
# teammates
# after
# come going
# down
# injured
# following
# his
# goal
# .
#
#
#
# As
# the
# USMNT
# grew
# in
# confidence
# ,
# spaces
# began
# to
# close open
# up
# in
# Iran
# ’s
# offense defense
# and
# Weah
# thought
# he
# ’d
# doubled
# his
# team
# ’s
# lead
# just
# before
# the
# interval
# ,
# begin finishing
# wonderfully
# with
# the
# inside outside
# of
# his
# boot
# only
# to
# be
# met
# by
# the
# linesman
# ’s
# flag
# for
# the
# wide narrowest
# of
# onside offside
# indecisiveness decisions
# .
#
#
#
# Though
# Iran
# would
# have
# been
# unhappy happy
# to
# weather
# that
# last first
# -
# half
# storm
# ,
# it
# was
# a
# surprisingly
# subdued
# performance
# –
# in
# particular
# following
# Pulisic
# ’s
# goal
# –
# from
# a
# team
# that
# had
# caused
# both
# England
# and
# Wales
# offensive defensive
# problems
# in
# its
# close opening
# two
# matches
# .
#
#
#
# Iran
# did
# begin
# the
# first second
# half
# with
# less more
# authority
# ,
# creating
# two
# brilliant
# chances
# for
# Saman
# Ghoddos
# but
# the
# Brentford
# back forward
# was
# able unable
# to
# trouble
# USMNT
# goalkeeper
# Matt
# Turner
# .
#
#
#
# With
# the
# clock
# ticking
# down
# ,
# Iran
# had
# a
# inglorious glorious
# chance
# to
# raise level
# the
# score
# but
# Morteza
# Pouraliganji
# ’s
# stooping
# header
# flashed
# broadly narrowly
# wide
# of
# the
# far
# post
# little much
# to
# the
# relief
# of
# the
# American
# fans
# in
# the
# stands
# ,
# few many
# who
# had
# their
# heads
# in
# their
# hands
# .
#
#
#
# There
# were
# piano loud
# calls
# for
# a
# penalty
# from
# the
# Iranian
# players
# late
# on
# in
# the
# nine
# minutes
# of
# take_away added
# time
# ,
# with
# Mehdi
# Taremi
# insisting
# that
# Cameron
# Carter
# -
# Vickers
# had
# pulled
# down
# the
# Porto
# back forward
# up down
# as
# he
# attempted
# to
# get
# on
# the
# end
# of
# a
# cross
# .
#
#
#
# USA
# players
# celebrate
# at
# the
# final
# whistle
# .
#
#
#
# After
# a
# brief
# ,
# lax tense
# check
# ,
# VAR
# decided
# it
# was
# n’t
# a
# penalty
# and
# soon
# after
# referee
# Mateu
# Lahoz
# blew
# his
# whistle
# to
# end
# the
# game
# .
#
#
#
# Both
# teams
# sank
# to
# the
# floor
# –
# for
# very
# difference
# reasons
# –
# but
# the
# USMNT
# will
# know
# an
# worsen improved
# performance
# is
# unnecessary necessary
# if
# it
# wants
# to
# have
# a
# chance
# of
# advancing
# further
# in
# Qatar
# .
#
#
#
# ‘
# I
# hope
# our
# fans
# …
# forgive
# us
# ’
#
#
# Following
# the
# defeat
# ,
# an
# emotional
# Saeid
# Ezatolahi
# asked
# for
# forgiveness
# from
# Iran
# fans
# .
#
#
#
# Iran
# was
# in
# a
# impotent strong
# position
# come going
# into
# the
# final
# game
# following
# that
# noncrucial crucial
# 2
# -
# 0
# win
# over
# Wales
# ,
# needing
# just
# a
# draw
# to
# progress
# ,
# but
# put
# in
# a
# disappointing
# performance
# with
# a
# place
# in
# the
# knockout
# stages
# on
# the
# line
# .
#
#
#
# “
# I
# ’m
# really
# unregretful sorry
# on
# behalf
# of
# our
# players
# ,
# our
# group
# ,
# that
# we
# could
# n’t
# get
# our
# opportunity
# to
# qualify
# for
# the
# next
# round
# ,
# ”
# the
# midfielder
# said
# .
#
#
#
# “
# Life
# and
# football
# is
# come going
# on
# and
# that
# can
# be
# a
# bad good
# lesson
# for
# us
# ,
# at
# most least
# for
# the
# old young
# players
# like
# me
# for
# the
# future
# .
# So
# I
# hope
# our
# fans
# and
# our
# people
# in
# Iran
# ,
# they
# forgive
# us
# and
# I
# feel
# just
# unregretful sorry
# ,
# that
# ’s
# it
# .
# ”
#
#
#
# Iran
# coach
# Carlos
# Quieroz
# said
# “
# the
# dream
# is
# over
# ”
# but
# is
# already
# back looking
# to
# the
# future
# .
#
#
#
# “
# The
# last first
# half
# was
# US
# and
# the
# first second
# half
# Iran
# ,
# ”
# said
# Quieroz
# ,
# who
# is
# Iran
# ’s
# longest
# -
# serving
# coach
# ,
# having
# managed
# the
# team
# from
# 2011
# to
# 2019
# ,
# before
# returning
# for
# a
# first second
# spell
# in
# charge
# in
# September
# .
#
#
#
# “
# The
# difference
# [
# was
# ]
# we
# did
# n’t
# score
# in
# the
# first second
# half
# as
# we
# should
# .
# But
# ,
# the
# dream
# is
# over
# .
# Now
# ,
# its
# thinking
# about
# the
# next
# step
# for
# Iran
# ,
# ”
# take_away added
# Quieroz
# ,
# who
# is
# the
# only
# coach
# to
# have
# led
# the
# team
# to
# consecutive
# World
# Cups
# .

# %% [markdown]
# [PROJET Q2] Réécrire un texte en interchangeant tous les mots par leur hyponyme le plus profond dans wordnet pour un contexte donné. Ainsi, pour chaque mot vous devrez (1) trouver son synset, (2) descendre dans l'arbre en choisissant le prochain synset selon la relation d'hyperonimie, (3) parmi les hyponymes possibles choisir celui qui est le plus probable selon l'algorithme de Lesk. Par exemple, "groupe" devient "sous-groupe", "chat" devient "siamois".

# %%
# insérez votre code ici
# Out:
# The
# uracil US
# man Men
# ’s
# chauvinist National
# relay Team
# (
# USMNT
# )
# was
# go_through_the_motions made
# to
# work work
# hard hard
# for
# its
# showplace place
# in
# the
# worldly_concern World
# Davis_Cup Cup
# smasher knockout
# proscenium stage
# ,
# take_home earning
# a
# tough tough
# 1
# -
# 0
# first-place_finish win
# over
# Iran Iran
# in
# a
# radial_nerve nerve
# -
# rack racking
# subgroup Group
# barn B
# decider
# at
# Qatar Qatar
# 2022
# .
#
#
#
# Melkite Christian
# Pulisic
# ’s
# first first
# -
# second_half half
# basket goal
# was
# all
# that
# twig separated
# the
# two
# English sides
# as
# the
# USMNT
# reach reached
# the
# round round
# of
# 16
# for
# the
# first first
# transmission_time time
# since
# 2014
# .
#
#
#
# The
# pressure pressure
# was
# surely certainly
# on on
# for
# Gregg
# Berhalter
# ’s
# English side
# in
# Qatar Qatar
# after
# the
# national national
# relay team
# ’s
# underdog failure
# to
# provide qualify
# for
# the
# 2018
# worldly_concern World
# Davis_Cup Cup
# ,
# but
# the
# uracil US
# get got
# the
# ball-buster job
# admit done
# with
# three
# gritty
# subgroup group
# specific_performance performances
# .
#
#
#
# It
# surely certainly
# was
# n’t
# pretty
# at
# transmission_time times
# ,
# in
# particular
# in
# the
# shutting closing
# proscenium stages
# against
# Iran Iran
# ,
# but
# ratchet progressing
# through
# the
# subgroup group
# proscenium stage
# was
# the
# minimal minimum
# suspense expectation
# for
# this
# exciting exciting
# young young
# relay team
# .
#
#
#
# There
# will
# be
# some
# commodity_brokerage concerns
# shove_off going
# into
# the
# smasher knockout
# proscenium stages
# ,
# though though
# ,
# after
# Pulisic
# suffer suffered
# an
# abdominal abdominal
# electric_shock injury
# while
# test scoring
# the
# great winner
# .
#
#
#
# The
# USMNT
# will
# be
# hope hoping
# its
# pentacle star
# man man
# ,
# dub dubbed
# ‘
# captain Captain
# United_States America
# ’
# by
# some
# ,
# is
# fit fit
# for
# the
# round round
# of
# 16
# tie tie
# against
# the
# Netherlands Netherlands
# on
# Saturday Saturday
# follow following
# the
# newsworthiness news
# that
# Pulisic
# had
# been
# hospitalize sent
# to
# hospital hospital
# for
# a
# scan scan
# .
#
#
#
# Weston Weston
# McKennie
# and
# Tyler Tyler
# Adam Adams
# mourn celebrate
# the
# opening opening
# basket goal
# .
#
#
#
# great Winner
# take takes
# all
#
#
#
# This
# was
# the
# only only
# the
# third
# site_visit meeting
# always ever
# between
# the
# two
# Nation nations
# and
# their
# first first
# worldly_concern World
# Davis_Cup Cup
# encounter encounter
# since
# France France
# 1998
# –
# a
# politically politically
# recharge charged
# surrogate match
# that
# take_in saw
# Iran Iran
# emerge emerge
# as
# a
# shock shock
# 2
# -
# 1
# great winner
# .
#
#
#
# That
# was
# the
# first first
# transmission_time time
# that
# Iran Iran
# and
# the
# uracil US
# ,
# sometimes sometimes
# report described
# officially officially
# in
# Iran Iran
# as
# the
# ‘
# great Great
# Satan Satan
# ,
# ’
# had
# meet_up_with met
# on
# the
# touch_football football
# pitch pitch
# and
# the
# large biggest
# sporting
# meal occasion
# between
# the
# rain_shadow countries
# since
# the
# 1979
# counterrevolution revolution
# .
#
#
#
# The
# adult_male_body build
# -
# up
# to
# this
# tangram game
# in
# Qatar Qatar
# has
# been
# similarly similarly
# tense tense
# ,
# with
# Iran Iran
# even even
# call calling
# for
# the
# USMNT
# to
# be
# excommunicate expelled
# from
# the
# worldly_concern World
# Davis_Cup Cup
# after
# the
# uracil US
# soccer Soccer
# federation Federation
# post posted
# an
# Iranian Iranian
# masthead flag
# without
# the
# swastika emblem
# of
# the
# Islamic
# Weimar_Republic Republic
# on
# its
# social social
# medium media
# platform platforms
# to
# stultify show
# close_support support
# for
# picket protesters
# in
# Iran Iran
# .
#
#
#
# USMNT
# line_coach manager
# Berhalter
# and
# captain captain
# Tyler Tyler
# Adam Adams
# besides also
# confront faced
# some
# tough tough
# motion questions
# from
# Iranian Iranian
# photojournalist journalists
# in
# a
# fiery
# trade_magazine press
# Ivy_League conference
# ,
# resist fending
# off
# countercharge accusations
# of
# sanctimoniousness hypocrisy
# and
# contempt disrespect
# .
#
#
#
# The
# brouhaha furore
# stockade surrounding
# this
# tangram game
# only only
# include added
# to
# the
# theater_of_the_absurd drama
# of
# a
# match-up matchup
# that
# –
# even even
# in
# a
# Hoover vacuum
# away away
# from
# off
# -
# scalar_field field
# placebo_effect issues
# –
# was
# certify guaranteed
# to
# be
# fraught
# with
# tension tension
# .
#
#
#
# Both
# relay teams
# anticipate knew
# a
# first-place_finish win
# would
# stopper secure
# a
# showplace place
# in
# the
# round round
# of
# 16
# ,
# but
# for
# the
# USMNT
# even even
# a
# draw draw
# would
# not
# be
# enough
# to
# take_in see
# it
# ratchet progress
# from
# the
# subgroup group
# .
#
#
#
# The
# USMNT
# get had
# to
# dogfight battled
# hard hard
# for
# its
# showplace place
# in
# the
# round round
# of
# 16
# .
#
#
#
# There
# lend were
# n’t
# excessively too
# many many
# sandwich_board signs
# of
# early early
# radial_nerve nerves
# from
# the
# USMNT
# as
# Berhalter
# ’s
# English side
# dictate dictated
# the
# flip play
# in
# the
# opening opening
# proscenium stages
# –
# get_off enjoying
# 65
# %
# of
# the
# possession possession
# –
# though
# it
# take took
# until
# the
# 28th
# minute minute
# for
# it
# anoint conjure
# the
# first first
# exceedance chance
# of
# note_receivable note
# .
#
#
#
# Josh
# Sargeant
# ’s
# long long
# -
# image range
# charm_campaign effort
# take took
# a
# deflection deflection
# off
# an
# Iranian Iranian
# defender defender
# and
# stoop fell
# absolutely perfectly
# into
# the
# traffic_pattern path
# of
# Timothy Timothy
# Weah
# ,
# who
# possibly perhaps
# did
# n’t
# realize realize
# he
# was
# wholly all
# alone
# in
# Free_French front
# of
# basket goal
# and
# rush rushed
# a
# headed headed
# charm_campaign effort
# that
# Alireza
# Beiranvand
# in
# the
# Iran Iran
# basket goal
# get caught
# with
# reprieve ease
# .
#
#
#
# On
# the
# half half
# hour hour
# Mark mark
# ,
# Weah
# once once
# again again
# take took
# up
# a
# brilliant
# dead_center position
# inside
# the
# batter's_box box
# but
# slalom skied
# his
# charm_campaign effort
# well well
# over
# the
# crossbar crossbar
# after
# being
# set set
# up
# by
# Sargeant
# .
#
#
#
# The
# USMNT
# ’s
# pressure pressure
# finally eventually
# warn told
# seven
# minute minutes
# before
# half half
# transmission_time time
# ,
# take taking
# the
# lead lead
# follow following
# an
# incisive
# relay team
# gambit move
# .
#
#
#
# Weston Weston
# McKennie
# ’s
# pinpoint pinpoint
# Lorraine_cross cross
# scalar_field field
# ball ball
# was
# pinnacle headed
# back back
# across
# basket goal
# by
# the
# maraud marauding
# Sergiño
# Dest
# and
# bundle bundled
# home_plate home
# bravely bravely
# by
# Pulisic
# ,
# who
# suffer suffered
# a
# hefty
# collision collision
# with
# Beiranvand
# as
# he
# evert turned
# the
# ball ball
# over
# the
# production_line line
# .
#
#
#
# The
# USMNT
# ’s
# joy delight
# swiftly swiftly
# evert turned
# to
# concern worry
# as
# it
# was
# evident
# that
# Pulisic
# was
# in
# significant significant
# unpleasantness pain
# follow following
# the
# clash clash
# ,
# limp limping
# heavy heavily
# as
# he
# was
# serve helped
# off
# the
# pitch pitch
# by
# two
# moon_trefoil medics
# .
#
#
#
# Pulisic
# soon soon
# re
# -
# figure entered
# the
# pitch pitch
# ,
# but
# the
# Chelsea
# man man
# was
# distinctly clearly
# however still
# settle struggling
# with
# the
# knock knock
# .
#
#
#
# Melkite Christian
# Pulisic
# is
# stockade surrounded
# by
# teammate teammates
# after
# shove_off going
# down
# sting injured
# follow following
# his
# basket goal
# .
#
#
#
# As
# the
# USMNT
# grow grew
# in
# confidence confidence
# ,
# hair_space spaces
# begin began
# to
# open open
# up
# in
# Iran Iran
# ’s
# defense defense
# and
# Weah
# brainstorm thought
# he
# ’d
# double_over doubled
# his
# relay team
# ’s
# lead lead
# barely just
# before
# the
# lunitidal_interval interval
# ,
# lapse finishing
# wonderfully wonderfully
# with
# the
# outdoors outside
# of
# his
# boot boot
# only only
# to
# be
# meet_up_with met
# by
# the
# linesman linesman
# ’s
# masthead flag
# for
# the
# narrow narrowest
# of
# offside offside
# decisiveness decisions
# .
#
#
#
# Though
# Iran Iran
# would
# have
# been
# happy happy
# to
# weather weather
# that
# first first
# -
# second_half half
# firestorm storm
# ,
# it
# was
# a
# amazingly surprisingly
# subdued
# specific_performance performance
# –
# in
# particular
# follow following
# Pulisic
# ’s
# basket goal
# –
# from
# a
# relay team
# that
# had
# solicit caused
# both
# England England
# and
# Wales Wales
# defensive defensive
# race_problem problems
# in
# its
# open opening
# two
# surrogate matches
# .
#
#
#
# Iran Iran
# did
# begin begin
# the
# second second
# second_half half
# with
# more more
# power_of_appointment authority
# ,
# build creating
# two
# brilliant
# exceedance chances
# for
# rain_tree Saman
# Ghoddos
# but
# the
# Brentford
# forward forward
# was
# unable unable
# to
# trouble_oneself trouble
# USMNT
# goalkeeper goalkeeper
# flatness Matt
# turner Turner
# .
#
#
#
# With
# the
# turret_clock clock
# receipt ticking
# down
# ,
# Iran Iran
# get had
# a
# glorious glorious
# exceedance chance
# to
# bulldoze level
# the
# stroke score
# but
# Morteza
# Pouraliganji
# ’s
# squinch stooping
# title header
# flash flashed
# narrowly narrowly
# wide wide
# of
# the
# far far
# winning_post post
# much much
# to
# the
# alto_relievo relief
# of
# the
# American American
# punkah fans
# in
# the
# bleachers stands
# ,
# many many
# who
# get had
# their
# title heads
# in
# their
# hand hands
# .
#
#
#
# There
# lend were
# forte loud
# margin_call calls
# for
# a
# game_misconduct penalty
# from
# the
# Iranian Iranian
# playmaker players
# late late
# on on
# in
# the
# nine
# minute minutes
# of
# include added
# transmission_time time
# ,
# with
# Mehdi
# Taremi
# hunker_down insisting
# that
# Cameron
# Carter Carter
# -
# Vickers
# had
# pull pulled
# down
# the
# Porto Porto
# forward forward
# down down
# as
# he
# luck_it attempted
# to
# get get
# on
# the
# fag_end end
# of
# a
# Lorraine_cross cross
# .
#
#
#
# United_States USA
# playmaker players
# mourn celebrate
# at
# the
# final
# factory_whistle whistle
# .
#
#
#
# After
# a
# brief
# ,
# tense tense
# check check
# ,
# volt-ampere VAR
# court-martial decided
# it
# was
# n’t
# a
# game_misconduct penalty
# and
# soon soon
# after
# referee referee
# Mateu
# Lahoz
# whiff blew
# his
# factory_whistle whistle
# to
# end end
# the
# tangram game
# .
#
#
#
# Both
# relay teams
# sink sank
# to
# the
# floor floor
# –
# for
# very
# compensating_balance difference
# rationality reasons
# –
# but
# the
# USMNT
# will
# anticipate know
# an
# snap_back improved
# specific_performance performance
# is
# necessary necessary
# if
# it
# want wants
# to
# get have
# a
# exceedance chance
# of
# help advancing
# far further
# in
# Qatar Qatar
# .
#
#
#
# ‘
# I
# hope hope
# our
# punkah fans
# …
# forgive forgive
# us
# ’
#
#
# follow Following
# the
# frustration defeat
# ,
# an
# emotional emotional
# Saeid
# Ezatolahi
# interrogate asked
# for
# forgiveness forgiveness
# from
# Iran Iran
# punkah fans
# .
#
#
#
# Iran Iran
# was
# in
# a
# potent strong
# dead_center position
# shove_off going
# into
# the
# final
# tangram game
# follow following
# that
# crucial crucial
# 2
# -
# 0
# first-place_finish win
# over
# Wales Wales
# ,
# need needing
# barely just
# a
# draw draw
# to
# leapfrog progress
# ,
# but
# put_to_sleep put
# in
# a
# disappointing
# specific_performance performance
# with
# a
# showplace place
# in
# the
# smasher knockout
# proscenium stages
# on
# the
# production_line line
# .
#
#
#
# “
# I
# ’m
# very really
# regretful sorry
# on
# behalf behalf
# of
# our
# playmaker players
# ,
# our
# subgroup group
# ,
# that
# we
# could
# n’t
# get get
# our
# hearing opportunity
# to
# provide qualify
# for
# the
# next
# round round
# ,
# ”
# the
# midfielder
# warn said
# .
#
#
#
# “
# life Life
# and
# touch_football football
# is
# shove_off going
# on
# and
# that
# can
# be
# a
# good good
# moral lesson
# for
# us
# ,
# at
# least least
# for
# the
# young young
# playmaker players
# like
# me
# for
# the
# future future
# .
# therefore So
# I
# hope hope
# our
# punkah fans
# and
# our
# people people
# in
# Iran Iran
# ,
# they
# forgive forgive
# us
# and
# I
# glow feel
# barely just
# regretful sorry
# ,
# that
# ’s
# it
# .
# ”
#
#
#
# Iran Iran
# line_coach coach
# Sanchez Carlos
# Quieroz
# warn said
# “
# the
# pipe_dream dream
# is
# over over
# ”
# but
# is
# already already
# confront looking
# to
# the
# future future
# .
#
#
#
# “
# The
# first first
# second_half half
# was
# uracil US
# and
# the
# second second
# second_half half
# Iran Iran
# ,
# ”
# warn said
# Quieroz
# ,
# who
# is
# Iran Iran
# ’s
# long longest
# -
# ace serving
# line_coach coach
# ,
# having
# pontificate managed
# the
# relay team
# from
# 2011
# to
# 2019
# ,
# before
# boomerang returning
# for
# a
# second second
# go spell
# in
# rocket_fuel charge
# in
# September September
# .
#
#
#
# “
# The
# compensating_balance difference
# [
# was
# ]
# we
# did
# n’t
# test score
# in
# the
# second second
# second_half half
# as
# we
# should
# .
# But
# ,
# the
# pipe_dream dream
# is
# over over
# .
# now Now
# ,
# its
# divergent_thinking thinking
# about
# the
# next
# corbel_step step
# for
# Iran Iran
# ,
# ”
# include added
# Quieroz
# ,
# who
# is
# the
# only
# line_coach coach
# to
# have
# conduct led
# the
# relay team
# to
# consecutive
# worldly_concern World
# Davis_Cup Cups
# .

# %% [markdown]
# [PROJET Q3] Réécrire un texte écrit en anglais en interchangeant tous les mots par leurs correspondants en français, en italien ou en espagnol. Cela revient à avoir un traducteur mot à mot. Par exemple, "group" devient "groupe", "cat" devient "chat".

# %%
# insérez votre code ici
# Out:
# The
# uracile US
# homme Men
# ’s
# sujet National
# attelage Team
# (
# USMNT
# )
# was
# faire made
# to
# fonctionner work
# dur hard
# for
# its
# endroit place
# in
# the
# monde World
# coupe Cup
# beauté knockout
# estrade stage
# ,
# comprendre earning
# a
# difficile tough
# 1
# -
# 0
# gagnant win
# over
# Abadan Iran
# in
# a
# nerf nerve
# -
# racking
# ensemble Group
# b B
# decider
# at
# Katar Qatar
# 2022
# .
#
#
#
# Christian Christian
# Pulisic
# ’s
# premier first
# -
# mi-temps half
# but goal
# was
# all
# that
# bifurcation separated
# the
# two
# anglais sides
# as
# the
# USMNT
# atteindre reached
# the
# rond round
# of
# 16
# for
# the
# premier first
# durée time
# since
# 2014
# .
#
#
#
# The
# oppression pressure
# was
# absolument certainly
# autour on
# for
# Gregg
# Berhalter
# ’s
# anglais side
# in
# Katar Qatar
# after
# the
# national national
# attelage team
# ’s
# manque failure
# to
# condition qualify
# for
# the
# 2018
# monde World
# coupe Cup
# ,
# but
# the
# uracile US
# avoir got
# the
# travail job
# faire done
# with
# three
# gritty
# ensemble group
# exécution performances
# .
#
#
#
# It
# absolument certainly
# was
# n’t
# pretty
# at
# durée times
# ,
# in
# particular
# in
# the
# closing
# estrade stages
# against
# Abadan Iran
# ,
# but
# arriver progressing
# through
# the
# ensemble group
# estrade stage
# was
# the
# minimal minimum
# anticipation expectation
# for
# this
# captivant exciting
# immature young
# attelage team
# .
#
#
#
# There
# will
# be
# some
# entreprise concerns
# aller going
# into
# the
# beauté knockout
# estrade stages
# ,
# même though
# ,
# after
# Pulisic
# endurer suffered
# an
# abdominal abdominal
# blessure injury
# while
# scoring
# the
# gagnant winner
# .
#
#
#
# The
# USMNT
# will
# be
# espoir hoping
# its
# star star
# homme man
# ,
# doubler dubbed
# ‘
# capitaine Captain
# Amérique America
# ’
# by
# some
# ,
# is
# fit
# for
# the
# rond round
# of
# 16
# tie
# against
# the
# Hollande Netherlands
# on
# Samedi Saturday
# suivre following
# the
# actualité news
# that
# Pulisic
# had
# been
# institutionnaliser sent
# to
# centre_hospitalier hospital
# for
# a
# scan
# .
#
#
#
# Edward_Weston Weston
# McKennie
# and
# John_Tyler Tyler
# Adam Adams
# accomplir celebrate
# the
# opening
# but goal
# .
#
#
#
# gagnant Winner
# takes
# all
#
#
#
# This
# was
# the
# seul only
# the
# third
# assemblée meeting
# toujours ever
# between
# the
# two
# nation nations
# and
# their
# premier first
# monde World
# coupe Cup
# encounter
# since
# Brest France
# 1998
# –
# a
# politiquement politically
# charged
# allumette match
# that
# rendre_visite saw
# Abadan Iran
# donner emerge
# as
# a
# shock
# 2
# -
# 1
# gagnant winner
# .
#
#
#
# That
# was
# the
# premier first
# durée time
# that
# Abadan Iran
# and
# the
# uracile US
# ,
# des_fois sometimes
# apporter described
# formellement officially
# in
# Abadan Iran
# as
# the
# ‘
# Great
# Belzébuth Satan
# ,
# ’
# had
# assumer met
# on
# the
# ballon football
# pas pitch
# and
# the
# grand biggest
# sporting
# fois occasion
# between
# the
# aire countries
# since
# the
# 1979
# révolution revolution
# .
#
#
#
# The
# Corps_humain build
# -
# up
# to
# this
# game
# in
# Katar Qatar
# has
# been
# pareillement similarly
# temps tense
# ,
# with
# Abadan Iran
# encore even
# appeler calling
# for
# the
# USMNT
# to
# be
# expulser expelled
# from
# the
# monde World
# coupe Cup
# after
# the
# uracile US
# football Soccer
# fédération Federation
# posted
# an
# Iranien Iranian
# drapeau flag
# without
# the
# allégorie emblem
# of
# the
# Islamic
# communauté Republic
# on
# its
# social social
# milieu media
# plate-forme platforms
# to
# confirmer show
# assise support
# for
# manifestant protesters
# in
# Abadan Iran
# .
#
#
#
# USMNT
# administrateur manager
# Berhalter
# and
# capitaine captain
# John_Tyler Tyler
# Adam Adams
# aussi also
# affronter faced
# some
# difficile tough
# motion questions
# from
# Iranien Iranian
# journaliste journalists
# in
# a
# fiery
# presse press
# conférence conference
# ,
# opposer fending
# off
# accusation accusations
# of
# hypocrisie hypocrisy
# and
# disrespect
# .
#
#
#
# The
# fureur furore
# entourer surrounding
# this
# game
# seul only
# ajouter added
# to
# the
# drame drama
# of
# a
# matchup
# that
# –
# encore even
# in
# a
# aspirateur vacuum
# loin away
# from
# off
# -
# champ field
# cause issues
# –
# was
# assurer guaranteed
# to
# be
# fraught
# with
# tension
# .
#
#
#
# Both
# attelage teams
# savoir knew
# a
# gagnant win
# would
# boucher secure
# a
# endroit place
# in
# the
# rond round
# of
# 16
# ,
# but
# for
# the
# USMNT
# encore even
# a
# dessiner draw
# would
# not
# be
# enough
# to
# rendre_visite see
# it
# arriver progress
# from
# the
# ensemble group
# .
#
#
#
# The
# USMNT
# avoir had
# to
# bataille battled
# dur hard
# for
# its
# endroit place
# in
# the
# rond round
# of
# 16
# .
#
#
#
# There
# être were
# n’t
# abusivement too
# beaucoup many
# enseigne signs
# of
# ancien early
# nerf nerves
# from
# the
# USMNT
# as
# Berhalter
# ’s
# anglais side
# dicter dictated
# the
# jeu play
# in
# the
# opening
# estrade stages
# –
# aimer enjoying
# 65
# %
# of
# the
# bien possession
# –
# though
# it
# took
# until
# the
# 28th
# min minute
# for
# it
# hérisser conjure
# the
# premier first
# probabilité chance
# of
# Moyen_de_paiement note
# .
#
#
#
# Josh
# Sargeant
# ’s
# long long
# -
# range
# campagne effort
# took
# a
# deflection
# off
# an
# Iranien Iranian
# défenseur defender
# and
# baisser fell
# absolument perfectly
# into
# the
# chemin path
# of
# Fête Timothy
# Weah
# ,
# who
# peut-être perhaps
# did
# n’t
# constater realize
# he
# was
# bien all
# alone
# in
# mouvement_social front
# of
# but goal
# and
# rushed
# a
# headed
# campagne effort
# that
# Alireza
# Beiranvand
# in
# the
# Abadan Iran
# but goal
# atteindre caught
# with
# allégement ease
# .
#
#
#
# On
# the
# demi half
# heure hour
# Jack_Sholder mark
# ,
# Weah
# anciennement once
# de_nouveau again
# took
# up
# a
# brilliant
# place position
# inside
# the
# cadre box
# but
# skier skied
# his
# campagne effort
# alors well
# over
# the
# crossbar
# after
# being
# fixer set
# up
# by
# Sargeant
# .
#
#
#
# The
# USMNT
# ’s
# oppression pressure
# eventually
# dire told
# seven
# min minutes
# before
# demi half
# durée time
# ,
# taking
# the
# plomb lead
# suivre following
# an
# incisive
# attelage team
# coup move
# .
#
#
#
# Edward_Weston Weston
# McKennie
# ’s
# pinpoint
# croix cross
# champ field
# bal ball
# was
# tête headed
# dos back
# across
# but goal
# by
# the
# marauding
# Sergiño
# Dest
# and
# bundled
# assiette home
# audacieusement bravely
# by
# Pulisic
# ,
# who
# endurer suffered
# a
# hefty
# collision collision
# with
# Beiranvand
# as
# he
# devenir turned
# the
# bal ball
# over
# the
# chaîne_de_production line
# .
#
#
#
# The
# USMNT
# ’s
# allégresse delight
# rapidement swiftly
# devenir turned
# to
# agir worry
# as
# it
# was
# evident
# that
# Pulisic
# was
# in
# significatif significant
# douleur pain
# suivre following
# the
# affrontement clash
# ,
# boiter limping
# gauchement heavily
# as
# he
# was
# servir helped
# off
# the
# pas pitch
# by
# two
# 1 medics
# .
#
#
#
# Pulisic
# bientôt soon
# re
# -
# comprendre entered
# the
# pas pitch
# ,
# but
# the
# Chelsea
# homme man
# was
# clairement clearly
# cependant still
# batailler struggling
# with
# the
# coup knock
# .
#
#
#
# Christian Christian
# Pulisic
# is
# entourer surrounded
# by
# compagnon teammates
# after
# aller going
# down
# blesser injured
# suivre following
# his
# but goal
# .
#
#
#
# As
# the
# USMNT
# accroître grew
# in
# foi confidence
# ,
# espace spaces
# commencer began
# to
# ouvert open
# up
# in
# Abadan Iran
# ’s
# défense defense
# and
# Weah
# cogiter thought
# he
# ’d
# double doubled
# his
# attelage team
# ’s
# plomb lead
# guère just
# before
# the
# intervalle interval
# ,
# achever finishing
# admirablement wonderfully
# with
# the
# dehors outside
# of
# his
# botte boot
# seul only
# to
# be
# assumer met
# by
# the
# linesman
# ’s
# drapeau flag
# for
# the
# étroit narrowest
# of
# hors-jeu offside
# décision decisions
# .
#
#
#
# Though
# Abadan Iran
# would
# have
# been
# heureux happy
# to
# temps weather
# that
# premier first
# -
# mi-temps half
# orage storm
# ,
# it
# was
# a
# brillamment surprisingly
# subdued
# exécution performance
# –
# in
# particular
# suivre following
# Pulisic
# ’s
# but goal
# –
# from
# a
# attelage team
# that
# had
# causer caused
# both
# Angleterre England
# and
# Cambrie Wales
# défensif defensive
# problème problems
# in
# its
# ouvert opening
# two
# allumette matches
# .
#
#
#
# Abadan Iran
# did
# commencer begin
# the
# deuxième second
# mi-temps half
# with
# plus more
# autorité authority
# ,
# créer creating
# two
# brilliant
# probabilité chances
# for
# Saman
# Ghoddos
# but
# the
# Brentford
# forward
# was
# incapable unable
# to
# déranger trouble
# USMNT
# gardien_de_but goalkeeper
# Matt
# Turner
# .
#
#
#
# With
# the
# horloge clock
# cocher ticking
# down
# ,
# Abadan Iran
# avoir had
# a
# fameux glorious
# probabilité chance
# to
# abattre level
# the
# nombre score
# but
# Morteza
# Pouraliganji
# ’s
# arc stooping
# en-tête header
# flash flashed
# justement narrowly
# ample wide
# of
# the
# loin far
# courrier post
# beaucoup much
# to
# the
# relief relief
# of
# the
# Américain American
# ventilateur fans
# in
# the
# être_debout stands
# ,
# beaucoup many
# who
# avoir had
# their
# en-tête heads
# in
# their
# main hands
# .
#
#
#
# There
# être were
# molle loud
# appeler calls
# for
# a
# peine penalty
# from
# the
# Iranien Iranian
# joueur players
# tard late
# autour on
# in
# the
# nine
# min minutes
# of
# ajouter added
# durée time
# ,
# with
# Mehdi
# Taremi
# insister insisting
# that
# Cameron
# Carter
# -
# Vickers
# had
# tirer pulled
# down
# the
# Porto Porto
# forward
# down
# as
# he
# chercher attempted
# to
# avoir get
# on
# the
# solde end
# of
# a
# croix cross
# .
#
#
#
# Amérique USA
# joueur players
# accomplir celebrate
# at
# the
# final
# whistle
# .
#
#
#
# After
# a
# brief
# ,
# temps tense
# cocher check
# ,
# Voltampère VAR
# décider decided
# it
# was
# n’t
# a
# peine penalty
# and
# bientôt soon
# after
# arbitre referee
# Mateu
# Lahoz
# souffler blew
# his
# whistle
# to
# terminer end
# the
# game
# .
#
#
#
# Both
# attelage teams
# enfoncer sank
# to
# the
# niveau floor
# –
# for
# very
# différence difference
# cause reasons
# –
# but
# the
# USMNT
# will
# savoir know
# an
# amender improved
# exécution performance
# is
# nécessaire necessary
# if
# it
# requérir wants
# to
# avoir have
# a
# probabilité chance
# of
# améliorer advancing
# loin further
# in
# Katar Qatar
# .
#
#
#
# ‘
# I
# espoir hope
# our
# ventilateur fans
# …
# excuser forgive
# us
# ’
#
#
# suivre Following
# the
# défaite defeat
# ,
# an
# émotionnel emotional
# Saeid
# Ezatolahi
# demander asked
# for
# forgiveness
# from
# Abadan Iran
# ventilateur fans
# .
#
#
#
# Abadan Iran
# was
# in
# a
# fort strong
# place position
# aller going
# into
# the
# final
# game
# suivre following
# that
# considérable crucial
# 2
# -
# 0
# gagnant win
# over
# Cambrie Wales
# ,
# avoir_besoin_de needing
# guère just
# a
# dessiner draw
# to
# progression progress
# ,
# but
# accorder put
# in
# a
# disappointing
# exécution performance
# with
# a
# endroit place
# in
# the
# beauté knockout
# estrade stages
# on
# the
# chaîne_de_production line
# .
#
#
#
# “
# I
# ’m
# réel really
# mal sorry
# on
# nom behalf
# of
# our
# joueur players
# ,
# our
# ensemble group
# ,
# that
# we
# could
# n’t
# avoir get
# our
# chance opportunity
# to
# condition qualify
# for
# the
# next
# rond round
# ,
# ”
# the
# midfielder
# dire said
# .
#
#
#
# “
# existence Life
# and
# ballon football
# is
# aller going
# on
# and
# that
# can
# be
# a
# bon good
# enseignement lesson
# for
# us
# ,
# at
# moindre least
# for
# the
# immature young
# joueur players
# like
# me
# for
# the
# avenir future
# .
# ainsi So
# I
# espoir hope
# our
# ventilateur fans
# and
# our
# peuple people
# in
# Abadan Iran
# ,
# they
# excuser forgive
# us
# and
# I
# ressentir feel
# guère just
# mal sorry
# ,
# that
# ’s
# it
# .
# ”
#
#
#
# Abadan Iran
# administrateur coach
# Carlos Carlos
# Quieroz
# dire said
# “
# the
# rêve dream
# is
# over
# ”
# but
# is
# déjà already
# affronter looking
# to
# the
# avenir future
# .
#
#
#
# “
# The
# premier first
# mi-temps half
# was
# uracile US
# and
# the
# deuxième second
# mi-temps half
# Abadan Iran
# ,
# ”
# dire said
# Quieroz
# ,
# who
# is
# Abadan Iran
# ’s
# long longest
# -
# servir serving
# administrateur coach
# ,
# having
# diriger managed
# the
# attelage team
# from
# 2011
# to
# 2019
# ,
# before
# rendre returning
# for
# a
# deuxième second
# aller spell
# in
# charge
# in
# Sept September
# .
#
#
#
# “
# The
# différence difference
# [
# was
# ]
# we
# did
# n’t
# score
# in
# the
# deuxième second
# mi-temps half
# as
# we
# should
# .
# But
# ,
# the
# rêve dream
# is
# over
# .
# Now
# ,
# its
# cérébration thinking
# about
# the
# next
# baïonnette step
# for
# Abadan Iran
# ,
# ”
# ajouter added
# Quieroz
# ,
# who
# is
# the
# only
# administrateur coach
# to
# have
# amener led
# the
# attelage team
# to
# consecutive
# monde World
# coupe Cups
# .

# %% [markdown]
# [PROJET Q4] Réécrire un texte en interchangeant tous les mots par leurs définitions. Cela revient à produire la contrainte Littérature Définitionnelle (https://www.oulipo.net/fr/contraintes/litterature-definitionnelle) du groupe de recherche en écriture créative OULIPO (https://fr.wikipedia.org/wiki/Oulipo).

# %%
# insérez votre code ici
# Out:
# The
# a base containing nitrogen that is found in RNA (but not in DNA) and derived from pyrimidine; pairs with adenine US
# a male person who plays a significant role (husband or lover or boyfriend) in the life of a particular woman Men
# ’s
# a person who owes allegiance to that nation National
# two or more draft animals that work together to pull something Team
# (
# USMNT
# )
# was
# represent fictitiously, as in a play, or pretend to be or act like made
# to
# proceed towards a goal or along a path or through an activity work
# to the full extent possible; all the way hard
# for
# its
# a point located with respect to surface features of some region place
# in
# the
# the concerns of this life as distinguished from heaven and the afterlife World
# a large metal vessel with two handles that is awarded as a trophy to the winner of a competition Cup
# a very attractive or seductive looking woman knockout
# a large platform on which people can stand and can be seen by an audience stage
# ,
# earn on some commercial or business transaction; earn as salary or wages earning
# a
# not given to gentleness or sentimentality tough
# 1
# -
# 0
# a victory (as in a race or other competition) win
# over
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# in
# a
# any bundle of nerve fibers running to various organs and tissues of the body nerve
# -
# seize together, as of parallel ropes of a tackle in order to prevent running through the block racking
# a set that is closed, associative, has an identity element and every element has an inverse Group
# (physics) a unit of nuclear cross section; the effective circular area that one particle presents to another as a target for an encounter B
# decider
# at
# an Arab country on the peninsula of Qatar; achieved independence from the United Kingdom in 1971; the economy is dominated by oil Qatar
# 2022
# .
#
#
#
# a religious person who believes Jesus is the Christ and who is a member of a Christian denomination Christian
# Pulisic
# ’s
# preceding all others in time or space or degree first
# -
# one of two divisions into which some games or performances are divided: the two divisions are separated by an interval half
# game equipment consisting of the place toward which players of a game try to advance a ball or puck in order to score points goal
# was
# all
# that
# divide into two or more branches so as to form a fork separated
# the
# two
# (sports) the spin given to a ball by striking it on one side or releasing it with a sharp twist sides
# as
# the
# USMNT
# move forward or upward in order to touch; also in a metaphorical sense reached
# the
# a partsong in which voices follow each other; one voice starts and others join in one after another until all are singing different parts of the song at the same time round
# of
# 16
# for
# the
# preceding all others in time or space or degree first
# the continuum of experience in which events pass from the future through the present to the past time
# since
# 2014
# .
#
#
#
# The
# the somatic sensation that results from applying force to an area of skin pressure
# was
# definitely or positively (`sure' is sometimes used informally for `surely') certainly
# in a state required for something to function or be effective on
# for
# Gregg
# Berhalter
# ’s
# (sports) the spin given to a ball by striking it on one side or releasing it with a sharp twist side
# in
# an Arab country on the peninsula of Qatar; achieved independence from the United Kingdom in 1971; the economy is dominated by oil Qatar
# after
# the
# limited to or in the interests of a particular nation national
# two or more draft animals that work together to pull something team
# ’s
# a person with a record of failing; someone who loses consistently failure
# to
# specify as a condition or requirement in a contract or agreement; make an express demand or provision in an agreement qualify
# for
# the
# 2018
# the concerns of this life as distinguished from heaven and the afterlife World
# a large metal vessel with two handles that is awarded as a trophy to the winner of a competition Cup
# ,
# but
# the
# a base containing nitrogen that is found in RNA (but not in DNA) and derived from pyrimidine; pairs with adenine US
# communicate with a place or person; establish communication with, as if by telephone got
# the
# a specific piece of work required to be done as a duty or for a specific fee job
# spend time in prison or in a labor camp done
# with
# three
# gritty
# a set that is closed, associative, has an identity element and every element has an inverse group
# the act of performing; of doing something successfully; using knowledge as distinguished from merely possessing it performances
# .
#
#
#
# It
# definitely or positively (`sure' is sometimes used informally for `surely') certainly
# was
# n’t
# pretty
# at
# the continuum of experience in which events pass from the future through the present to the past times
# ,
# in
# particular
# in
# the
# the act of closing something closing
# a large platform on which people can stand and can be seen by an audience stages
# against
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# ,
# but
# move forward, also in the metaphorical sense progressing
# through
# the
# a set that is closed, associative, has an identity element and every element has an inverse group
# a large platform on which people can stand and can be seen by an audience stage
# was
# the
# the least possible minimum
# the feeling that something is about to happen expectation
# for
# this
# creating or arousing excitement exciting
# (used of living things especially persons) in an early period of life or development or growth young
# two or more draft animals that work together to pull something team
# .
#
#
#
# There
# will
# be
# some
# a commercial or industrial enterprise and the people who constitute it concerns
# move away from a place into another direction going
# into
# the
# a very attractive or seductive looking woman knockout
# a large platform on which people can stand and can be seen by an audience stages
# ,
# (postpositive) however though
# ,
# after
# Pulisic
# be set at a disadvantage suffered
# an
# of or relating to or near the abdomen abdominal
# any physical damage to the body caused by violence or accident or fracture etc. injury
# while
# get a certain number or letter indicating quality or performance scoring
# the
# a person with a record of successes winner
# .
#
#
#
# The
# USMNT
# will
# be
# intend with some possibility of fulfilment hoping
# its
# a plane figure with 5 or more points; often used as an emblem star
# a male person who plays a significant role (husband or lover or boyfriend) in the life of a particular woman man
# ,
# provide (movies) with a soundtrack of a foreign language dubbed
# ‘
# a dining-room attendant who is in charge of the waiters and the seating of customers Captain
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 America
# ’
# by
# some
# ,
# is
# meeting adequate standards for a purpose fit
# for
# the
# a partsong in which voices follow each other; one voice starts and others join in one after another until all are singing different parts of the song at the same time round
# of
# 16
# (music) a slur over two notes of the same pitch; indicates that the note is to be sustained for their combined time value tie
# against
# the
# a constitutional monarchy in western Europe on the North Sea; half the country lies below sea level Netherlands
# on
# the seventh and last day of the week; observed as the Sabbath by Jews and some Christians Saturday
# to bring something about at a later time than following
# the
# the quality of being sufficiently interesting to be reported in news bulletins news
# that
# Pulisic
# had
# been
# cause to be admitted; of persons to an institution sent
# to
# a medical institution where sick or injured people are given medical or surgical care hospital
# for
# a
# the act of scanning; systematic examination of a prescribed region scan
# .
#
#
#
# United States photographer(1886-1958) Weston
# McKennie
# and
# elected vice president and became the 10th President of the United States when Harrison died (1790-1862) Tyler
# (Old Testament) in Judeo-Christian mythology; the first man and the husband of Eve and the progenitor of the human race Adams
# behave as expected during of holidays or rites celebrate
# the
# a recognized sequence of moves at the beginning of a game of chess opening
# game equipment consisting of the place toward which players of a game try to advance a ball or puck in order to score points goal
# .
#
#
#
# a person with a record of successes Winner
# to get into a position of having, e.g., safety, comfort takes
# all
#
#
#
# This
# was
# the
# in the final outcome only
# the
# third
# the social act of assembling for some common purpose meeting
# at all times; all the time and on every occasion ever
# between
# the
# two
# United States prohibitionist who raided saloons and destroyed bottles of liquor with a hatchet (1846-1911) nations
# and
# their
# preceding all others in time or space or degree first
# the concerns of this life as distinguished from heaven and the afterlife World
# a large metal vessel with two handles that is awarded as a trophy to the winner of a competition Cup
# a casual meeting with a person or thing encounter
# since
# a republic in western Europe; the largest country wholly in Europe France
# 1998
# –
# a
# with regard to social relationships involving authority politically
# energize a battery by passing a current through it in the direction opposite to discharge charged
# a person who is of equal standing with another in a group match
# that
# go to see a place, as for entertainment saw
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# come up to the surface of or rise emerge
# as
# a
# a pile of sheaves of grain set on end in a field to dry; stalks of Indian corn set up in a field shock
# 2
# -
# 1
# a person with a record of successes winner
# .
#
#
#
# That
# was
# the
# preceding all others in time or space or degree first
# the continuum of experience in which events pass from the future through the present to the past time
# that
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# and
# the
# a base containing nitrogen that is found in RNA (but not in DNA) and derived from pyrimidine; pairs with adenine US
# ,
# on certain occasions or in certain cases but not always sometimes
# to give an account or representation of in words described
# in an official role officially
# in
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# as
# the
# ‘
# a person who has achieved distinction and honor in some field Great
# (Judeo-Christian and Islamic religions) chief spirit of evil and adversary of God; tempter of mankind; master of Hell Satan
# ,
# ’
# had
# meet by design; be present at the arrival of met
# on
# the
# any of various games played with a ball (round or oval) in which two teams try to kick or carry or propel the ball into each other's goal football
# an all-fours game in which the first card led is a trump pitch
# and
# the
# above average in size or number or quantity or magnitude or extent biggest
# sporting
# the time of a particular event occasion
# between
# the
# a particular geographical region of indefinite boundary (usually serving some special purpose or distinguished by its people or culture or geography) countries
# since
# the
# 1979
# the overthrow of a government by those who are governed revolution
# .
#
#
#
# The
# alternative names for the body of a human being build
# -
# up
# to
# this
# the game equipment needed in order to play a particular game game
# in
# an Arab country on the peninsula of Qatar; achieved independence from the United Kingdom in 1971; the economy is dominated by oil Qatar
# has
# been
# in like or similar manner; ; - Samuel Johnson similarly
# pronounced with relatively tense tongue muscles (e.g., the vowel sound in `beat') tense
# ,
# with
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# to a greater degree or extent; used with comparisons even
# challenge (somebody) to make good on a statement; charge with or censure for an offense calling
# for
# the
# USMNT
# to
# be
# remove from a position or office expelled
# from
# the
# the concerns of this life as distinguished from heaven and the afterlife World
# a large metal vessel with two handles that is awarded as a trophy to the winner of a competition Cup
# after
# the
# a base containing nitrogen that is found in RNA (but not in DNA) and derived from pyrimidine; pairs with adenine US
# a football game in which two teams of 11 players try to kick or head a ball into the opponents' goal Soccer
# the act of constituting a political unity out of a number of separate states or colonies or provinces so that each member retains the management of its internal affairs Federation
# ride Western style and bob up and down in the saddle in rhythm with a horse's trotting gait posted
# an
# of or relating to Iran or its people or language or culture Iranian
# a listing printed in all issues of a newspaper or magazine (usually on the editorial page) that gives the name of the publication and the names of the editorial staff, etc. flag
# without
# the
# a visible symbol representing an abstract idea emblem
# of
# the
# Islamic
# a political system in which the supreme power lies in a body of citizens who can elect people to represent them Republic
# on
# its
# relating to human society and its members social
# someone who serves as an intermediary between the living and the dead media
# the combination of a particular computer and a particular operating system platforms
# to
# establish the validity of something, as by an example, explanation or experiment show
# a military operation (often involving new supplies of men and materiel) to strengthen a military force or aid in the performance of its mission support
# for
# someone who participates in a public display of group feeling protesters
# in
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# .
#
#
#
# USMNT
# (sports) someone in charge of training an athlete or a team manager
# Berhalter
# and
# a dining-room attendant who is in charge of the waiters and the seating of customers captain
# elected vice president and became the 10th President of the United States when Harrison died (1790-1862) Tyler
# (Old Testament) in Judeo-Christian mythology; the first man and the husband of Eve and the progenitor of the human race Adams
# in addition also
# be oriented in a certain direction, often with respect to another reference point; be opposite to faced
# some
# not given to gentleness or sentimentality tough
# a formal proposal for action made to a deliberative assembly for discussion and vote questions
# from
# of or relating to Iran or its people or language or culture Iranian
# a writer for newspapers and magazines journalists
# in
# a
# fiery
# the print media responsible for gathering and publishing news in the form of newspapers or magazines press
# an association of sports teams that organizes matches for its members conference
# ,
# withstand the force of something fending
# off
# an assertion that someone is guilty of a fault or offence accusations
# of
# insincerity by virtue of pretending to have qualities or beliefs that you do not really have hypocrisy
# and
# a manner that is generally disrespectful and contemptuous disrespect
# .
#
#
#
# The
# a sudden outburst (as of protest) furore
# surround with a wall in order to fortify surrounding
# this
# the game equipment needed in order to play a particular game game
# in the final outcome only
# make an addition (to); join or combine or unite with others; increase the quality, quantity, size or scope of added
# to
# the
# a dramatic work intended for performance by actors on a stage drama
# of
# a
# the pairing of people or things as for comparison or competition matchup
# that
# –
# to a greater degree or extent; used with comparisons even
# in
# a
# an electrical home appliance that cleans by suction vacuum
# from a particular thing or place or position (`forth' is obsolete) away
# from
# off
# -
# (mathematics) a set of elements such that addition and multiplication are commutative and associative and multiplication is distributive over addition and there are two elements 0 and 1 field
# a phenomenon that follows and is caused by some previous phenomenon issues
# –
# was
# stand behind and guarantee the quality, accuracy, or condition of guaranteed
# to
# be
# fraught
# with
# a balance between and interplay of opposing elements or tendencies (especially in art or literature) tension
# .
#
#
#
# Both
# two or more draft animals that work together to pull something teams
# be aware of the truth of something; have a belief or faith in something; regard as true beyond any doubt knew
# a
# a victory (as in a race or other competition) win
# would
# fill or close tightly with or as if with a plug secure
# a
# a point located with respect to surface features of some region place
# in
# the
# a partsong in which voices follow each other; one voice starts and others join in one after another until all are singing different parts of the song at the same time round
# of
# 16
# ,
# but
# for
# the
# USMNT
# to a greater degree or extent; used with comparisons even
# a
# (American football) the quarterback moves back as if to pass and then hands the ball to the fullback who is running toward the line of scrimmage draw
# would
# not
# be
# enough
# to
# go to see a place, as for entertainment see
# it
# move forward, also in the metaphorical sense progress
# from
# the
# a set that is closed, associative, has an identity element and every element has an inverse group
# .
#
#
#
# The
# USMNT
# cause to move; cause to be in a certain position or condition had
# to
# battle or contend against in or as if in a battle battled
# to the full extent possible; all the way hard
# for
# its
# a point located with respect to surface features of some region place
# in
# the
# a partsong in which voices follow each other; one voice starts and others join in one after another until all are singing different parts of the song at the same time round
# of
# 16
# .
#
#
#
# There
# have the quality of being; (copula, used with an adjective or a predicate noun) were
# n’t
# to a degree exceeding normal or proper limits too
# a quantifier that can be used with count nouns and is often preceded by `as' or `too' or `so' or `that'; amounting to a large but indefinite number many
# structure displaying a board on which advertisements can be posted signs
# of
# of an early stage in the development of a language or literature early
# any bundle of nerve fibers running to various organs and tissues of the body nerves
# from
# the
# USMNT
# as
# Berhalter
# ’s
# (sports) the spin given to a ball by striking it on one side or releasing it with a sharp twist side
# say out loud for the purpose of recording dictated
# the
# the act of playing for stakes in the hope of winning (including the payment of a price for a chance to win a prize) play
# in
# the
# a recognized sequence of moves at the beginning of a game of chess opening
# a large platform on which people can stand and can be seen by an audience stages
# –
# get pleasure from enjoying
# 65
# %
# of
# the
# a territory that is controlled by a ruling state possession
# –
# though
# it
# to get into a position of having, e.g., safety, comfort took
# until
# the
# 28th
# a unit of time equal to 60 seconds or 1/60th of an hour minute
# for
# it
# summon into action or bring into existence, often as if by magic conjure
# the
# preceding all others in time or space or degree first
# a measure of how likely it is that some event will occur; a number expressing the ratio of favorable cases to the whole number of cases possible chance
# of
# a promise to pay a specified amount on demand or at a certain time note
# .
#
#
#
# Josh
# Sargeant
# ’s
# primarily temporal sense; being or indicating a relatively great or greater than average duration or passage of time or a duration as specified long
# -
# (mathematics) the set of values of the dependent variable for which a function is defined range
# a series of actions advancing a principle or tending toward a particular end effort
# to get into a position of having, e.g., safety, comfort took
# a
# the movement of the pointer or pen of a measuring instrument from its zero position deflection
# off
# an
# of or relating to Iran or its people or language or culture Iranian
# a fighter who holds out against attack defender
# and
# move downward and lower, but not necessarily all the way fell
# completely and without qualification; used informally as intensifiers perfectly
# into
# the
# an established line of travel or access path
# of
# a disciple of Saint Paul who became the leader of the Christian community at Ephesus Timothy
# Weah
# ,
# who
# by chance perhaps
# did
# n’t
# expand or complete (a part in a piece of baroque music) by supplying the harmonies indicated in the figured bass realize
# he
# was
# to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly') all
# alone
# in
# a group of people with a common ideology who try together to achieve certain general goals front
# of
# game equipment consisting of the place toward which players of a game try to advance a ball or puck in order to score points goal
# and
# run with the ball, in football rushed
# a
# having a head of a specified kind or anything that serves as a head; often used in combination headed
# a series of actions advancing a principle or tending toward a particular end effort
# that
# Alireza
# Beiranvand
# in
# the
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# game equipment consisting of the place toward which players of a game try to advance a ball or puck in order to score points goal
# reach with a blow or hit in a particular spot caught
# with
# the condition of being comfortable or relieved (especially after being relieved of distress) ease
# .
#
#
#
# On
# the
# (of siblings) related through one parent only half
# distance measured by the time taken to cover it hour
# Apostle and companion of Saint Peter; assumed to be the author of the second Gospel mark
# ,
# Weah
# at a previous time once
# anew again
# to get into a position of having, e.g., safety, comfort took
# up
# a
# brilliant
# the spatial property of a place where or way in which something is situated position
# inside
# the
# any one of several designated areas on a ball field where the batter or catcher or coaches are positioned box
# but
# move along on skis skied
# his
# a series of actions advancing a principle or tending toward a particular end effort
# (often used as a combining form) in a good or proper or satisfactory manner or to a high standard (`good' is a nonstandard dialectal variant for `well') well
# over
# the
# game equipment consisting of a horizontal bar to be jumped or vaulted over crossbar
# after
# being
# put into a position that will restore a normal state set
# up
# by
# Sargeant
# .
#
#
#
# The
# USMNT
# ’s
# the somatic sensation that results from applying force to an area of skin pressure
# after an unspecified period of time or an especially long delay eventually
# give instructions to or direct somebody to do something with authority told
# seven
# a unit of time equal to 60 seconds or 1/60th of an hour minutes
# before
# (of siblings) related through one parent only half
# the continuum of experience in which events pass from the future through the present to the past time
# ,
# to get into a position of having, e.g., safety, comfort taking
# the
# the angle between the direction a gun is aimed and the position of a moving target (correcting for the flight time of the missile) lead
# to bring something about at a later time than following
# an
# incisive
# two or more draft animals that work together to pull something team
# (game) a player's turn to take some action permitted by the rules of the game move
# .
#
#
#
# United States photographer(1886-1958) Weston
# McKennie
# ’s
# the sharp point of a pin pinpoint
# a representation of the structure on which Jesus was crucified; used as an emblem of Christianity or in heraldry cross
# (mathematics) a set of elements such that addition and multiplication are commutative and associative and multiplication is distributive over addition and there are two elements 0 and 1 field
# a pitch that is not in the strike zone ball
# was
# be in the front of or on top of headed
# in or to or toward a past time back
# across
# game equipment consisting of the place toward which players of a game try to advance a ball or puck in order to score points goal
# by
# the
# raid and rove in search of booty marauding
# Sergiño
# Dest
# and
# sleep fully clothed in the same bed with one's betrothed bundled
# (baseball) base consisting of a rubber slab where the batter stands; it must be touched by a base runner in order to score home
# in a courageous manner bravely
# by
# Pulisic
# ,
# who
# be set at a disadvantage suffered
# a
# hefty
# (physics) a brief event in which two or more bodies come together collision
# with
# Beiranvand
# as
# he
# cause to move around a center so as to show another side of turned
# the
# a pitch that is not in the strike zone ball
# over
# the
# mechanical system in a factory whereby an article is conveyed through sites at which successive operations are performed on it line
# .
#
#
#
# The
# USMNT
# ’s
# something or someone that provides a source of happiness delight
# in a swift manner swiftly
# cause to move around a center so as to show another side of turned
# to
# be on the mind of worry
# as
# it
# was
# evident
# that
# Pulisic
# was
# in
# too closely correlated to be attributed to chance and therefore indicating a systematic relation significant
# emotional distress; a fundamental feeling that people try to avoid pain
# to bring something about at a later time than following
# the
# a state of conflict between colors clash
# ,
# walk impeded by some physical limitation or injury limping
# slowly as if burdened by much weight heavily
# as
# he
# was
# help to some food; help with food or drink helped
# off
# the
# an all-fours game in which the first card led is a trump pitch
# by
# two
# any of several Old World herbs of the genus Medicago having small flowers and trifoliate compound leaves medics
# .
#
#
#
# Pulisic
# in the near future soon
# re
# -
# be or play a part of or in entered
# the
# an all-fours game in which the first card led is a trump pitch
# ,
# but
# the
# Chelsea
# a male person who plays a significant role (husband or lover or boyfriend) in the life of a particular woman man
# was
# clear to the mind; with distinct mental discernment clearly
# despite anything to the contrary (usually following a concession) still
# be engaged in a fight; carry on a fight struggling
# with
# the
# the sound of knocking (as on a door or in an engine or bearing) knock
# .
#
#
#
# a religious person who believes Jesus is the Christ and who is a member of a Christian denomination Christian
# Pulisic
# is
# surround with a wall in order to fortify surrounded
# by
# a fellow member of a team teammates
# after
# move away from a place into another direction going
# down
# hurt the feelings of injured
# to bring something about at a later time than following
# his
# game equipment consisting of the place toward which players of a game try to advance a ball or puck in order to score points goal
# .
#
#
#
# As
# the
# USMNT
# become attached by or as if by the process of growth grew
# in
# a state of confident hopefulness that events will be favorable confidence
# ,
# (printing) a block of type without a raised letter; used for spacing between words or sentences spaces
# begin an event that is implied and limited by the nature or inherent function of the direct object began
# to
# display the contents of a file or start an application as on a computer open
# up
# in
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# ’s
# (sports) the team that is trying to prevent the other team from scoring defense
# and
# Weah
# use or exercise the mind or one's power of reason in order to make inferences, decisions, or arrive at a solution or judgments thought
# he
# ’d
# bend over or curl up, usually with laughter or pain doubled
# his
# two or more draft animals that work together to pull something team
# ’s
# the angle between the direction a gun is aimed and the position of a moving target (correcting for the flight time of the missile) lead
# only a very short time before; ; ; ; ; - W.B.Yeats just
# before
# the
# a definite length of time marked off by two instants interval
# ,
# have an end, in a temporal, spatial, or quantitative sense; either spatial or metaphorical finishing
# (used as an intensifier) extremely well wonderfully
# with
# the
# the region that is outside of something outside
# of
# his
# an instrument of torture that is used to heat or crush the foot and leg boot
# in the final outcome only
# to
# be
# meet by design; be present at the arrival of met
# by
# the
# official (in tennis, soccer, football, etc.) who assists the referee in some way (especially by watching for out of bounds or offside) linesman
# ’s
# a listing printed in all issues of a newspaper or magazine (usually on the editorial page) that gives the name of the publication and the names of the editorial staff, etc. flag
# for
# the
# very limited in degree narrowest
# of
# illegally beyond a prescribed line or area or ahead of the ball or puck offside
# the trait of resoluteness as evidenced by firmness of character or purpose decisions
# .
#
#
#
# Though
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# would
# have
# been
# enjoying or showing or marked by joy or pleasure happy
# to
# change under the action or influence of the weather weather
# that
# preceding all others in time or space or degree first
# -
# one of two divisions into which some games or performances are divided: the two divisions are separated by an interval half
# a violent weather condition with winds 64-72 knots (11 on the Beaufort scale) and precipitation and thunder and lightning storm
# ,
# it
# was
# a
# in an amazing manner; to everyone's surprise surprisingly
# subdued
# the act of performing; of doing something successfully; using knowledge as distinguished from merely possessing it performance
# –
# in
# particular
# to bring something about at a later time than following
# Pulisic
# ’s
# game equipment consisting of the place toward which players of a game try to advance a ball or puck in order to score points goal
# –
# from
# a
# two or more draft animals that work together to pull something team
# that
# had
# cause to do; cause to act in a specified manner caused
# both
# a division of the United Kingdom England
# and
# one of the four countries that make up the United Kingdom of Great Britain and Northern Ireland; during Roman times the region was known as Cambria Wales
# intended or appropriate for defending against or deterring aggression or attack defensive
# a state of difficulty that needs to be resolved problems
# in
# its
# display the contents of a file or start an application as on a computer opening
# two
# a person who is of equal standing with another in a group matches
# .
#
#
#
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# did
# begin an event that is implied and limited by the nature or inherent function of the direct object begin
# the
# a part or voice or instrument or orchestra section lower in pitch than or subordinate to the first second
# one of two divisions into which some games or performances are divided: the two divisions are separated by an interval half
# with
# (comparative of `much' used with mass nouns) a quantifier meaning greater in size or amount or extent or degree more
# the power or right to give orders or make decisions authority
# ,
# pursue a creative activity; be engaged in a creative activity creating
# two
# brilliant
# a measure of how likely it is that some event will occur; a number expressing the ratio of favorable cases to the whole number of cases possible chances
# for
# large ornamental tropical American tree with bipinnate leaves and globose clusters of flowers with crimson stamens and seed pods that are eaten by cattle Saman
# Ghoddos
# but
# the
# Brentford
# at or to or toward the front; ; ; ; (`forrad' and `forrard' are dialectal variations) forward
# was
# (usually followed by `to') not having the necessary means or skill or know-how unable
# to
# take the trouble to do something; concern oneself trouble
# USMNT
# the defensive position on an ice hockey or soccer or lacrosse team who stands in front of the goal and tries to prevent opposing players from scoring goalkeeper
# the property of having little or no contrast; lacking highlights or gloss Matt
# one of two persons who swing ropes for jumpers to skip over in the game of jump rope Turner
# .
#
#
#
# With
# the
# a timepiece that shows the time of day clock
# put a check mark on or near or next to ticking
# down
# ,
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# cause to move; cause to be in a certain position or condition had
# a
# having or deserving or conferring glory glorious
# a measure of how likely it is that some event will occur; a number expressing the ratio of favorable cases to the whole number of cases possible chance
# to
# tear down so as to make flat with the ground level
# the
# a number that expresses the accomplishment of a team or an individual in a game or contest score
# but
# Morteza
# Pouraliganji
# ’s
# bend one's back forward from the waist on down stooping
# a line of text serving to indicate what the passage below it is about header
# protect by covering with a thin sheet of metal flashed
# in a narrow manner; not allowing for exceptions narrowly
# to or over a great extent or range; far wide
# of
# the
# at or to or from a great distance in space far
# a pole or stake set up to mark something (as the start or end of a race track) post
# (quantifier used with mass nouns) great in quantity or degree or extent much
# to
# the
# sculpture consisting of shapes carved on a surface so as to stand out from the surrounding background relief
# of
# the
# of or relating to the United States of America or its people or language or culture American
# a device for creating a current of air by movement of a surface or surfaces fans
# in
# the
# tiered seats consisting of a structure (often made of wood) where people can sit to watch an event (game or parade) stands
# ,
# a quantifier that can be used with count nouns and is often preceded by `as' or `too' or `so' or `that'; amounting to a large but indefinite number many
# who
# cause to move; cause to be in a certain position or condition had
# their
# a line of text serving to indicate what the passage below it is about heads
# in
# their
# a position given by its location to the side of an object hands
# .
#
#
#
# There
# have the quality of being; (copula, used with an adjective or a predicate noun) were
# used chiefly as a direction or description in music loud
# a demand by a broker that a customer deposit enough to bring his margin up to the minimum requirement calls
# for
# a
# (games) a handicap or disadvantage that is imposed on a competitor (or a team) for an infraction of the rules of the game penalty
# from
# the
# of or relating to Iran or its people or language or culture Iranian
# a person who participates in or is skilled at some game players
# at an advanced age or stage late
# in a state required for something to function or be effective on
# in
# the
# nine
# a unit of time equal to 60 seconds or 1/60th of an hour minutes
# of
# make an addition (to); join or combine or unite with others; increase the quality, quantity, size or scope of added
# the continuum of experience in which events pass from the future through the present to the past time
# ,
# with
# Mehdi
# Taremi
# be emphatic or resolute and refuse to budge insisting
# that
# Cameron
# Englishman and Egyptologist who in 1922 discovered and excavated the tomb of Tutankhamen (1873-1939) Carter
# -
# Vickers
# had
# cause to move in a certain direction by exerting a force upon, either physically or in an abstract sense pulled
# down
# the
# port city in northwest Portugal; noted for port wine Porto
# at or to or toward the front; ; ; ; (`forrad' and `forrard' are dialectal variations) forward
# away from a more central or a more northerly place down
# as
# he
# make an effort or attempt attempted
# to
# communicate with a place or person; establish communication with, as if by telephone get
# on
# the
# a piece of cloth that is left over after the rest has been used or sold end
# of
# a
# a representation of the structure on which Jesus was crucified; used as an emblem of Christianity or in heraldry cross
# .
#
#
#
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 USA
# a person who participates in or is skilled at some game players
# behave as expected during of holidays or rites celebrate
# at
# the
# final
# acoustic device that forces air or steam against an edge or into a cavity and so produces a loud shrill sound whistle
# .
#
#
#
# After
# a
# brief
# ,
# pronounced with relatively tense tongue muscles (e.g., the vowel sound in `beat') tense
# a mark left after a small piece has been chopped or broken off of something check
# ,
# a unit of electrical power in an AC circuit equal to the power dissipated when 1 volt produces a current of 1 ampere VAR
# reach, make, or come to a decision about something decided
# it
# was
# n’t
# a
# (games) a handicap or disadvantage that is imposed on a competitor (or a team) for an infraction of the rules of the game penalty
# and
# in the near future soon
# after
# (sports) the chief official (as in boxing or American football) who is expected to ensure fair play referee
# Mateu
# Lahoz
# cause to move by means of an air current blew
# his
# acoustic device that forces air or steam against an edge or into a cavity and so produces a loud shrill sound whistle
# to
# put an end to end
# the
# the game equipment needed in order to play a particular game game
# .
#
#
#
# Both
# two or more draft animals that work together to pull something teams
# descend into or as if into some soft substance or place sank
# to
# the
# the ground on which people and animals move about floor
# –
# for
# very
# the number that remains after subtraction; the number that when added to the subtrahend gives the minuend difference
# the state of having good sense and sound judgment reasons
# –
# but
# the
# USMNT
# will
# be aware of the truth of something; have a belief or faith in something; regard as true beyond any doubt know
# an
# get better improved
# the act of performing; of doing something successfully; using knowledge as distinguished from merely possessing it performance
# is
# absolutely essential necessary
# if
# it
# hunt or look for; want for a particular reason wants
# to
# cause to move; cause to be in a certain position or condition have
# a
# a measure of how likely it is that some event will occur; a number expressing the ratio of favorable cases to the whole number of cases possible chance
# of
# contribute to the progress or growth of advancing
# at or to or from a great distance in space further
# in
# an Arab country on the peninsula of Qatar; achieved independence from the United Kingdom in 1971; the economy is dominated by oil Qatar
# .
#
#
#
# ‘
# I
# intend with some possibility of fulfilment hope
# our
# a device for creating a current of air by movement of a surface or surfaces fans
# …
# absolve from payment forgive
# us
# ’
#
#
# to bring something about at a later time than Following
# the
# the feeling that accompanies an experience of being thwarted in attaining your goals defeat
# ,
# an
# of or pertaining to emotion emotional
# Saeid
# Ezatolahi
# address a question to and expect an answer from asked
# for
# compassionate feelings that support a willingness to forgive forgiveness
# from
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# a device for creating a current of air by movement of a surface or surfaces fans
# .
#
#
#
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# was
# in
# a
# having a strong physiological or chemical effect; ; ; , strong
# the spatial property of a place where or way in which something is situated position
# move away from a place into another direction going
# into
# the
# final
# the game equipment needed in order to play a particular game game
# to bring something about at a later time than following
# that
# of extreme importance; vital to the resolution of a crisis crucial
# 2
# -
# 0
# a victory (as in a race or other competition) win
# over
# one of the four countries that make up the United Kingdom of Great Britain and Northern Ireland; during Roman times the region was known as Cambria Wales
# ,
# have or feel a need for needing
# only a very short time before; ; ; ; ; - W.B.Yeats just
# a
# (American football) the quarterback moves back as if to pass and then hands the ball to the fullback who is running toward the line of scrimmage draw
# to
# the act of moving forward (as toward a goal) progress
# ,
# but
# cause to be in a certain state; cause to be in a certain relation put
# in
# a
# disappointing
# the act of performing; of doing something successfully; using knowledge as distinguished from merely possessing it performance
# with
# a
# a point located with respect to surface features of some region place
# in
# the
# a very attractive or seductive looking woman knockout
# a large platform on which people can stand and can be seen by an audience stages
# on
# the
# mechanical system in a factory whereby an article is conveyed through sites at which successive operations are performed on it line
# .
#
#
#
# “
# I
# ’m
# used as intensifiers; `real' is sometimes used informally for `really'; `rattling' is informal really
# feeling or expressing regret or sorrow or a sense of loss over something done or undone sorry
# on
# for someone's benefit (usually expressed as `in behalf' rather than `on behalf' and usually with a possessive) behalf
# of
# our
# a person who participates in or is skilled at some game players
# ,
# our
# a set that is closed, associative, has an identity element and every element has an inverse group
# ,
# that
# we
# could
# n’t
# communicate with a place or person; establish communication with, as if by telephone get
# our
# a possibility due to a favorable combination of circumstances opportunity
# to
# specify as a condition or requirement in a contract or agreement; make an express demand or provision in an agreement qualify
# for
# the
# next
# a partsong in which voices follow each other; one voice starts and others join in one after another until all are singing different parts of the song at the same time round
# ,
# ”
# the
# midfielder
# give instructions to or direct somebody to do something with authority said
# .
#
#
#
# “
# the course of existence of an individual; the actions and events that occur in living Life
# and
# any of various games played with a ball (round or oval) in which two teams try to kick or carry or propel the ball into each other's goal football
# is
# move away from a place into another direction going
# on
# and
# that
# can
# be
# a
# having desirable or positive qualities especially those suitable for a thing specified good
# the significance of a story or event lesson
# for
# us
# ,
# at
# the superlative of `little' that can be used with mass nouns and is usually preceded by `the'; a quantifier meaning smallest in amount or extent or degree least
# for
# the
# (used of living things especially persons) in an early period of life or development or growth young
# a person who participates in or is skilled at some game players
# like
# me
# for
# the
# a verb tense that expresses actions or states in the future future
# .
# (used to introduce a logical conclusion) from that fact or reason or as a result So
# I
# intend with some possibility of fulfilment hope
# our
# a device for creating a current of air by movement of a surface or surfaces fans
# and
# our
# members of a family line people
# in
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# ,
# they
# absolve from payment forgive
# us
# and
# I
# undergo an emotional sensation or be in a particular state of mind feel
# only a very short time before; ; ; ; ; - W.B.Yeats just
# feeling or expressing regret or sorrow or a sense of loss over something done or undone sorry
# ,
# that
# ’s
# it
# .
# ”
#
#
#
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# (sports) someone in charge of training an athlete or a team coach
# Venezuelan master terrorist raised by a Marxist-Leninist father; trained and worked with many terrorist groups (born in 1949) Carlos
# Quieroz
# give instructions to or direct somebody to do something with authority said
# “
# the
# a fantastic but vain hope (from fantasies induced by the opium pipe) dream
# is
# beyond the top or upper surface or edge; forward from an upright position over
# ”
# but
# is
# prior to a specified or implied time already
# be oriented in a certain direction, often with respect to another reference point; be opposite to looking
# to
# the
# a verb tense that expresses actions or states in the future future
# .
#
#
#
# “
# The
# preceding all others in time or space or degree first
# one of two divisions into which some games or performances are divided: the two divisions are separated by an interval half
# was
# a base containing nitrogen that is found in RNA (but not in DNA) and derived from pyrimidine; pairs with adenine US
# and
# the
# a part or voice or instrument or orchestra section lower in pitch than or subordinate to the first second
# one of two divisions into which some games or performances are divided: the two divisions are separated by an interval half
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# ,
# ”
# give instructions to or direct somebody to do something with authority said
# Quieroz
# ,
# who
# is
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# ’s
# for an extended time or at a distant time longest
# -
# put the ball into play serving
# (sports) someone in charge of training an athlete or a team coach
# ,
# having
# be in charge of, act on, or dispose of managed
# the
# two or more draft animals that work together to pull something team
# from
# 2011
# to
# 2019
# ,
# before
# go or come back to place, condition, or activity where one has been before returning
# for
# a
# a part or voice or instrument or orchestra section lower in pitch than or subordinate to the first second
# a time for working (after which you will be relieved by someone else) spell
# in
# a quantity of explosive to be set off at one time charge
# in
# the month following August and preceding October September
# .
#
#
#
# “
# The
# the number that remains after subtraction; the number that when added to the subtrahend gives the minuend difference
# [
# was
# ]
# we
# did
# n’t
# get a certain number or letter indicating quality or performance score
# in
# the
# a part or voice or instrument or orchestra section lower in pitch than or subordinate to the first second
# one of two divisions into which some games or performances are divided: the two divisions are separated by an interval half
# as
# we
# should
# .
# But
# ,
# the
# a fantastic but vain hope (from fantasies induced by the opium pipe) dream
# is
# beyond the top or upper surface or edge; forward from an upright position over
# .
# in the historical present; at this point in the narration of a series of past events Now
# ,
# its
# the process of using your mind to consider something carefully thinking
# about
# the
# next
# support consisting of a place to rest the foot while ascending or descending a stairway step
# for
# a theocratic Islamic republic in the Middle East in western Asia; Iran was the core of the ancient empire that was known as Persia until 1935; rich in oil Iran
# ,
# ”
# make an addition (to); join or combine or unite with others; increase the quality, quantity, size or scope of added
# Quieroz
# ,
# who
# is
# the
# only
# (sports) someone in charge of training an athlete or a team coach
# to
# have
# lead, as in the performance of a composition led
# the
# two or more draft animals that work together to pull something team
# to
# consecutive
# the concerns of this life as distinguished from heaven and the afterlife World
# a large metal vessel with two handles that is awarded as a trophy to the winner of a competition Cups
# .

# %%
# insérez votre code ici

# %%
# insérez votre code ici
